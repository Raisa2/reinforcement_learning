# %%
# Importing needed packages
import torch
import torch.nn as nn
import gym
import numpy as np
import random
import wandb
from copy import deepcopy

# %%
# Setting seeds
def make_deterministic(seed):
  torch.manual_seed(seed)
  random.seed(seed)
  np.random.seed(seed)

# %%
# Building a class for the neural network
class Neural_Network(nn.Module):
  def __init__(self, in_dim, out_dim, hidden_dim):
        super(Neural_Network, self).__init__()
        self.input_layer = nn.Linear(in_dim, hidden_dim[0])
        self.hidden_layer = nn.Linear(hidden_dim[0], hidden_dim[1])
        self.output_layer = nn.Linear(hidden_dim[1], out_dim)
       
  def forward (self, x, activation_function = nn.ReLU()):
    x = activation_function(self.input_layer(x))
    x = activation_function(self.hidden_layer(x))
    output = self.output_layer(x)
    return output

# %%
# Defining function for epsilon greedy actions
def eps_greedy(state, online_model, eps):
  with torch.no_grad():
    if (random.random() > eps):
      value, inds  = torch.max(online_model(state), dim=0)
      return inds.item()
    else:
      action = env.action_space.sample()
      return action

# %%
# Defining function for playing during and after training to obtain performance of the agent
def play(episodes, step, end, envs):
  x = 0
  returns = []

  for i in range(0, episodes):
    memory_states = [] 
    memory_actions = [] 
    memory_rewards = [] 
    memory_terminal = [] 
    memory_states_next = []

    state = envs.reset()
    while True:
      action = eps_greedy(state = torch.tensor(state).float() , online_model = online_model, eps = -1)
      state_next, reward, done, _ = envs.step(action)
      memory_actions.append(action)
      memory_states.append(state)
      memory_states_next.append(state_next)
      memory_rewards.append(reward)
      memory_terminal.append(done)
      state = state_next

      if done:
        x = sum(memory_rewards)
        state = envs.reset()
        returns.append(x)
        break

  if end:
    avg_return = sum(returns[-100:]) / 100
    print("Average return over 100 episodes of trained agent:", avg_return)
  else:
    avg_return = sum(returns[-25:]) / 25
    wandb.log({"Average return over 25 episodes of playing": avg_return,"step": step})
    print("Average return over 25 episodes of playing:", avg_return)

  return avg_return

# %%
##### Double DQN Algorithm ###########

# Seeds for repeatable training results
SEEDS = (12, 34, 56)

# Creating two environments: One for training and for playing
env = gym.make("CartPole-v1")
env2 = gym.make("CartPole-v1")

# Looping over different seeds for training different agents
for seed in SEEDS:
  make_deterministic(seed)
  print("SEED:", seed)
  wandb.init(project="DoubleDQN-CartPole", entity="raisa")
  config = wandb.config

  # Defining hyperparameters
  gamma = 0.99 # gamma
  eps_max = 1 # maximum value for epsilon
  eps_min = 0.1 # minimum value for epsilon
  eps_decay = (1-0.1) / 25000 # decaying factor for epsilon
  learning_rate = 0.0025 # learning rate
  batch_size = 64 # batch size
  num_episodes = 1000 # maximum number of episodes
  min_memory = 100 # size of replay memory at start of training
  max_memory =  1000 # maximum size of replay memory
  hidden_dims = [128, 64] # size of hidden layers in the neural network
  act_period = 150 # update frequency of target neural network
  criterion = nn.MSELoss() # loss function

  # Logging hyperparameters
  config.learning_rate = learning_rate
  config.gamma = gamma
  config.batch_size = batch_size
  config.num_episodes = num_episodes
  config.max_memory = max_memory
  config.min_memory = min_memory
  config.hidden_dim = hidden_dims
  config.act_period = act_period
  config.eps_max = eps_max
  config.eps_min = eps_min
  config.eps_decay = eps_decay
  config.seed = seed

  # Setting the seed for the environments
  env.seed(seed)
  env.action_space.seed(seed)
  env2.seed(seed)
  env2.action_space.seed(seed)

  # Initializing replay memory
  memory_states = [] 
  memory_actions = [] 
  memory_rewards = [] 
  memory_terminal = [] 
  memory_states_next = []
  reward_durch = []
  reward_werte = []

  # Initializing list for average returns during training
  returns_train = []
  # Initializing list for average returns during playing
  returns_play = []

  # Creating neural networks and setting optimizer
  online_model = (Neural_Network(in_dim = int(np.prod(env.observation_space.shape)), out_dim = env.action_space.n, hidden_dim=hidden_dims)) 
  target_model = (Neural_Network(in_dim = int(np.prod(env.observation_space.shape)), out_dim = env.action_space.n, hidden_dim=hidden_dims)) 
  optimizer = torch.optim.Adam(online_model.parameters(), lr=learning_rate)
  target_model = deepcopy(online_model) 

  # Storing minimum experiences in replay memory
  state = env.reset()
  for step in range(0,min_memory):
    action = env.action_space.sample()
    state_next, reward, done, _ = env.step(action)
    memory_actions.append(action)
    memory_states.append(state)
    memory_states_next.append(state_next)
    memory_rewards.append(reward)
    memory_terminal.append(done)
    state = state_next

    if done:
      state = env.reset()

  epsi = eps_max
  step = 0

  # Training the agent for number of episodes
  for episode in range(0, num_episodes):
    state = env.reset()
    reward_sum = 0
    while True:
      step += 1

    # Deleting first element of replay memory, if max_memory length is reached
      if(len(memory_states) > max_memory):
        memory_actions.pop(0)
        memory_states.pop(0)
        memory_states_next.pop(0)
        memory_rewards.pop(0)
        memory_terminal.pop(0)

    # Taking epsilon greedy action and storing experience in replay memory
      epsi = max(epsi - eps_decay, eps_min)
      action = eps_greedy(state = torch.tensor(state).float() , online_model = online_model, eps = epsi)
      state_next, reward, done, _ = env.step(action)
      memory_actions.append(action)
      memory_states.append(state)
      memory_states_next.append(state_next)
      memory_rewards.append(reward)
      memory_terminal.append(done)
      state = state_next

      reward_sum+=reward

    # Selecting random batch of experiences
      rand_index = np.random.choice(len(memory_states_next), size=batch_size, replace=False)
      batch_states = torch.tensor(np.array(memory_states)[rand_index], dtype=torch.float32) 
      batch_states_next = torch.tensor(np.array(memory_states_next)[rand_index], dtype=torch.float32) 
      batch_rewards = torch.tensor(np.array(memory_rewards)[rand_index], dtype=torch.float32) 
      batch_actions = torch.tensor(np.array(memory_actions)[rand_index], dtype=torch.int64) 
      batch_terminal = torch.tensor(np.array(memory_terminal)[rand_index], dtype=torch.int64) 
    
    # Calculating q-values for training
      with torch.no_grad():
      # Calculating q-values for next possible states
        q_values_next = online_model(batch_states_next)
      # Calculating indices of max q-values
        _, inds = torch.max(q_values_next,dim=1)
        inds = torch.reshape(input = inds, shape = (batch_size, 1))
      # Evaluating these actions with the help of target model
        max_q_values_next = torch.gather(target_model(batch_states_next), 1, inds)
        max_q_values_next = (torch.reshape(max_q_values_next, (-1,)))
      # Calculating the target q-values
        q_target = (batch_rewards + gamma * (1 - batch_terminal) * max_q_values_next)
  
      # Calculating the expected q-values
      q_exp = online_model(batch_states)
      batch_actions = torch.reshape(input = batch_actions, shape = (batch_size, 1))
      q_exp = torch.gather(input = q_exp, dim = 1, index = batch_actions)
      q_exp = (torch.reshape(q_exp, (-1,))) 

      # Calculating loss
      loss = criterion(q_target, q_exp) 

      optimizer.zero_grad()

      # Backpropagating the loss
      loss.backward()

      # Taking an optimization step
      optimizer.step()

      # Copying the weights of online network in the target network every act_period steps
      if step % act_period == 0:
        target_model = deepcopy(online_model) 

      # Playing every 500 steps to obtain the performance of the DDQN agent
      if step % 500 == 0:
        avg_return_play = play(episodes = 25, step = step, end = False, envs = env2)
        returns_play.append(avg_return_play)
      
      # If an episode has to come to an end, reset environment and print the reward for the last episode
      if done:
        print(episode + 1, epsi, reward_sum)
        returns_train.append(reward_sum)

        # If episode > 100, then print the average reward for the last hundred episodes 
        if episode + 1  > 100:
          x = sum(returns_train[-100:])/100
          print("Average return training:", x)
          # Logging the training average return
          wandb.log({"Average return over 100 episodes of training": x, "episode": episode + 1})  
        break

    # If training steps >= 2500 and the agent has obtained an average reward of 475 during last 5 times of playing, end training
    if step >= 2500:
      if sum(returns_play[-5:]) / 5 >= 475:
        break

  # Playing after training to obtain end results
  play(episodes = 100, step = step, end = True, envs = env2)
# Out:
# SEED: 12
# wandb: Currently logged in as: raisa (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/raisa/DoubleDQN-CartPole/runs/k85lld9d" target="_blank">fancy-puddle-42</a></strong> to <a href="https://wandb.ai/raisa/DoubleDQN-CartPole" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 1 0.9995679999999996 12.0
# 2 0.9986679999999987 25.0
# 3 0.9973359999999973 37.0
# 4 0.9969039999999969 12.0
# 5 0.9964359999999964 13.0
# 6 0.9958959999999959 15.0
# 7 0.9952839999999953 17.0
# 8 0.9946719999999947 17.0
# 9 0.9939159999999939 21.0
# 10 0.9933039999999933 17.0
# 11 0.9924759999999925 23.0
# 12 0.9919359999999919 15.0
# 13 0.9907839999999908 32.0
# 14 0.9898479999999898 26.0
# 15 0.9888759999999889 27.0
# 16 0.9884799999999885 11.0
# 17 0.9877239999999877 21.0
# 18 0.9871119999999871 17.0
# 19 0.9864639999999865 18.0
# 20 0.9858159999999858 18.0
# 21 0.9847359999999847 30.0
# 22 0.9841599999999842 16.0
# 23 0.9826839999999827 41.0
# 24 0.9820719999999821 17.0
# Average return over 25 episodes of playing: 37.96
# 25 0.9811359999999811 26.0
# 26 0.9805959999999806 15.0
# 27 0.98005599999998 15.0
# 28 0.9794799999999795 16.0
# 29 0.9783999999999784 30.0
# 30 0.9776079999999776 22.0
# 31 0.9763839999999764 34.0
# 32 0.9753759999999754 28.0
# 33 0.9749439999999749 12.0
# 34 0.9732879999999733 46.0
# 35 0.9711639999999712 59.0
# 36 0.9706239999999706 15.0
# 37 0.9702279999999702 11.0
# 38 0.9695079999999695 20.0
# 39 0.9689319999999689 16.0
# 40 0.9681399999999681 22.0
# 41 0.9672759999999673 24.0
# 42 0.9665559999999666 20.0
# 43 0.9651879999999652 38.0
# Average return over 25 episodes of playing: 143.88
# 44 0.9638199999999638 38.0
# 45 0.9628119999999628 28.0
# 46 0.9622719999999623 15.0
# 47 0.9618039999999618 13.0
# 48 0.9614079999999614 11.0
# 49 0.9594999999999595 53.0
# 50 0.9584199999999584 30.0
# 51 0.9577359999999577 19.0
# 52 0.956979999999957 21.0
# 53 0.9561519999999561 23.0
# 54 0.9542799999999543 52.0
# 55 0.9537399999999537 15.0
# 56 0.9531639999999532 16.0
# 57 0.9522279999999522 26.0
# 58 0.9515079999999515 20.0
# 59 0.9510759999999511 12.0
# 60 0.9502479999999502 23.0
# 61 0.9496359999999496 17.0
# 62 0.9489159999999489 20.0
# 63 0.9485559999999486 10.0
# 64 0.9476919999999477 24.0
# 65 0.9461799999999462 42.0
# Average return over 25 episodes of playing: 126.52
# 66 0.9455679999999456 17.0
# 67 0.9450639999999451 14.0
# 68 0.9444519999999444 17.0
# 69 0.9432999999999433 32.0
# 70 0.9428319999999428 13.0
# 71 0.9418959999999419 26.0
# 72 0.9413559999999414 15.0
# 73 0.9400959999999401 35.0
# 74 0.9386919999999387 39.0
# 75 0.9367479999999367 54.0
# 76 0.9355959999999356 32.0
# 77 0.9332919999999333 64.0
# 78 0.9328959999999329 11.0
# 79 0.9318159999999318 30.0
# 80 0.930987999999931 23.0
# 81 0.9303039999999303 19.0
# 82 0.928971999999929 37.0
# Average return over 25 episodes of playing: 120.0
# 83 0.9277479999999277 34.0
# 84 0.9273159999999273 12.0
# 85 0.9265599999999266 21.0
# 86 0.9256239999999256 26.0
# 87 0.924975999999925 18.0
# 88 0.9243279999999243 18.0
# 89 0.9237879999999238 15.0
# 90 0.9232839999999233 14.0
# 91 0.9226359999999226 18.0
# 92 0.9216279999999216 28.0
# 93 0.9211239999999211 14.0
# 94 0.9206919999999207 12.0
# 95 0.9193599999999194 37.0
# 96 0.9189279999999189 12.0
# 97 0.9184599999999185 13.0
# 98 0.9171639999999172 36.0
# 99 0.9154719999999155 47.0
# 100 0.9145719999999146 25.0
# 101 0.914031999999914 15.0
# Average return training: 23.76
# 102 0.912987999999913 29.0
# Average return training: 23.8
# 103 0.9125559999999125 12.0
# Average return training: 23.55
# 104 0.911979999999912 16.0
# Average return training: 23.59
# 105 0.9115119999999115 13.0
# Average return training: 23.59
# 106 0.9104319999999104 30.0
# Average return training: 23.74
# Average return over 25 episodes of playing: 190.84
# 107 0.9095679999999096 24.0
# Average return training: 23.81
# 108 0.9090999999999091 13.0
# Average return training: 23.77
# 109 0.9078039999999078 36.0
# Average return training: 23.92
# 110 0.907047999999907 21.0
# Average return training: 23.96
# 111 0.9065079999999065 15.0
# Average return training: 23.88
# 112 0.9044919999999045 56.0
# Average return training: 24.29
# 113 0.9039159999999039 16.0
# Average return training: 24.13
# 114 0.9034839999999035 12.0
# Average return training: 23.99
# 115 0.9027999999999028 19.0
# Average return training: 23.91
# 116 0.9024399999999024 10.0
# Average return training: 23.9
# 117 0.9018999999999019 15.0
# Average return training: 23.84
# 118 0.9011439999999011 21.0
# Average return training: 23.88
# 119 0.9006759999999007 13.0
# Average return training: 23.83
# 120 0.9000639999999 17.0
# Average return training: 23.82
# 121 0.8996319999998996 12.0
# Average return training: 23.64
# 122 0.8988039999998988 23.0
# Average return training: 23.71
# 123 0.8968239999998968 55.0
# Average return training: 23.85
# 124 0.8956359999998956 33.0
# Average return training: 24.01
# 125 0.8944839999998945 32.0
# Average return training: 24.07
# 126 0.8932599999998933 34.0
# Average return training: 24.26
# 127 0.8927919999998928 13.0
# Average return training: 24.24
# 128 0.8921799999998922 17.0
# Average return training: 24.25
# Average return over 25 episodes of playing: 396.24
# 129 0.8914599999998915 20.0
# Average return training: 24.15
# 130 0.8910999999998911 10.0
# Average return training: 24.03
# 131 0.8902719999998903 23.0
# Average return training: 23.92
# 132 0.8898399999998898 12.0
# Average return training: 23.76
# 133 0.8893359999998893 14.0
# Average return training: 23.78
# 134 0.8887599999998888 16.0
# Average return training: 23.48
# 135 0.887967999999888 22.0
# Average return training: 23.11
# 136 0.8864199999998864 43.0
# Average return training: 23.39
# 137 0.8853759999998854 29.0
# Average return training: 23.57
# 138 0.8845839999998846 22.0
# Average return training: 23.59
# 139 0.8838639999998839 20.0
# Average return training: 23.63
# 140 0.8831079999998831 21.0
# Average return training: 23.62
# 141 0.8818839999998819 34.0
# Average return training: 23.72
# 142 0.8812359999998812 18.0
# Average return training: 23.7
# 143 0.8801559999998801 30.0
# Average return training: 23.62
# 144 0.8793999999998794 21.0
# Average return training: 23.45
# 145 0.878967999999879 12.0
# Average return training: 23.29
# 146 0.8778159999998778 32.0
# Average return training: 23.46
# 147 0.8774919999998775 9.0
# Average return training: 23.42
# 148 0.8771319999998771 10.0
# Average return training: 23.41
# 149 0.8767359999998767 11.0
# Average return training: 22.99
# 150 0.876051999999876 19.0
# Average return training: 22.88
# 151 0.8755839999998756 13.0
# Average return training: 22.82
# 152 0.8751879999998752 11.0
# Average return training: 22.72
# 153 0.8742519999998742 26.0
# Average return training: 22.75
# Average return over 25 episodes of playing: 396.72
# 154 0.8716959999998717 71.0
# Average return training: 22.94
# 155 0.8705079999998705 33.0
# Average return training: 23.12
# 156 0.8701479999998701 10.0
# Average return training: 23.06
# 157 0.8692839999998693 24.0
# Average return training: 23.04
# 158 0.8683479999998683 26.0
# Average return training: 23.1
# 159 0.8679519999998679 11.0
# Average return training: 23.09
# 160 0.8674119999998674 15.0
# Average return training: 23.01
# 161 0.8666199999998666 22.0
# Average return training: 23.06
# 162 0.8661519999998661 13.0
# Average return training: 22.99
# 163 0.8656119999998656 15.0
# Average return training: 23.04
# 164 0.8642439999998642 38.0
# Average return training: 23.18
# 165 0.8638479999998638 11.0
# Average return training: 22.87
# 166 0.8634519999998634 11.0
# Average return training: 22.81
# 167 0.8621559999998621 36.0
# Average return training: 23.03
# 168 0.8617959999998618 10.0
# Average return training: 22.96
# 169 0.8611479999998611 18.0
# Average return training: 22.82
# 170 0.8607519999998607 11.0
# Average return training: 22.8
# 171 0.8601759999998602 16.0
# Average return training: 22.7
# 172 0.8595279999998595 18.0
# Average return training: 22.73
# 173 0.8584839999998585 29.0
# Average return training: 22.67
# 174 0.858051999999858 12.0
# Average return training: 22.4
# 175 0.8570799999998571 27.0
# Average return training: 22.13
# Average return over 25 episodes of playing: 90.56
# 176 0.8555679999998556 42.0
# Average return training: 22.23
# 177 0.8551719999998552 11.0
# Average return training: 21.7
# 178 0.8538759999998539 36.0
# Average return training: 21.95
# 179 0.8533719999998534 14.0
# Average return training: 21.79
# 180 0.8521839999998522 33.0
# Average return training: 21.89
# 181 0.8511399999998511 29.0
# Average return training: 21.99
# 182 0.8505639999998506 16.0
# Average return training: 21.78
# 183 0.8492319999998492 37.0
# Average return training: 21.81
# 184 0.8484399999998484 22.0
# Average return training: 21.91
# 185 0.8467839999998468 46.0
# Average return training: 22.16
# 186 0.8460999999998461 19.0
# Average return training: 22.09
# 187 0.8454159999998454 19.0
# Average return training: 22.1
# 188 0.8445519999998445 24.0
# Average return training: 22.16
# 189 0.8438319999998438 20.0
# Average return training: 22.21
# 190 0.8434719999998435 10.0
# Average return training: 22.17
# 191 0.8423919999998424 30.0
# Average return training: 22.29
# 192 0.8415279999998415 24.0
# Average return training: 22.25
# 193 0.8406639999998406 24.0
# Average return training: 22.35
# 194 0.8393319999998393 37.0
# Average return training: 22.6
# 195 0.838035999999838 36.0
# Average return training: 22.59
# Average return over 25 episodes of playing: 33.56
# 196 0.8374959999998375 15.0
# Average return training: 22.62
# 197 0.8368839999998369 17.0
# Average return training: 22.66
# 198 0.8360919999998361 22.0
# Average return training: 22.52
# 199 0.8356599999998356 12.0
# Average return training: 22.17
# 200 0.8346879999998347 27.0
# Average return training: 22.19
# 201 0.8341119999998341 16.0
# Average return training: 22.2
# 202 0.8337159999998337 11.0
# Average return training: 22.02
# 203 0.832995999999833 20.0
# Average return training: 22.1
# 204 0.8318439999998318 32.0
# Average return training: 22.26
# 205 0.8311599999998311 19.0
# Average return training: 22.32
# 206 0.8306199999998306 15.0
# Average return training: 22.17
# 207 0.8300799999998301 15.0
# Average return training: 22.08
# 208 0.8296479999998296 12.0
# Average return training: 22.07
# 209 0.8282079999998282 40.0
# Average return training: 22.11
# 210 0.8274519999998274 21.0
# Average return training: 22.11
# 211 0.8269479999998269 14.0
# Average return training: 22.1
# 212 0.826047999999826 25.0
# Average return training: 21.79
# 213 0.8252919999998253 21.0
# Average return training: 21.84
# 214 0.8248239999998248 13.0
# Average return training: 21.85
# 215 0.824067999999824 21.0
# Average return training: 21.87
# 216 0.8235999999998236 13.0
# Average return training: 21.9
# 217 0.8225919999998226 28.0
# Average return training: 22.03
# 218 0.8219079999998219 19.0
# Average return training: 22.01
# 219 0.8214759999998215 12.0
# Average return training: 22.0
# Average return over 25 episodes of playing: 71.8
# 220 0.8197479999998197 48.0
# Average return training: 22.31
# 221 0.8189559999998189 22.0
# Average return training: 22.41
# 222 0.8182359999998182 20.0
# Average return training: 22.38
# 223 0.8176239999998176 17.0
# Average return training: 22.0
# 224 0.816975999999817 18.0
# Average return training: 21.85
# 225 0.8161839999998162 22.0
# Average return training: 21.75
# 226 0.8152839999998153 25.0
# Average return training: 21.66
# 227 0.8140959999998141 33.0
# Average return training: 21.86
# 228 0.8136279999998136 13.0
# Average return training: 21.82
# 229 0.8124039999998124 34.0
# Average return training: 21.96
# 230 0.810963999999811 40.0
# Average return training: 22.26
# 231 0.8085159999998085 68.0
# Average return training: 22.71
# 232 0.8059239999998059 72.0
# Average return training: 23.31
# 233 0.8051679999998052 21.0
# Average return training: 23.38
# 234 0.8035839999998036 44.0
# Average return training: 23.66
# 235 0.8029359999998029 18.0
# Average return training: 23.62
# Average return over 25 episodes of playing: 78.04
# 236 0.8004159999998004 70.0
# Average return training: 23.89
# 237 0.7999479999997999 13.0
# Average return training: 23.73
# 238 0.797031999999797 81.0
# Average return training: 24.32
# 239 0.7964199999997964 17.0
# Average return training: 24.29
# 240 0.7955559999997955 24.0
# Average return training: 24.32
# 241 0.7951239999997951 12.0
# Average return training: 24.1
# 242 0.7938999999997939 34.0
# Average return training: 24.26
# 243 0.7933959999997934 14.0
# Average return training: 24.1
# 244 0.7921719999997922 34.0
# Average return training: 24.23
# 245 0.7893639999997893 78.0
# Average return training: 24.89
# 246 0.789003999999789 10.0
# Average return training: 24.67
# 247 0.7886799999997887 9.0
# Average return training: 24.67
# 248 0.7879599999997879 20.0
# Average return training: 24.77
# 249 0.7863039999997863 46.0
# Average return training: 25.12
# 250 0.7857999999997858 14.0
# Average return training: 25.07
# 251 0.7848639999997848 26.0
# Average return training: 25.2
# Average return over 25 episodes of playing: 97.04
# 252 0.7819119999997819 82.0
# Average return training: 25.91
# 253 0.7807239999997807 33.0
# Average return training: 25.98
# 254 0.7771599999997771 99.0
# Average return training: 26.26
# 255 0.7767999999997768 10.0
# Average return training: 26.03
# 256 0.7763679999997763 12.0
# Average return training: 26.05
# 257 0.7758279999997758 15.0
# Average return training: 25.96
# 258 0.7751079999997751 20.0
# Average return training: 25.9
# 259 0.7737399999997737 38.0
# Average return training: 26.17
# 260 0.7728039999997728 26.0
# Average return training: 26.28
# 261 0.7721199999997721 19.0
# Average return training: 26.25
# 262 0.7713639999997713 21.0
# Average return training: 26.33
# 263 0.7707879999997708 16.0
# Average return training: 26.34
# 264 0.77006799999977 20.0
# Average return training: 26.16
# 265 0.7693119999997693 21.0
# Average return training: 26.26
# 266 0.7689159999997689 11.0
# Average return training: 26.26
# 267 0.7683759999997684 15.0
# Average return training: 26.05
# 268 0.7668639999997668 42.0
# Average return training: 26.37
# 269 0.7662879999997663 16.0
# Average return training: 26.35
# Average return over 25 episodes of playing: 105.24
# 270 0.7659279999997659 10.0
# Average return training: 26.34
# 271 0.764991999999765 26.0
# Average return training: 26.44
# 272 0.7640919999997641 25.0
# Average return training: 26.51
# 273 0.7626519999997626 40.0
# Average return training: 26.62
# 274 0.7618959999997619 21.0
# Average return training: 26.71
# 275 0.7614639999997614 12.0
# Average return training: 26.56
# 276 0.7608879999997609 16.0
# Average return training: 26.3
# 277 0.7603479999997603 15.0
# Average return training: 26.34
# 278 0.7595199999997595 23.0
# Average return training: 26.21
# 279 0.7587999999997588 20.0
# Average return training: 26.27
# 280 0.7582239999997582 16.0
# Average return training: 26.1
# 281 0.7563879999997564 51.0
# Average return training: 26.32
# 282 0.7552719999997553 31.0
# Average return training: 26.47
# 283 0.7548759999997549 11.0
# Average return training: 26.21
# 284 0.7541199999997541 21.0
# Average return training: 26.2
# 285 0.7533279999997533 22.0
# Average return training: 25.96
# 286 0.7527159999997527 17.0
# Average return training: 25.94
# 287 0.7506999999997507 56.0
# Average return training: 26.31
# 288 0.75001599999975 19.0
# Average return training: 26.26
# 289 0.7495119999997495 14.0
# Average return training: 26.2
# 290 0.7490799999997491 12.0
# Average return training: 26.22
# 291 0.7482519999997482 23.0
# Average return training: 26.15
# Average return over 25 episodes of playing: 102.24
# 292 0.7459479999997459 64.0
# Average return training: 26.55
# 293 0.7455879999997456 10.0
# Average return training: 26.41
# 294 0.7444359999997444 32.0
# Average return training: 26.36
# 295 0.743031999999743 39.0
# Average return training: 26.39
# 296 0.7415559999997415 41.0
# Average return training: 26.65
# 297 0.7404759999997405 30.0
# Average return training: 26.78
# 298 0.7398639999997398 17.0
# Average return training: 26.73
# 299 0.7391079999997391 21.0
# Average return training: 26.82
# 300 0.7382799999997383 23.0
# Average return training: 26.78
# 301 0.7377759999997378 14.0
# Average return training: 26.76
# 302 0.7373799999997374 11.0
# Average return training: 26.76
# 303 0.7364799999997365 25.0
# Average return training: 26.81
# 304 0.735975999999736 14.0
# Average return training: 26.63
# 305 0.7355439999997355 12.0
# Average return training: 26.56
# 306 0.7351119999997351 12.0
# Average return training: 26.53
# 307 0.7344639999997344 18.0
# Average return training: 26.56
# 308 0.734067999999734 11.0
# Average return training: 26.55
# 309 0.7327719999997327 36.0
# Average return training: 26.51
# 310 0.7305759999997306 61.0
# Average return training: 26.91
# 311 0.7301079999997301 13.0
# Average return training: 26.9
# Average return over 25 episodes of playing: 55.48
# 312 0.729063999999729 29.0
# Average return training: 26.94
# 313 0.7285599999997285 14.0
# Average return training: 26.87
# 314 0.7281639999997281 11.0
# Average return training: 26.85
# 315 0.7275159999997275 18.0
# Average return training: 26.82
# 316 0.726975999999727 15.0
# Average return training: 26.84
# 317 0.7252119999997252 49.0
# Average return training: 27.05
# 318 0.7247439999997247 13.0
# Average return training: 26.99
# 319 0.7234119999997234 37.0
# Average return training: 27.24
# 320 0.7229439999997229 13.0
# Average return training: 26.89
# 321 0.7221519999997221 22.0
# Average return training: 26.89
# 322 0.7216119999997216 15.0
# Average return training: 26.84
# 323 0.72006399999972 43.0
# Average return training: 27.1
# 324 0.7196319999997196 12.0
# Average return training: 27.04
# 325 0.7191999999997192 12.0
# Average return training: 26.94
# 326 0.7184439999997184 21.0
# Average return training: 26.9
# 327 0.7177599999997177 19.0
# Average return training: 26.76
# 328 0.7153119999997153 68.0
# Average return training: 27.31
# 329 0.7139079999997139 39.0
# Average return training: 27.36
# Average return over 25 episodes of playing: 80.24
# 330 0.7112439999997112 74.0
# Average return training: 27.7
# 331 0.7095879999997096 46.0
# Average return training: 27.48
# 332 0.709011999999709 16.0
# Average return training: 26.92
# 333 0.7086159999997086 11.0
# Average return training: 26.82
# 334 0.7077519999997077 24.0
# Average return training: 26.62
# 335 0.7059159999997059 51.0
# Average return training: 26.95
# 336 0.7051959999997052 20.0
# Average return training: 26.45
# 337 0.7042599999997042 26.0
# Average return training: 26.58
# 338 0.7025319999997025 48.0
# Average return training: 26.25
# 339 0.7019559999997019 16.0
# Average return training: 26.24
# 340 0.7005519999997005 39.0
# Average return training: 26.39
# 341 0.7000119999997 15.0
# Average return training: 26.42
# 342 0.6993279999996993 19.0
# Average return training: 26.27
# 343 0.6984639999996984 24.0
# Average return training: 26.37
# 344 0.6975999999996976 24.0
# Average return training: 26.27
# 345 0.6968439999996968 21.0
# Average return training: 25.7
# 346 0.6958359999996958 28.0
# Average return training: 25.88
# 347 0.6947559999996947 30.0
# Average return training: 26.09
# 348 0.6943599999996943 11.0
# Average return training: 26.0
# Average return over 25 episodes of playing: 98.84
# 349 0.6937479999996937 17.0
# Average return training: 25.71
# 350 0.6915879999996916 60.0
# Average return training: 26.17
# 351 0.6908679999996908 20.0
# Average return training: 26.11
# 352 0.6888519999996888 56.0
# Average return training: 25.85
# 353 0.6866919999996867 60.0
# Average return training: 26.12
# 354 0.6861159999996861 16.0
# Average return training: 25.29
# 355 0.6849279999996849 33.0
# Average return training: 25.52
# 356 0.6839199999996839 28.0
# Average return training: 25.68
# 357 0.6813279999996813 72.0
# Average return training: 26.25
# 358 0.6808599999996808 13.0
# Average return training: 26.18
# 359 0.6798159999996798 29.0
# Average return training: 26.09
# 360 0.6788079999996788 28.0
# Average return training: 26.11
# 361 0.6773319999996773 41.0
# Average return training: 26.33
# 362 0.6761439999996761 33.0
# Average return training: 26.45
# Average return over 25 episodes of playing: 66.24
# 363 0.6756759999996756 13.0
# Average return training: 26.42
# 364 0.6751719999996751 14.0
# Average return training: 26.36
# 365 0.673983999999674 33.0
# Average return training: 26.48
# 366 0.672039999999672 54.0
# Average return training: 26.91
# 367 0.6702399999996702 50.0
# Average return training: 27.26
# 368 0.6693759999996693 24.0
# Average return training: 27.08
# 369 0.6645879999996646 133.0
# Average return training: 28.25
# 370 0.663003999999663 44.0
# Average return training: 28.59
# 371 0.6625719999996625 12.0
# Average return training: 28.45
# 372 0.6614559999996614 31.0
# Average return training: 28.51
# 373 0.6608439999996608 17.0
# Average return training: 28.28
# 374 0.6591519999996591 47.0
# Average return training: 28.54
# 375 0.6583239999996583 23.0
# Average return training: 28.65
# Average return over 25 episodes of playing: 98.36
# 376 0.6576759999996576 18.0
# Average return training: 28.67
# 377 0.6569559999996569 20.0
# Average return training: 28.72
# 378 0.6564159999996564 15.0
# Average return training: 28.64
# 379 0.6556239999996556 22.0
# Average return training: 28.66
# 380 0.6545799999996545 29.0
# Average return training: 28.79
# 381 0.6511599999996511 95.0
# Average return training: 29.23
# 382 0.6506199999996506 15.0
# Average return training: 29.07
# 383 0.6487479999996487 52.0
# Average return training: 29.48
# 384 0.648063999999648 19.0
# Average return training: 29.46
# 385 0.6474879999996475 16.0
# Average return training: 29.4
# 386 0.6465519999996465 26.0
# Average return training: 29.49
# 387 0.6457599999996457 22.0
# Average return training: 29.15
# 388 0.645039999999645 20.0
# Average return training: 29.16
# 389 0.6426279999996426 67.0
# Average return training: 29.69
# 390 0.6403959999996404 62.0
# Average return training: 30.19
# Average return over 25 episodes of playing: 108.6
# 391 0.6364719999996364 109.0
# Average return training: 31.05
# 392 0.6356799999996356 22.0
# Average return training: 30.63
# 393 0.6348879999996349 22.0
# Average return training: 30.75
# 394 0.6324759999996324 67.0
# Average return training: 31.1
# 395 0.6297039999996297 77.0
# Average return training: 31.48
# 396 0.6281559999996281 43.0
# Average return training: 31.5
# 397 0.6271839999996272 27.0
# Average return training: 31.47
# 398 0.6263919999996264 22.0
# Average return training: 31.52
# 399 0.6245199999996245 52.0
# Average return training: 31.83
# 400 0.624087999999624 12.0
# Average return training: 31.72
# 401 0.623043999999623 29.0
# Average return training: 31.87
# 402 0.6222519999996222 22.0
# Average return training: 31.98
# Average return over 25 episodes of playing: 126.44
# 403 0.6212799999996212 27.0
# Average return training: 32.0
# 404 0.6207399999996207 15.0
# Average return training: 32.01
# 405 0.6177159999996177 84.0
# Average return training: 32.73
# 406 0.6168159999996168 25.0
# Average return training: 32.86
# 407 0.615987999999616 23.0
# Average return training: 32.91
# 408 0.6131439999996131 79.0
# Average return training: 33.59
# 409 0.611019999999611 59.0
# Average return training: 33.82
# 410 0.6105159999996105 14.0
# Average return training: 33.35
# 411 0.6087159999996087 50.0
# Average return training: 33.72
# 412 0.6072039999996072 42.0
# Average return training: 33.85
# 413 0.6064479999996064 21.0
# Average return training: 33.92
# 414 0.6047559999996047 47.0
# Average return training: 34.28
# 415 0.6043599999996043 11.0
# Average return training: 34.21
# Average return over 25 episodes of playing: 355.4
# 416 0.6033519999996033 28.0
# Average return training: 34.34
# 417 0.6018399999996018 42.0
# Average return training: 34.27
# 418 0.5993919999995994 68.0
# Average return training: 34.82
# 419 0.5985279999995985 24.0
# Average return training: 34.69
# 420 0.5976639999995976 24.0
# Average return training: 34.8
# 421 0.5971959999995972 13.0
# Average return training: 34.71
# 422 0.5958999999995959 36.0
# Average return training: 34.92
# 423 0.5949279999995949 27.0
# Average return training: 34.76
# 424 0.5942799999995942 18.0
# Average return training: 34.82
# 425 0.5936319999995936 18.0
# Average return training: 34.88
# 426 0.5906079999995906 84.0
# Average return training: 35.51
# 427 0.5899239999995899 19.0
# Average return training: 35.51
# 428 0.5887359999995887 33.0
# Average return training: 35.16
# 429 0.5879079999995879 23.0
# Average return training: 35.0
# 430 0.5871159999995871 22.0
# Average return training: 34.48
# Average return over 25 episodes of playing: 110.72
# 431 0.5853879999995854 48.0
# Average return training: 34.5
# 432 0.5825799999995825 78.0
# Average return training: 35.12
# 433 0.5822559999995822 9.0
# Average return training: 35.1
# 434 0.5808519999995808 39.0
# Average return training: 35.25
# 435 0.5803839999995803 13.0
# Average return training: 34.87
# 436 0.5787999999995788 44.0
# Average return training: 35.11
# 437 0.5766399999995766 60.0
# Average return training: 35.45
# 438 0.5755959999995756 29.0
# Average return training: 35.26
# 439 0.5728239999995728 77.0
# Average return training: 35.87
# 440 0.5722479999995722 16.0
# Average return training: 35.64
# 441 0.5701959999995702 57.0
# Average return training: 36.06
# 442 0.5692239999995692 27.0
# Average return training: 36.14
# 443 0.5684679999995684 21.0
# Average return training: 36.11
# Average return over 25 episodes of playing: 81.24
# 444 0.5672439999995672 34.0
# Average return training: 36.21
# 445 0.5666319999995666 17.0
# Average return training: 36.17
# 446 0.5659119999995659 20.0
# Average return training: 36.09
# 447 0.5625999999995626 92.0
# Average return training: 36.71
# 448 0.5608359999995608 49.0
# Average return training: 37.09
# 449 0.5601879999995601 18.0
# Average return training: 37.1
# 450 0.5594319999995594 21.0
# Average return training: 36.71
# 451 0.5589279999995589 14.0
# Average return training: 36.65
# 452 0.5571279999995571 50.0
# Average return training: 36.59
# 453 0.5555799999995555 43.0
# Average return training: 36.42
# 454 0.5538519999995538 48.0
# Average return training: 36.74
# 455 0.5526639999995526 33.0
# Average return training: 36.74
# 456 0.5517639999995517 25.0
# Average return training: 36.71
# 457 0.5508999999995509 24.0
# Average return training: 36.23
# 458 0.5505039999995505 11.0
# Average return training: 36.21
# Average return over 25 episodes of playing: 138.36
# 459 0.5491359999995491 38.0
# Average return training: 36.3
# 460 0.5474439999995474 47.0
# Average return training: 36.49
# 461 0.5446359999995446 78.0
# Average return training: 36.86
# 462 0.544095999999544 15.0
# Average return training: 36.68
# 463 0.5434479999995434 18.0
# Average return training: 36.73
# 464 0.5425479999995425 25.0
# Average return training: 36.84
# 465 0.5418999999995419 18.0
# Average return training: 36.69
# 466 0.5412519999995412 18.0
# Average return training: 36.33
# 467 0.5401719999995401 30.0
# Average return training: 36.13
# 468 0.5392719999995392 25.0
# Average return training: 36.14
# 469 0.5389479999995389 9.0
# Average return training: 34.9
# 470 0.538047999999538 25.0
# Average return training: 34.71
# 471 0.5376519999995376 11.0
# Average return training: 34.7
# 472 0.5341599999995341 97.0
# Average return training: 35.36
# 473 0.5337279999995337 12.0
# Average return training: 35.31
# 474 0.5323959999995324 37.0
# Average return training: 35.21
# Average return over 25 episodes of playing: 77.96
# 475 0.5294439999995294 82.0
# Average return training: 35.8
# 476 0.5289759999995289 13.0
# Average return training: 35.75
# 477 0.5283639999995283 17.0
# Average return training: 35.72
# 478 0.5278239999995278 15.0
# Average return training: 35.72
# 479 0.5268159999995268 28.0
# Average return training: 35.78
# 480 0.5258439999995258 27.0
# Average return training: 35.76
# 481 0.5248719999995248 27.0
# Average return training: 35.08
# 482 0.5244039999995244 13.0
# Average return training: 35.06
# 483 0.5238279999995238 16.0
# Average return training: 34.7
# 484 0.5232879999995232 15.0
# Average return training: 34.66
# 485 0.5226399999995226 18.0
# Average return training: 34.68
# 486 0.5213799999995213 35.0
# Average return training: 34.77
# 487 0.5209119999995209 13.0
# Average return training: 34.68
# 488 0.5205519999995205 10.0
# Average return training: 34.58
# 489 0.5196159999995196 26.0
# Average return training: 34.17
# 490 0.519039999999519 16.0
# Average return training: 33.71
# 491 0.5186439999995186 11.0
# Average return training: 32.73
# 492 0.5178519999995178 22.0
# Average return training: 32.73
# 493 0.5169159999995169 26.0
# Average return training: 32.77
# 494 0.516087999999516 23.0
# Average return training: 32.33
# 495 0.5154759999995154 17.0
# Average return training: 31.73
# Average return over 25 episodes of playing: 86.28
# 496 0.5135679999995135 53.0
# Average return training: 31.83
# 497 0.5124159999995124 32.0
# Average return training: 31.88
# 498 0.5114439999995114 27.0
# Average return training: 31.93
# 499 0.5091399999995091 64.0
# Average return training: 32.05
# 500 0.5086359999995086 14.0
# Average return training: 32.07
# 501 0.5083119999995083 9.0
# Average return training: 31.87
# 502 0.5074479999995074 24.0
# Average return training: 31.89
# 503 0.5065479999995065 25.0
# Average return training: 31.87
# 504 0.5047839999995047 49.0
# Average return training: 32.21
# 505 0.5035959999995036 33.0
# Average return training: 31.7
# 506 0.5003919999995003 89.0
# Average return training: 32.34
# 507 0.4997799999995001 17.0
# Average return training: 32.28
# 508 0.4989519999995006 23.0
# Average return training: 31.72
# 509 0.4976559999995013 36.0
# Average return training: 31.49
# Average return over 25 episodes of playing: 103.32
# 510 0.49567599999950235 55.0
# Average return training: 31.9
# 511 0.4937319999995034 54.0
# Average return training: 31.94
# 512 0.4932279999995037 14.0
# Average return training: 31.66
# 513 0.492651999999504 16.0
# Average return training: 31.61
# 514 0.4919319999995044 20.0
# Average return training: 31.34
# 515 0.49088799999950494 29.0
# Average return training: 31.52
# 516 0.4904559999995052 12.0
# Average return training: 31.36
# 517 0.4898439999995055 17.0
# Average return training: 31.11
# 518 0.48775599999950664 58.0
# Average return training: 31.01
# 519 0.48721599999950693 15.0
# Average return training: 30.92
# 520 0.4868559999995071 10.0
# Average return training: 30.78
# 521 0.4861359999995075 20.0
# Average return training: 30.85
# 522 0.4854159999995079 20.0
# Average return training: 30.69
# 523 0.48386799999950875 43.0
# Average return training: 30.85
# 524 0.48332799999950904 15.0
# Average return training: 30.82
# 525 0.4817079999995099 45.0
# Average return training: 31.09
# 526 0.48069999999951046 28.0
# Average return training: 30.53
# Average return over 25 episodes of playing: 115.04
# 527 0.4767759999995126 109.0
# Average return training: 31.43
# 528 0.4763439999995128 12.0
# Average return training: 31.22
# 529 0.4754799999995133 24.0
# Average return training: 31.23
# 530 0.4733919999995144 58.0
# Average return training: 31.59
# 531 0.47277999999951476 17.0
# Average return training: 31.28
# 532 0.47076399999951585 56.0
# Average return training: 31.06
# 533 0.47018799999951616 16.0
# Average return training: 31.13
# 534 0.46889199999951686 36.0
# Average return training: 31.1
# 535 0.46467999999951914 117.0
# Average return training: 32.14
# 536 0.4639959999995195 19.0
# Average return training: 31.89
# 537 0.4603239999995215 102.0
# Average return training: 32.31
# Average return over 25 episodes of playing: 114.92
# 538 0.45621999999952373 114.0
# Average return training: 33.16
# 539 0.45578799999952396 12.0
# Average return training: 32.51
# 540 0.45413199999952486 46.0
# Average return training: 32.81
# 541 0.4503519999995269 105.0
# Average return training: 33.29
# 542 0.44642799999952903 109.0
# Average return training: 34.11
# 543 0.4424679999995312 110.0
# Average return training: 35.0
# Average return over 25 episodes of playing: 109.52
# 544 0.4400199999995325 68.0
# Average return training: 35.34
# 545 0.43573599999953483 119.0
# Average return training: 36.36
# 546 0.4352679999995351 13.0
# Average return training: 36.29
# 547 0.4332519999995362 56.0
# Average return training: 35.93
# 548 0.42957999999953816 102.0
# Average return training: 36.46
# 549 0.4246839999995408 136.0
# Average return training: 37.64
# 550 0.42403599999954117 18.0
# Average return training: 37.61
# Average return over 25 episodes of playing: 500.0
# 551 0.4234239999995415 17.0
# Average return training: 37.64
# 552 0.42205599999954224 38.0
# Average return training: 37.52
# 553 0.4203279999995432 48.0
# Average return training: 37.57
# 554 0.4197159999995435 17.0
# Average return training: 37.26
# 555 0.4186719999995441 29.0
# Average return training: 37.22
# 556 0.41672799999954513 54.0
# Average return training: 37.51
# 557 0.4147479999995462 55.0
# Average return training: 37.82
# 558 0.41204799999954766 75.0
# Average return training: 38.46
# 559 0.41024799999954864 50.0
# Average return training: 38.58
# 560 0.40823199999954973 56.0
# Average return training: 38.67
# Average return over 25 episodes of playing: 86.52
# 561 0.40596399999955096 63.0
# Average return training: 38.52
# 562 0.40545999999955123 14.0
# Average return training: 38.51
# 563 0.40373199999955217 48.0
# Average return training: 38.81
# 564 0.40322799999955244 14.0
# Average return training: 38.7
# 565 0.39825999999955514 138.0
# Average return training: 39.9
# 566 0.3952359999995568 84.0
# Average return training: 40.56
# 567 0.3902319999995595 139.0
# Average return training: 41.65
# 568 0.3882159999995606 56.0
# Average return training: 41.96
# Average return over 25 episodes of playing: 396.92
# 569 0.38753199999956095 19.0
# Average return training: 42.06
# 570 0.3824199999995637 142.0
# Average return training: 43.23
# 571 0.380043999999565 66.0
# Average return training: 43.78
# 572 0.37424799999956815 161.0
# Average return training: 44.42
# Average return over 25 episodes of playing: 287.6
# 573 0.3667239999995722 209.0
# Average return training: 46.39
# 574 0.36614799999957254 16.0
# Average return training: 46.18
# 575 0.36297999999957425 88.0
# Average return training: 46.24
# 576 0.35675199999957763 173.0
# Average return training: 47.84
# Average return over 25 episodes of playing: 165.72
# 577 0.34674399999958305 278.0
# Average return training: 50.45
# 578 0.3439359999995846 78.0
# Average return training: 51.08
# 579 0.33583599999958896 225.0
# Average return training: 53.05
# Average return over 25 episodes of playing: 500.0
# 580 0.33029199999959197 154.0
# Average return training: 54.32
# 581 0.3243159999995952 166.0
# Average return training: 55.71
# Average return over 25 episodes of playing: 500.0
# 582 0.3095199999996032 411.0
# Average return training: 59.69
# Average return over 25 episodes of playing: 500.0
# 583 0.29677599999961013 354.0
# Average return training: 63.07
# 584 0.2842479999996169 348.0
# Average return training: 66.4
# Average return over 25 episodes of playing: 500.0
# 585 0.26624799999962667 500.0
# Average return training: 71.22
# 586 0.2658159999996269 12.0
# Average return training: 70.99
# Average return over 25 episodes of playing: 71.4
# 587 0.2615679999996292 118.0
# Average return training: 72.04
# 588 0.25893999999963063 73.0
# Average return training: 72.67
# 589 0.2584719999996309 13.0
# Average return training: 72.54
# 590 0.25800399999963114 13.0
# Average return training: 72.51
# 591 0.2574999999996314 14.0
# Average return training: 72.54
# 592 0.2571399999996316 10.0
# Average return training: 72.42
# 593 0.256419999999632 20.0
# Average return training: 72.36
# 594 0.2553399999996326 30.0
# Average return training: 72.43
# 595 0.254583999999633 21.0
# Average return training: 72.47
# 596 0.2540079999996333 16.0
# Average return training: 72.1
# 597 0.25357599999963354 12.0
# Average return training: 71.9
# 598 0.2528919999996339 19.0
# Average return training: 71.82
# 599 0.25188399999963446 28.0
# Average return training: 71.46
# 600 0.250911999999635 27.0
# Average return training: 71.59
# 601 0.2471319999996348 105.0
# Average return training: 72.55
# 602 0.2462319999996346 25.0
# Average return training: 72.56
# 603 0.24511599999963435 31.0
# Average return training: 72.62
# 604 0.24453999999963422 16.0
# Average return training: 72.29
# Average return over 25 episodes of playing: 105.48
# 605 0.24083199999963337 103.0
# Average return training: 72.99
# 606 0.2396079999996331 34.0
# Average return training: 72.44
# 607 0.23539599999963212 117.0
# Average return training: 73.44
# 608 0.230535999999631 135.0
# Average return training: 74.56
# 609 0.22931199999963073 34.0
# Average return training: 74.54
# 610 0.2274399999996303 52.0
# Average return training: 74.51
# Average return over 25 episodes of playing: 180.4
# 611 0.22387599999962948 99.0
# Average return training: 74.96
# 612 0.22250799999962917 38.0
# Average return training: 75.2
# 613 0.22157199999962895 26.0
# Average return training: 75.3
# 614 0.21163599999962668 276.0
# Average return training: 77.86
# Average return over 25 episodes of playing: 131.12
# 615 0.20760399999962575 112.0
# Average return training: 78.69
# 616 0.2017359999996244 163.0
# Average return training: 80.2
# 617 0.2004039999996241 37.0
# Average return training: 80.4
# 618 0.19943199999962388 27.0
# Average return training: 80.09
# 619 0.19532799999962294 114.0
# Average return training: 81.08
# 620 0.19093599999962194 122.0
# Average return training: 82.2
# Average return over 25 episodes of playing: 122.32
# 621 0.18621999999962086 131.0
# Average return training: 83.31
# 622 0.18150399999961978 131.0
# Average return training: 84.42
# 623 0.17664399999961866 135.0
# Average return training: 85.34
# Average return over 25 episodes of playing: 130.4
# 624 0.17192799999961758 131.0
# Average return training: 86.5
# 625 0.1667799999996164 143.0
# Average return training: 87.48
# 626 0.1620279999996153 132.0
# Average return training: 88.52
# 627 0.16163199999961522 11.0
# Average return training: 87.54
# 628 0.1584999999996145 87.0
# Average return training: 88.29
# 629 0.15774399999961433 21.0
# Average return training: 88.26
# Average return over 25 episodes of playing: 131.24
# 630 0.1528479999996132 136.0
# Average return training: 89.04
# 631 0.1479879999996121 135.0
# Average return training: 90.22
# 632 0.143199999999611 133.0
# Average return training: 90.99
# 633 0.13826799999960987 137.0
# Average return training: 92.2
# Average return over 25 episodes of playing: 131.52
# 634 0.1331199999996087 143.0
# Average return training: 93.27
# 635 0.12786399999960749 146.0
# Average return training: 93.56
# 636 0.12257199999960722 147.0
# Average return training: 94.84
# Average return over 25 episodes of playing: 131.16
# 637 0.117531999999608 140.0
# Average return training: 95.22
# 638 0.11238399999960881 143.0
# Average return training: 95.51
# 639 0.10777599999960953 128.0
# Average return training: 96.67
# 640 0.10323999999961024 126.0
# Average return training: 97.47
# Average return over 25 episodes of playing: 129.92
# 641 0.1 119.0
# Average return training: 97.61
# 642 0.1 127.0
# Average return training: 97.79
# 643 0.1 123.0
# Average return training: 97.92
# 644 0.1 32.0
# Average return training: 97.56
# 645 0.1 119.0
# Average return training: 97.56
# Average return over 25 episodes of playing: 111.68
# 646 0.1 103.0
# Average return training: 98.46
# 647 0.1 121.0
# Average return training: 99.11
# 648 0.1 121.0
# Average return training: 99.3
# 649 0.1 12.0
# Average return training: 98.06
# 650 0.1 130.0
# Average return training: 99.18
# Average return over 25 episodes of playing: 120.84
# 651 0.1 139.0
# Average return training: 100.4
# 652 0.1 12.0
# Average return training: 100.14
# 653 0.1 82.0
# Average return training: 100.48
# 654 0.1 129.0
# Average return training: 101.6
# 655 0.1 129.0
# Average return training: 102.6
# Average return over 25 episodes of playing: 136.6
# 656 0.1 134.0
# Average return training: 103.4
# 657 0.1 131.0
# Average return training: 104.16
# 658 0.1 135.0
# Average return training: 104.76
# 659 0.1 130.0
# Average return training: 105.56
# Average return over 25 episodes of playing: 146.88
# 660 0.1 152.0
# Average return training: 106.52
# 661 0.1 142.0
# Average return training: 107.31
# 662 0.1 62.0
# Average return training: 107.79
# 663 0.1 158.0
# Average return training: 108.89
# Average return over 25 episodes of playing: 141.56
# 664 0.1 104.0
# Average return training: 109.79
# 665 0.1 160.0
# Average return training: 110.01
# 666 0.1 182.0
# Average return training: 110.99
# Average return over 25 episodes of playing: 184.84
# 667 0.1 187.0
# Average return training: 111.47
# 668 0.1 179.0
# Average return training: 112.7
# 669 0.1 129.0
# Average return training: 113.8
# Average return over 25 episodes of playing: 234.0
# 670 0.1 120.0
# Average return training: 113.58
# 671 0.1 15.0
# Average return training: 113.07
# 672 0.1 413.0
# Average return training: 115.59
# Average return over 25 episodes of playing: 338.32
# 673 0.1 500.0
# Average return training: 118.5
# 674 0.1 17.0
# Average return training: 118.51
# Average return over 25 episodes of playing: 188.28
# 675 0.1 337.0
# Average return training: 121.0
# 676 0.1 162.0
# Average return training: 120.89
# Average return over 25 episodes of playing: 264.16
# 677 0.1 180.0
# Average return training: 119.91
# 678 0.1 184.0
# Average return training: 120.97
# Average return over 25 episodes of playing: 295.52
# 679 0.1 234.0
# Average return training: 121.06
# 680 0.1 125.0
# Average return training: 120.77
# 681 0.1 165.0
# Average return training: 120.76
# Average return over 25 episodes of playing: 441.56
# 682 0.1 178.0
# Average return training: 118.43
# 683 0.1 254.0
# Average return training: 117.43
# Average return over 25 episodes of playing: 500.0
# 684 0.1 351.0
# Average return training: 117.46
# Average return over 25 episodes of playing: 500.0
# 685 0.1 500.0
# Average return training: 117.46
# 686 0.1 14.0
# Average return training: 117.48
# Average return over 25 episodes of playing: 500.0
# 687 0.1 500.0
# Average return training: 121.3
# Average return over 25 episodes of playing: 500.0
# 688 0.1 500.0
# Average return training: 125.57
# Average return over 100 episodes of trained agent: 500.0
# SEED: 34
# Finishing last run (ID:k85lld9d) before initializing another...
# <br/>Waiting for W&B process to finish, PID 398... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>Average return over 100 episodes of training</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▃▅▅▅▆▇██</td></tr><tr><td>Average return over 25 episodes of playing</td><td>▁▃▂▆▆▁▂▂▂▂▂▂▂▆▂▂▂▂▂█▆▃██▂▂▂▂▂▂▂▂▃▃▄▃▅▇██</td></tr><tr><td>episode</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>Average return over 100 episodes of training</td><td>125.57</td></tr><tr><td>Average return over 25 episodes of playing</td><td>500.0</td></tr><tr><td>episode</td><td>688</td></tr><tr><td>step</td><td>33000</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">fancy-puddle-42</strong>: <a href="https://wandb.ai/raisa/DoubleDQN-CartPole/runs/k85lld9d" target="_blank">https://wandb.ai/raisa/DoubleDQN-CartPole/runs/k85lld9d</a><br/>
# Find logs at: <code>./wandb/run-20220114_195729-k85lld9d/logs</code><br/>
# Successfully finished last run (ID:k85lld9d). Initializing new run:<br/>
#                     Syncing run <strong><a href="https://wandb.ai/raisa/DoubleDQN-CartPole/runs/1fyp5yvt" target="_blank">volcanic-plant-43</a></strong> to <a href="https://wandb.ai/raisa/DoubleDQN-CartPole" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 1 0.9987039999999987 36.0
# 2 0.9977679999999978 26.0
# 3 0.9973359999999973 12.0
# 4 0.9968679999999969 13.0
# 5 0.9951759999999952 47.0
# 6 0.9946719999999947 14.0
# 7 0.9940959999999941 16.0
# 8 0.9934119999999934 19.0
# 9 0.9926559999999927 21.0
# 10 0.992043999999992 17.0
# 11 0.9914679999999915 16.0
# 12 0.990963999999991 14.0
# 13 0.9904959999999905 13.0
# 14 0.9898479999999898 18.0
# 15 0.9878679999999879 55.0
# 16 0.9873639999999874 14.0
# 17 0.9866799999999867 19.0
# 18 0.9850959999999851 44.0
# 19 0.9845919999999846 14.0
# 20 0.9842319999999842 10.0
# 21 0.9834759999999835 21.0
# 22 0.9827919999999828 19.0
# 23 0.9822159999999822 16.0
# Average return over 25 episodes of playing: 23.44
# 24 0.9814239999999814 22.0
# 25 0.9795159999999795 53.0
# 26 0.9788679999999789 18.0
# 27 0.9782559999999783 17.0
# 28 0.9777519999999778 14.0
# 29 0.9771759999999772 16.0
# 30 0.9752679999999753 53.0
# 31 0.9744039999999744 24.0
# 32 0.9738999999999739 14.0
# 33 0.9734319999999734 13.0
# 34 0.9729279999999729 14.0
# 35 0.9723879999999724 15.0
# 36 0.9714159999999714 27.0
# 37 0.9704079999999704 28.0
# 38 0.97001199999997 11.0
# 39 0.9695079999999695 14.0
# 40 0.9690759999999691 12.0
# 41 0.9684999999999685 16.0
# 42 0.9679239999999679 16.0
# 43 0.9673479999999673 16.0
# 44 0.9667359999999667 17.0
# 45 0.9659439999999659 22.0
# 46 0.9654759999999655 13.0
# 47 0.965007999999965 13.0
# 48 0.9644319999999644 16.0
# Average return over 25 episodes of playing: 252.08
# 49 0.9637119999999637 20.0
# 50 0.9631719999999632 15.0
# 51 0.9624519999999624 20.0
# 52 0.9616239999999616 23.0
# 53 0.9608319999999608 22.0
# 54 0.9603639999999604 13.0
# 55 0.9598239999999598 15.0
# 56 0.9588519999999588 27.0
# 57 0.957987999999958 24.0
# 58 0.9574119999999574 16.0
# 59 0.9568719999999569 15.0
# 60 0.9564759999999565 11.0
# 61 0.9558639999999559 17.0
# 62 0.9548919999999549 27.0
# 63 0.9542799999999543 17.0
# 64 0.9528759999999529 39.0
# 65 0.9515079999999515 38.0
# 66 0.9508599999999509 18.0
# 67 0.9502839999999503 16.0
# 68 0.9494199999999494 24.0
# 69 0.9488439999999488 16.0
# 70 0.9484479999999484 11.0
# 71 0.9479439999999479 14.0
# 72 0.9475119999999475 12.0
# 73 0.9465759999999466 26.0
# 74 0.9462159999999462 10.0
# Average return over 25 episodes of playing: 162.96
# 75 0.9455679999999456 18.0
# 76 0.945027999999945 15.0
# 77 0.9438039999999438 34.0
# 78 0.9432639999999433 15.0
# 79 0.9422559999999423 28.0
# 80 0.9418599999999419 11.0
# 81 0.9401679999999402 47.0
# 82 0.9394119999999394 21.0
# 83 0.939015999999939 11.0
# 84 0.9383679999999384 18.0
# 85 0.9361719999999362 61.0
# 86 0.9358119999999358 10.0
# 87 0.9351639999999352 18.0
# 88 0.9347319999999347 12.0
# 89 0.9342999999999343 12.0
# 90 0.9336159999999336 19.0
# 91 0.933039999999933 16.0
# 92 0.9324279999999324 17.0
# 93 0.9318879999999319 15.0
# 94 0.9301599999999302 48.0
# 95 0.9294759999999295 19.0
# 96 0.9282159999999282 35.0
# Average return over 25 episodes of playing: 242.76
# 97 0.927027999999927 33.0
# 98 0.9266319999999266 11.0
# 99 0.9258399999999258 22.0
# 100 0.9253719999999254 13.0
# 101 0.9245079999999245 24.0
# Average return training: 20.61
# 102 0.9233919999999234 31.0
# Average return training: 20.66
# 103 0.9216279999999216 49.0
# Average return training: 21.03
# 104 0.921015999999921 17.0
# Average return training: 21.07
# 105 0.9205119999999205 14.0
# Average return training: 20.74
# 106 0.9193239999999193 33.0
# Average return training: 20.93
# 107 0.9185319999999185 22.0
# Average return training: 20.99
# 108 0.917991999999918 15.0
# Average return training: 20.95
# 109 0.9168039999999168 33.0
# Average return training: 21.07
# 110 0.9163719999999164 12.0
# Average return training: 21.02
# 111 0.9153999999999154 27.0
# Average return training: 21.13
# 112 0.9143919999999144 28.0
# Average return training: 21.27
# 113 0.9138159999999138 16.0
# Average return training: 21.3
# 114 0.9133479999999133 13.0
# Average return training: 21.25
# 115 0.9122679999999123 30.0
# Average return training: 21.0
# 116 0.9117279999999117 15.0
# Average return training: 21.01
# 117 0.9110799999999111 18.0
# Average return training: 21.0
# 118 0.9104679999999105 17.0
# Average return training: 20.73
# Average return over 25 episodes of playing: 308.6
# 119 0.9095319999999095 26.0
# Average return training: 20.85
# 120 0.9081279999999081 39.0
# Average return training: 21.14
# 121 0.9073359999999073 22.0
# Average return training: 21.15
# 122 0.9069399999999069 11.0
# Average return training: 21.07
# 123 0.9056079999999056 37.0
# Average return training: 21.28
# 124 0.9052119999999052 11.0
# Average return training: 21.17
# 125 0.903987999999904 34.0
# Average return training: 20.98
# 126 0.9026919999999027 36.0
# Average return training: 21.16
# 127 0.9017919999999018 25.0
# Average return training: 21.24
# 128 0.9013959999999014 11.0
# Average return training: 21.21
# 129 0.9009279999999009 13.0
# Average return training: 21.18
# 130 0.8999559999999 27.0
# Average return training: 20.92
# 131 0.8993079999998993 18.0
# Average return training: 20.86
# 132 0.8986239999998986 19.0
# Average return training: 20.91
# 133 0.898047999999898 16.0
# Average return training: 20.94
# 134 0.8971839999998972 24.0
# Average return training: 21.04
# 135 0.8964999999998965 19.0
# Average return training: 21.08
# 136 0.8957799999998958 20.0
# Average return training: 21.01
# 137 0.895023999999895 21.0
# Average return training: 20.94
# 138 0.8944479999998944 16.0
# Average return training: 20.99
# 139 0.8937639999998938 19.0
# Average return training: 21.04
# 140 0.8928279999998928 26.0
# Average return training: 21.18
# 141 0.8922519999998922 16.0
# ...
# Average return training: 39.42
# 514 0.5052159999995052 24.0
# Average return training: 39.49
# 515 0.5048919999995048 9.0
# Average return training: 39.16
# 516 0.5042079999995042 19.0
# Average return training: 38.61
# 517 0.5038479999995038 10.0
# Average return training: 38.52
# 518 0.5033799999995033 13.0
# Average return training: 38.29
# 519 0.5022639999995022 31.0
# Average return training: 38.49
# 520 0.5015799999995015 19.0
# Average return training: 38.56
# 521 0.5011119999995011 13.0
# Average return training: 38.47
# 522 0.5006799999995006 12.0
# Average return training: 38.42
# 523 0.49916799999950046 42.0
# Average return training: 38.62
# 524 0.49866399999950073 14.0
# Average return training: 38.65
# Average return over 25 episodes of playing: 95.32
# 525 0.49070799999950504 221.0
# Average return training: 40.65
# 526 0.49031199999950525 11.0
# Average return training: 40.02
# 527 0.4896279999995056 19.0
# Average return training: 40.08
# 528 0.4887639999995061 24.0
# Average return training: 39.38
# 529 0.48843999999950627 9.0
# Average return training: 39.27
# 530 0.4867479999995072 47.0
# Average return training: 39.59
# 531 0.4863519999995074 11.0
# Average return training: 39.54
# 532 0.4828239999995093 98.0
# Average return training: 40.32
# 533 0.47850399999951165 120.0
# Average return training: 41.37
# Average return over 25 episodes of playing: 79.04
# 534 0.47778399999951204 20.0
# Average return training: 41.31
# 535 0.4771719999995124 17.0
# Average return training: 41.35
# 536 0.4767399999995126 12.0
# Average return training: 40.99
# 537 0.47540799999951333 37.0
# Average return training: 40.84
# 538 0.4740039999995141 39.0
# Average return training: 40.39
# 539 0.47259999999951485 39.0
# Average return training: 39.65
# 540 0.4721679999995151 12.0
# Average return training: 38.93
# 541 0.47169999999951534 13.0
# Average return training: 38.67
# 542 0.4676679999995175 112.0
# Average return training: 39.12
# 543 0.46352799999951977 115.0
# Average return training: 40.08
# 544 0.4629519999995201 16.0
# Average return training: 39.93
# 545 0.4617639999995207 33.0
# Average return training: 40.13
# Average return over 25 episodes of playing: 108.92
# 546 0.4579119999995228 107.0
# Average return training: 40.64
# 547 0.4540959999995249 106.0
# Average return training: 41.53
# 548 0.45337599999952527 20.0
# Average return training: 41.62
# 549 0.45287199999952554 14.0
# Average return training: 41.5
# 550 0.45179199999952613 30.0
# Average return training: 41.57
# 551 0.45121599999952644 16.0
# Average return training: 41.59
# 552 0.4505679999995268 18.0
# Average return training: 41.27
# 553 0.450135999999527 12.0
# Average return training: 41.29
# 554 0.4496679999995273 13.0
# Average return training: 41.1
# 555 0.44883999999952773 23.0
# Average return training: 40.55
# 556 0.4485159999995279 9.0
# Average return training: 40.37
# 557 0.4477959999995283 20.0
# Average return training: 40.37
# 558 0.4470759999995287 20.0
# Average return training: 40.35
# 559 0.44642799999952903 18.0
# Average return training: 40.23
# 560 0.4459599999995293 13.0
# Average return training: 40.13
# 561 0.44469999999952997 35.0
# Average return training: 40.33
# 562 0.4441239999995303 16.0
# Average return training: 40.33
# 563 0.44365599999953054 13.0
# Average return training: 40.37
# 564 0.44307999999953085 16.0
# Average return training: 40.35
# Average return over 25 episodes of playing: 101.16
# 565 0.4405599999995322 70.0
# Average return training: 40.82
# 566 0.44009199999953247 13.0
# Average return training: 40.55
# 567 0.43919199999953296 25.0
# Average return training: 40.34
# 568 0.43868799999953323 14.0
# Average return training: 39.77
# 569 0.43753599999953385 32.0
# Average return training: 39.77
# 570 0.4368519999995342 19.0
# Average return training: 39.79
# 571 0.43584399999953477 28.0
# Average return training: 38.84
# 572 0.4324959999995366 93.0
# Average return training: 39.59
# 573 0.42871599999953863 105.0
# Average return training: 40.34
# 574 0.4276359999995392 30.0
# Average return training: 40.21
# 575 0.42720399999953945 12.0
# Average return training: 39.3
# 576 0.42644799999953986 21.0
# Average return training: 38.99
# 577 0.4260519999995401 11.0
# Average return training: 38.98
# Average return over 25 episodes of playing: 105.12
# 578 0.42317199999954164 80.0
# Average return training: 39.65
# 579 0.41928399999954374 108.0
# Average return training: 39.38
# 580 0.41615199999954544 87.0
# Average return training: 39.69
# 581 0.4155399999995458 17.0
# Average return training: 39.45
# 582 0.41499999999954607 15.0
# Average return training: 38.78
# 583 0.4135959999995468 39.0
# Average return training: 38.8
# 584 0.41298399999954716 17.0
# Average return training: 38.7
# 585 0.4125879999995474 11.0
# Average return training: 37.99
# 586 0.41042799999954854 60.0
# Average return training: 37.66
# 587 0.40967199999954895 21.0
# Average return training: 37.66
# 588 0.4089879999995493 19.0
# Average return training: 37.68
# 589 0.4084839999995496 14.0
# Average return training: 37.68
# Average return over 25 episodes of playing: 98.6
# 590 0.40563999999955114 79.0
# Average return training: 37.59
# 591 0.40434399999955184 36.0
# Average return training: 37.8
# 592 0.40394799999955205 11.0
# Average return training: 37.37
# 593 0.4035159999995523 12.0
# Average return training: 37.37
# 594 0.40121199999955354 64.0
# Average return training: 37.71
# 595 0.40059999999955387 17.0
# Average return training: 37.76
# 596 0.39951999999955445 30.0
# Average return training: 37.84
# 597 0.3981879999995552 37.0
# Average return training: 36.6
# 598 0.3976119999995555 16.0
# Average return training: 36.49
# 599 0.3938679999995575 104.0
# Average return training: 36.9
# 600 0.392967999999558 25.0
# Average return training: 36.74
# 601 0.38954799999955986 95.0
# Average return training: 37.45
# Average return over 25 episodes of playing: 99.64
# 602 0.3872799999995611 63.0
# Average return training: 37.89
# 603 0.3838959999995629 94.0
# Average return training: 38.41
# 604 0.38252799999956366 38.0
# Average return training: 37.84
# 605 0.3806199999995647 53.0
# Average return training: 38.25
# 606 0.38011599999956497 14.0
# Average return training: 38.08
# 607 0.3795399999995653 16.0
# Average return training: 38.02
# 608 0.37795599999956614 44.0
# Average return training: 38.04
# 609 0.37680399999956676 32.0
# Average return training: 38.05
# 610 0.37442799999956805 66.0
# Average return training: 38.42
# 611 0.3734199999995686 28.0
# Average return training: 38.22
# 612 0.3730239999995688 11.0
# Average return training: 37.72
# 613 0.3722679999995692 21.0
# Average return training: 37.17
# 614 0.3710439999995699 34.0
# Average return training: 37.27
# Average return over 25 episodes of playing: 95.2
# 615 0.36978399999957057 35.0
# Average return training: 37.53
# 616 0.3685959999995712 33.0
# Average return training: 37.67
# 617 0.3677319999995717 24.0
# Average return training: 37.81
# 618 0.3673359999995719 11.0
# Average return training: 37.79
# 619 0.3629079999995743 123.0
# Average return training: 38.71
# 620 0.3586959999995766 117.0
# Average return training: 39.69
# 621 0.357939999999577 21.0
# Average return training: 39.77
# 622 0.35671599999957765 34.0
# Average return training: 39.99
# Average return over 25 episodes of playing: 310.0
# 623 0.3513159999995806 150.0
# Average return training: 41.07
# 624 0.3383199999995876 361.0
# Average return training: 44.54
# 625 0.33489999999958947 95.0
# Average return training: 43.28
# Average return over 25 episodes of playing: 118.12
# 626 0.33090399999959164 111.0
# Average return training: 44.28
# 627 0.3260079999995943 136.0
# Average return training: 45.45
# 628 0.3198879999995976 170.0
# Average return training: 46.91
# Average return over 25 episodes of playing: 146.44
# 629 0.3023199999996071 488.0
# Average return training: 51.7
# 630 0.3018519999996074 13.0
# Average return training: 51.36
# Average return over 25 episodes of playing: 187.96
# 631 0.28939599999961413 346.0
# Average return training: 54.71
# 632 0.28507599999961647 120.0
# Average return training: 54.93
# 633 0.28457199999961674 14.0
# Average return training: 53.87
# 634 0.280431999999619 115.0
# Average return training: 54.82
# Average return over 25 episodes of playing: 170.96
# 635 0.27996399999961924 13.0
# Average return training: 54.78
# 636 0.2795319999996195 12.0
# Average return training: 54.78
# 637 0.27902799999961975 14.0
# Average return training: 54.55
# 638 0.2784159999996201 17.0
# Average return training: 54.33
# 639 0.27639999999962117 56.0
# Average return training: 54.5
# 640 0.26685999999962634 265.0
# Average return training: 57.03
# 641 0.26595999999962683 25.0
# Average return training: 57.15
# Average return over 25 episodes of playing: 179.88
# 642 0.2593719999996304 183.0
# Average return training: 57.86
# 643 0.2581119999996311 35.0
# Average return training: 57.06
# 644 0.25742799999963145 19.0
# Average return training: 57.09
# 645 0.25688799999963174 15.0
# Average return training: 56.91
# 646 0.2553039999996326 44.0
# Average return training: 56.28
# 647 0.25443999999963307 24.0
# Average return training: 55.46
# 648 0.24702399999963479 206.0
# Average return training: 57.32
# 649 0.24655599999963468 13.0
# Average return training: 57.31
# 650 0.24457599999963422 55.0
# Average return training: 57.56
# Average return over 25 episodes of playing: 364.88
# 651 0.24378399999963404 22.0
# Average return training: 57.62
# 652 0.23906799999963296 131.0
# Average return training: 58.75
# 653 0.2375199999996326 43.0
# Average return training: 59.06
# 654 0.2370879999996325 12.0
# Average return training: 59.05
# Average return over 25 episodes of playing: 329.44
# 655 0.21908799999962839 500.0
# Average return training: 63.82
# 656 0.21811599999962816 27.0
# Average return training: 64.0
# 657 0.21541599999962754 75.0
# Average return training: 64.55
# 658 0.21055599999962643 135.0
# Average return training: 65.7
# 659 0.21012399999962633 12.0
# Average return training: 65.64
# Average return over 25 episodes of playing: 99.8
# 660 0.20637999999962547 104.0
# Average return training: 66.55
# 661 0.2025639999996246 106.0
# Average return training: 67.26
# 662 0.20198799999962447 16.0
# Average return training: 67.26
# 663 0.20144799999962434 15.0
# Average return training: 67.28
# 664 0.20108799999962426 10.0
# Average return training: 67.22
# 665 0.1907199999996219 288.0
# Average return training: 69.4
# Average return over 25 episodes of playing: 167.56
# 666 0.18711999999962106 100.0
# Average return training: 70.27
# 667 0.1816479999996198 152.0
# Average return training: 71.54
# 668 0.17779599999961893 107.0
# Average return training: 72.47
# 669 0.17397999999961805 106.0
# Average return training: 73.21
# Average return over 25 episodes of playing: 102.76
# 670 0.17005599999961715 109.0
# Average return training: 74.11
# 671 0.16494399999961598 142.0
# Average return training: 75.25
# 672 0.16087599999961505 113.0
# Average return training: 75.45
# 673 0.15684399999961413 112.0
# Average return training: 75.52
# Average return over 25 episodes of playing: 107.84
# 674 0.15302799999961325 106.0
# Average return training: 76.28
# 675 0.14877999999961228 118.0
# Average return training: 77.34
# 676 0.14460399999961132 116.0
# Average return training: 78.29
# 677 0.14089599999961047 103.0
# Average return training: 79.21
# Average return over 25 episodes of playing: 193.4
# 678 0.1353159999996092 155.0
# Average return training: 79.96
# 679 0.1262079999996071 253.0
# Average return training: 81.41
# 680 0.125739999999607 13.0
# Average return training: 80.67
# Average return over 25 episodes of playing: 138.08
# 681 0.11472399999960844 306.0
# Average return training: 83.56
# 682 0.11101599999960902 103.0
# Average return training: 84.44
# 683 0.10597599999960981 140.0
# Average return training: 85.45
# 684 0.10478799999961 33.0
# Average return training: 85.61
# 685 0.10334799999961022 40.0
# Average return training: 85.9
# Average return over 25 episodes of playing: 61.96
# 686 0.1 177.0
# Average return training: 87.07
# 687 0.1 210.0
# Average return training: 88.96
# 688 0.1 18.0
# Average return training: 88.95
# Average return over 25 episodes of playing: 340.88
# 689 0.1 234.0
# Average return training: 91.15
# 690 0.1 321.0
# Average return training: 93.57
# Average return over 25 episodes of playing: 500.0
# 691 0.1 252.0
# Average return training: 95.73
# 692 0.1 104.0
# Average return training: 96.66
# Average return over 25 episodes of playing: 500.0
# 693 0.1 368.0
# Average return training: 100.22
# 694 0.1 12.0
# Average return training: 99.7
# 695 0.1 113.0
# Average return training: 100.66
# 696 0.1 60.0
# Average return training: 100.96
# 697 0.1 67.0
# Average return training: 101.26
# Average return over 25 episodes of playing: 161.28
# 698 0.1 461.0
# Average return training: 105.71
# Average return over 25 episodes of playing: 419.48
# 699 0.1 473.0
# Average return training: 109.4
# Average return over 25 episodes of playing: 312.52
# 700 0.1 283.0
# Average return training: 111.98
# 701 0.1 192.0
# Average return training: 112.95
# 702 0.1 196.0
# Average return training: 114.28
# Average return over 25 episodes of playing: 181.44
# 703 0.1 215.0
# Average return training: 115.49
# 704 0.1 259.0
# Average return training: 117.7
# Average return over 25 episodes of playing: 491.6
# 705 0.1 500.0
# Average return training: 122.17
# Average return over 25 episodes of playing: 500.0
# 706 0.1 136.0
# Average return training: 123.39
# 707 0.1 384.0
# Average return training: 127.07
# Average return over 25 episodes of playing: 290.76
# 708 0.1 64.0
# Average return training: 127.27
# 709 0.1 234.0
# Average return training: 129.29
# 710 0.1 59.0
# Average return training: 129.22
# Average return over 25 episodes of playing: 334.44
# 711 0.1 261.0
# Average return training: 131.55
# Average return over 25 episodes of playing: 499.84
# 712 0.1 500.0
# Average return training: 136.44
# Average return over 25 episodes of playing: 287.12
# 713 0.1 500.0
# Average return training: 141.23
# Average return over 25 episodes of playing: 489.44
# 714 0.1 500.0
# Average return training: 145.89
# Average return over 25 episodes of playing: 500.0
# 715 0.1 500.0
# Average return training: 150.54
# 716 0.1 186.0
# Average return training: 152.07
# 717 0.1 186.0
# Average return training: 153.69
# Average return over 25 episodes of playing: 145.44
# 718 0.1 403.0
# Average return training: 157.61
# Average return over 25 episodes of playing: 158.96
# 719 0.1 273.0
# Average return training: 159.11
# 720 0.1 153.0
# Average return training: 159.47
# 721 0.1 151.0
# Average return training: 160.77
# Average return over 25 episodes of playing: 160.68
# 722 0.1 165.0
# Average return training: 162.08
# 723 0.1 173.0
# Average return training: 162.31
# 724 0.1 162.0
# Average return training: 160.32
# Average return over 25 episodes of playing: 207.0
# 725 0.1 200.0
# Average return training: 161.37
# 726 0.1 16.0
# Average return training: 160.42
# Average return over 25 episodes of playing: 182.08
# 727 0.1 426.0
# Average return training: 163.32
# 728 0.1 55.0
# Average return training: 162.17
# Average return over 25 episodes of playing: 500.0
# 729 0.1 500.0
# Average return training: 162.29
# Average return over 25 episodes of playing: 500.0
# 730 0.1 500.0
# Average return training: 167.16
# 731 0.1 303.0
# Average return training: 166.73
# Average return over 25 episodes of playing: 129.16
# 732 0.1 184.0
# Average return training: 167.37
# Average return over 25 episodes of playing: 500.0
# 733 0.1 500.0
# Average return training: 172.23
# Average return over 25 episodes of playing: 500.0
# 734 0.1 472.0
# Average return training: 175.8
# 735 0.1 368.0
# Average return training: 179.35
# 736 0.1 20.0
# Average return training: 179.43
# 737 0.1 20.0
# Average return training: 179.49
# Average return over 25 episodes of playing: 442.88
# 738 0.1 31.0
# Average return training: 179.63
# 739 0.1 210.0
# Average return training: 181.17
# 740 0.1 153.0
# Average return training: 180.05
# Average return over 25 episodes of playing: 500.0
# 741 0.1 500.0
# Average return training: 184.8
# 742 0.1 77.0
# Average return training: 183.74
# Average return over 25 episodes of playing: 427.28
# 743 0.1 203.0
# Average return training: 185.42
# 744 0.1 118.0
# Average return training: 186.41
# 745 0.1 108.0
# Average return training: 187.34
# Average return over 25 episodes of playing: 500.0
# 746 0.1 500.0
# Average return training: 191.9
# 747 0.1 115.0
# Average return training: 192.81
# Average return over 25 episodes of playing: 500.0
# 748 0.1 500.0
# Average return training: 195.75
# Average return over 25 episodes of playing: 500.0
# 749 0.1 75.0
# Average return training: 196.37
# Average return over 100 episodes of trained agent: 500.0
