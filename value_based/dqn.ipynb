# %%
# Importing needed librarys
import torch
import torch.nn as nn
import gym
import numpy as np
import random
import wandb
from copy import deepcopy

# %%
# Setting seeds
def make_deterministic(seed):
  torch.manual_seed(seed)
  random.seed(seed)
  np.random.seed(seed)

# %%
# Building a class for the neural network
class Neural_Network(nn.Module):
  def __init__(self, in_dim, out_dim, hidden_dim):
        super(Neural_Network, self).__init__()
        self.input_layer = nn.Linear(in_dim, hidden_dim[0])
        self.hidden_layer = nn.Linear(hidden_dim[0], hidden_dim[1])
        self.output_layer = nn.Linear(hidden_dim[1], out_dim)
       
  def forward (self, x, activation_function = nn.ReLU()):
    x = activation_function(self.input_layer(x))
    x = activation_function(self.hidden_layer(x))
    output = self.output_layer(x)
    return output

# %%
# Defining function for epsilon greedy actions
def eps_greedy(state, online_model, eps):
  with torch.no_grad():
    if (np.random.rand() > eps):
      value, inds  = torch.max(online_model(state), dim=0)
      return inds.item()
    else:
      action = np.random.choice(env.action_space.n)
      return action

# %%
 # Defining function for playing during and after training to obtain performance of the agent
def play(episodes, step, end, envs):
  x = 0
  returns = []

  for i in range(0, episodes):
    memory_states = [] 
    memory_actions = [] 
    memory_rewards = [] 
    memory_terminal = [] 
    memory_states_next = []

    state = envs.reset()
    while True:
      action = eps_greedy(state = torch.tensor(state).float() , online_model = online_model, eps = -1)
      state_next, reward, done, _ = envs.step(action)
      memory_rewards.append(reward)
      memory_terminal.append(done)
      state = state_next

      if done:
        x = sum(memory_rewards)
        state = envs.reset()
        returns.append(x)
        break

  if end:
    avg_return = sum(returns[-100:]) / 100
    print("Average return over 100 episodes of trained agent:", avg_return)
  else:
    avg_return = sum(returns[-25:]) / 25
    wandb.log({"Average return over 25 episodes of playing": avg_return,"step": step})
    print("Average return over 25 episodes of playing:", avg_return)

  return avg_return

# %%
##### DQN Algorithm ###########

# Seeds for repeatable training results
SEEDS = (12, 34, 56)

# Creating two environments: One for training and for playing
env = gym.make("CartPole-v1")
env2 = gym.make("CartPole-v1")

# Looping over different seeds for training different agents
for seed in SEEDS:
  make_deterministic(seed)
  print("SEED:", seed)
  wandb.init(project="DQN-CartPole", entity="raisa")
  config = wandb.config

  # Defining hyperparameters
  gamma = 0.99 # gamma
  eps_max = 1 # maximum value for epsilon
  eps_min = 0.1 # minimum value for epsilon
  eps_decay = (1-0.1) / 25000 # decaying factor for epsilon
  learning_rate = 0.0025 # learning rate
  batch_size = 64 # batch size
  num_episodes = 1000 # maximum number of episodes
  min_memory = 100 # size of replay memory at start of training
  max_memory = 1000 # maximum size of replay memory
  hidden_dims = [128, 64] # size of hidden layers in the neural network
  act_period = 150 # update frequency of target neural network
  criterion = nn.MSELoss() # loss function

  # Logging hyperparameters
  config.learning_rate = learning_rate
  config.gamma = gamma
  config.batch_size = batch_size
  config.num_episodes = num_episodes
  config.max_memory = max_memory
  config.min_memory = min_memory
  config.hidden_dim = hidden_dims
  config.act_period = act_period
  config.eps_max = eps_max
  config.eps_min = eps_min
  config.eps_decay = eps_decay
  config.seed = seed

  # Setting the seed for the environments
  env.seed(seed)
  env.action_space.seed(seed)
  env2.seed(seed)
  env2.action_space.seed(seed)

  # Initializing replay memory
  memory_states = [] 
  memory_actions = [] 
  memory_rewards = [] 
  memory_terminal = [] 
  memory_states_next = []

  # Initializing list for average returns during training
  returns_train = []
  # Initializing list for average returns during playing
  returns_play = []

  # Creating neural networks and setting optimizer
  online_model = (Neural_Network(in_dim = int(np.prod(env.observation_space.shape)), out_dim = env.action_space.n, hidden_dim=hidden_dims)) 
  target_model = (Neural_Network(in_dim = int(np.prod(env.observation_space.shape)), out_dim = env.action_space.n, hidden_dim=hidden_dims)) 
  optimizer = torch.optim.Adam(online_model.parameters(), lr=learning_rate)
  target_model = deepcopy(online_model) 

  # Storing minimum experiences in replay memory
  state = env.reset()
  for step in range(0,min_memory):
    action = np.random.choice(env.action_space.n)
    state_next, reward, done, _ = env.step(action)
    memory_actions.append(action)
    memory_states.append(state)
    memory_states_next.append(state_next)
    memory_rewards.append(reward)
    memory_terminal.append(done)
    state = state_next

    if done:
      state = env.reset()

  epsi = eps_max
  step = 0

  # Training the agent for number of episodes
  for episode in range(0, num_episodes):
    state = env.reset()
    reward_sum = 0
    while True:
      step += 1

      # Deleting first element of replay memory, if max_memory length is reached
      if(len(memory_states) > max_memory):
        memory_actions.pop(0)
        memory_states.pop(0)
        memory_states_next.pop(0)
        memory_rewards.pop(0)
        memory_terminal.pop(0)

      # Taking epsilon greedy action and storing experience in replay memory
      epsi = max(epsi - eps_decay, eps_min)
      action = eps_greedy(state = torch.tensor(state).float() , online_model = online_model, eps = epsi)
      state_next, reward, done, _ = env.step(action)
      memory_actions.append(action)
      memory_states.append(state)
      memory_states_next.append(state_next)
      memory_rewards.append(reward)
      memory_terminal.append(done)
      state = state_next

      reward_sum+=reward

      # Selecting random batch of experiences
      rand_index = np.random.choice(len(memory_states_next), size=batch_size, replace=False)
      batch_states = torch.tensor(np.array(memory_states)[rand_index], dtype=torch.float32) 
      batch_states_next = torch.tensor(np.array(memory_states_next)[rand_index], dtype=torch.float32) 
      batch_rewards = torch.tensor(np.array(memory_rewards)[rand_index], dtype=torch.float32) 
      batch_actions = torch.tensor(np.array(memory_actions)[rand_index], dtype=torch.int64) 
      batch_terminal = torch.tensor(np.array(memory_terminal)[rand_index], dtype=torch.int64) 
    
      # Calculating q-values for training
      with torch.no_grad():
        q_values_next = target_model(batch_states_next)
        max_q_values_next, _ = torch.max(q_values_next,dim=1)
        # Calculating the target q-values
        q_target = (batch_rewards + gamma * (1 - batch_terminal) * max_q_values_next)
  

      # Calculating the expected q-values
      q_exp = online_model(batch_states)
      batch_actions = torch.reshape(input = batch_actions, shape = (batch_size, 1))
      q_exp = torch.gather(input = q_exp, dim = 1, index = batch_actions)
      q_exp = (torch.reshape(q_exp, (-1,))) 

      # Calculating loss
      loss = criterion(q_target, q_exp) 

      optimizer.zero_grad()

      # Backpropagating the loss
      loss.backward()

      # Taking an optimization step
      optimizer.step()

      # Copying the weights of online network in the target network every act_period steps
      if step % act_period == 0:
        target_model = deepcopy(online_model) 

      # Playing every 500 steps to obtain the performance of the DQN agent
      if step % 500 == 0:
        avg_return_play = play(episodes = 25, step = step, end = False, envs = env2)
        returns_play.append(avg_return_play)
      
      # If an episode has to come to an end, reset environment and print the reward for the last episode
      if done:
        print(episode + 1, epsi, reward_sum)
        returns_train.append(reward_sum)

        # If episode > 100, then print the average reward for the last hundred episodes 
        if episode + 1  > 100:
          x = sum(returns_train[-100:])/100
          print("Average return training:", x)
          # Logging the training average return
          wandb.log({"Average return over 100 episodes of training": x, "episode": episode + 1})  
        break

    # If training steps >= 2500 and the agent has obtained an average reward of 475 during last 5 times of playing: End the training
    if step >= 2500:
      if sum(returns_play[-5:]) / 5 >= 475:
        break

  # Playing after training to obtain end results
  play(episodes = 100, step = step, end = True, envs = env2)
# Out:
# SEED: 12
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                     Syncing run <strong><a href="https://wandb.ai/raisa/DQN-CartPole/runs/2nh4pig5" target="_blank">super-feather-94</a></strong> to <a href="https://wandb.ai/raisa/DQN-CartPole" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 1 0.9991359999999991 24.0
# 2 0.9983799999999984 21.0
# 3 0.998019999999998 10.0
# 4 0.9971559999999972 24.0
# 5 0.9964359999999964 20.0
# 6 0.9954999999999955 26.0
# 7 0.995031999999995 13.0
# 8 0.9944919999999945 15.0
# 9 0.9938799999999939 17.0
# 10 0.9931239999999931 21.0
# 11 0.9923319999999923 22.0
# 12 0.9898839999999899 68.0
# 13 0.9891639999999892 20.0
# 14 0.9886599999999887 14.0
# 15 0.9879399999999879 20.0
# 16 0.9854199999999854 70.0
# 17 0.985023999999985 11.0
# 18 0.9844119999999844 17.0
# 19 0.9830799999999831 37.0
# 20 0.9823599999999824 20.0
# Average return over 25 episodes of playing: 75.04
# 21 0.9817119999999817 18.0
# 22 0.9808119999999808 25.0
# 23 0.9802719999999803 15.0
# 24 0.9797319999999797 15.0
# 25 0.9783279999999783 39.0
# 26 0.9775359999999775 22.0
# 27 0.9769239999999769 17.0
# 28 0.9761319999999761 22.0
# 29 0.9753039999999753 23.0
# 30 0.9747999999999748 14.0
# 31 0.9742599999999743 15.0
# 32 0.9737919999999738 13.0
# 33 0.9733599999999734 12.0
# 34 0.9723879999999724 27.0
# 35 0.9717399999999717 18.0
# 36 0.9712359999999712 14.0
# 37 0.9704799999999705 21.0
# 38 0.9701559999999702 9.0
# 39 0.9693279999999693 23.0
# 40 0.9686079999999686 20.0
# 41 0.9673479999999673 35.0
# 42 0.966951999999967 11.0
# 43 0.9656559999999657 36.0
# 44 0.9643599999999644 36.0
# Average return over 25 episodes of playing: 21.4
# 45 0.963963999999964 11.0
# 46 0.9632079999999632 21.0
# 47 0.9626679999999627 15.0
# 48 0.9621999999999622 13.0
# 49 0.9615519999999615 18.0
# 50 0.9607239999999607 23.0
# 51 0.9594279999999594 36.0
# 52 0.9589239999999589 14.0
# 53 0.9582399999999582 19.0
# 54 0.9576639999999577 16.0
# 55 0.9566919999999567 27.0
# 56 0.9551799999999552 42.0
# 57 0.9548559999999549 9.0
# 58 0.9544239999999544 12.0
# 59 0.9537759999999538 18.0
# 60 0.9522639999999523 42.0
# 61 0.9504639999999505 50.0
# 62 0.94995999999995 14.0
# 63 0.9492759999999493 19.0
# 64 0.947979999999948 36.0
# 65 0.9473319999999473 18.0
# 66 0.9467919999999468 15.0
# 67 0.9464679999999465 9.0
# Average return over 25 episodes of playing: 197.6
# 68 0.9455679999999456 25.0
# 69 0.9441999999999442 38.0
# 70 0.9436239999999436 16.0
# 71 0.9429399999999429 19.0
# 72 0.9423999999999424 15.0
# 73 0.9416439999999416 21.0
# 74 0.941031999999941 17.0
# 75 0.9405639999999406 13.0
# 76 0.9393759999999394 33.0
# 77 0.938979999999939 11.0
# 78 0.9379359999999379 29.0
# 79 0.9372519999999372 19.0
# 80 0.9366759999999367 16.0
# 81 0.9362799999999363 11.0
# 82 0.9357399999999357 15.0
# 83 0.9334359999999334 64.0
# 84 0.9328959999999329 15.0
# 85 0.9323559999999323 15.0
# 86 0.9315639999999316 22.0
# 87 0.931023999999931 15.0
# 88 0.9304479999999304 16.0
# 89 0.9298719999999299 16.0
# 90 0.9288999999999289 27.0
# 91 0.9285399999999285 10.0
# Average return over 25 episodes of playing: 154.8
# 92 0.9278199999999278 20.0
# 93 0.9272799999999273 15.0
# 94 0.9267039999999267 16.0
# 95 0.9254439999999254 35.0
# 96 0.9248679999999249 16.0
# 97 0.9244359999999244 12.0
# 98 0.9230679999999231 38.0
# 99 0.9224919999999225 16.0
# 100 0.9214479999999214 29.0
# 101 0.9207999999999208 18.0
# Average return training: 21.76
# 102 0.91997199999992 23.0
# Average return training: 21.78
# 103 0.9191799999999192 22.0
# Average return training: 21.9
# 104 0.9187839999999188 11.0
# Average return training: 21.77
# 105 0.9182799999999183 14.0
# Average return training: 21.71
# 106 0.916983999999917 36.0
# Average return training: 21.81
# 107 0.9165159999999165 13.0
# Average return training: 21.81
# 108 0.9157599999999158 21.0
# Average return training: 21.87
# 109 0.9148959999999149 24.0
# Average return training: 21.94
# 110 0.9137439999999137 32.0
# Average return training: 22.05
# 111 0.9132759999999133 13.0
# Average return training: 21.96
# 112 0.9123039999999123 27.0
# Average return training: 21.55
# 113 0.9116559999999116 18.0
# Average return training: 21.53
# Average return over 25 episodes of playing: 173.96
# 114 0.9099279999999099 48.0
# Average return training: 21.87
# 115 0.907047999999907 80.0
# Average return training: 22.47
# 116 0.9065799999999066 13.0
# Average return training: 21.9
# 117 0.9057879999999058 22.0
# Average return training: 22.01
# 118 0.9045279999999045 35.0
# Average return training: 22.19
# 119 0.9033039999999033 34.0
# Average return training: 22.16
# 120 0.9021879999999022 31.0
# Average return training: 22.27
# 121 0.9008559999999008 37.0
# Average return training: 22.46
# 122 0.9003879999999004 13.0
# Average return training: 22.34
# 123 0.8998119999998998 16.0
# Average return training: 22.35
# 124 0.8992719999998993 15.0
# Average return training: 22.35
# 125 0.8986959999998987 16.0
# Average return training: 22.12
# 126 0.8981559999998981 15.0
# Average return training: 22.05
# 127 0.8971839999998972 27.0
# Average return training: 22.15
# 128 0.8965719999998966 17.0
# Average return training: 22.1
# 129 0.8962119999998962 10.0
# Average return training: 21.97
# 130 0.8954919999998955 20.0
# Average return training: 22.03
# 131 0.8949519999998949 15.0
# Average return training: 22.03
# 132 0.8943039999998943 18.0
# Average return training: 22.08
# 133 0.8921799999998922 59.0
# Average return training: 22.55
# Average return over 25 episodes of playing: 149.92
# 134 0.8906319999998906 43.0
# Average return training: 22.71
# 135 0.8902359999998902 11.0
# Average return training: 22.64
# 136 0.8896959999998897 15.0
# Average return training: 22.65
# 137 0.8893359999998893 10.0
# Average return training: 22.54
# 138 0.8884359999998884 25.0
# Average return training: 22.7
# 139 0.8877879999998878 18.0
# Average return training: 22.65
# 140 0.8872839999998873 14.0
# Average return training: 22.59
# 141 0.8868519999998868 12.0
# Average return training: 22.36
# 142 0.8861679999998862 19.0
# Average return training: 22.44
# 143 0.8853039999998853 24.0
# Average return training: 22.32
# 144 0.8846559999998846 18.0
# Average return training: 22.14
# 145 0.8832879999998833 38.0
# Average return training: 22.41
# 146 0.8814519999998814 51.0
# Average return training: 22.71
# 147 0.881055999999881 11.0
# Average return training: 22.67
# 148 0.8804439999998804 17.0
# Average return training: 22.71
# 149 0.8798319999998798 17.0
# Average return training: 22.7
# 150 0.8791479999998791 19.0
# Average return training: 22.66
# 151 0.8787159999998787 12.0
# Average return training: 22.42
# 152 0.8768799999998769 51.0
# Average return training: 22.79
# 153 0.8756559999998756 34.0
# Average return training: 22.94
# Average return over 25 episodes of playing: 197.24
# 154 0.8739279999998739 48.0
# Average return training: 23.26
# 155 0.8732439999998732 19.0
# Average return training: 23.18
# 156 0.8727759999998728 13.0
# Average return training: 22.89
# 157 0.8722719999998723 14.0
# Average return training: 22.94
# 158 0.8712999999998713 27.0
# Average return training: 23.09
# 159 0.8705799999998706 20.0
# Average return training: 23.11
# 160 0.8701839999998702 11.0
# Average return training: 22.8
# 161 0.8697519999998697 12.0
# Average return training: 22.42
# 162 0.8685279999998685 34.0
# Average return training: 22.62
# 163 0.868059999999868 13.0
# Average return training: 22.56
# 164 0.8674479999998674 17.0
# Average return training: 22.37
# 165 0.8667279999998667 20.0
# Average return training: 22.39
# 166 0.8647839999998648 54.0
# Average return training: 22.78
# 167 0.864063999999864 20.0
# Average return training: 22.89
# 168 0.8623719999998624 47.0
# Average return training: 23.11
# 169 0.8619039999998619 13.0
# Average return training: 22.86
# 170 0.8613639999998614 15.0
# Average return training: 22.85
# 171 0.8604999999998605 24.0
# Average return training: 22.9
# 172 0.86003199999986 13.0
# Average return training: 22.88
# 173 0.8594919999998595 15.0
# Average return training: 22.82
# 174 0.8588079999998588 19.0
# Average return training: 22.84
# 175 0.8582679999998583 15.0
# Average return training: 22.86
# 176 0.8576559999998576 17.0
# Average return training: 22.7
# 177 0.8563599999998563 36.0
# Average return training: 22.95
# Average return over 25 episodes of playing: 159.72
# 178 0.8555319999998555 23.0
# Average return training: 22.89
# 179 0.8549559999998549 16.0
# Average return training: 22.86
# 180 0.8544519999998544 14.0
# Average return training: 22.84
# 181 0.8539479999998539 14.0
# Average return training: 22.87
# 182 0.8534439999998534 14.0
# Average return training: 22.86
# 183 0.851967999999852 41.0
# Average return training: 22.63
# 184 0.8514639999998515 14.0
# Average return training: 22.62
# 185 0.851067999999851 11.0
# Average return training: 22.58
# 186 0.8494839999998495 44.0
# Average return training: 22.8
# 187 0.8488719999998489 17.0
# Average return training: 22.82
# 188 0.8475759999998476 36.0
# Average return training: 23.02
# 189 0.8471439999998471 12.0
# Average return training: 22.98
# 190 0.8457399999998457 39.0
# Average return training: 23.1
# 191 0.8452719999998453 13.0
# Average return training: 23.13
# 192 0.8446959999998447 16.0
# Average return training: 23.09
# 193 0.8440839999998441 17.0
# Average return training: 23.11
# 194 0.842031999999842 57.0
# Average return training: 23.52
# 195 0.8416359999998416 11.0
# Average return training: 23.28
# 196 0.8397639999998397 52.0
# Average return training: 23.64
# 197 0.839007999999839 21.0
# Average return training: 23.73
# 198 0.8385039999998385 14.0
# Average return training: 23.49
# Average return over 25 episodes of playing: 226.64
# 199 0.8373519999998373 32.0
# Average return training: 23.65
# 200 0.8367759999998368 16.0
# Average return training: 23.52
# 201 0.8345079999998345 63.0
# Average return training: 23.97
# 202 0.834003999999834 14.0
# Average return training: 23.88
# 203 0.8332839999998333 20.0
# Average return training: 23.86
# 204 0.8328159999998328 13.0
# Average return training: 23.88
# 205 0.8311599999998311 46.0
# Average return training: 24.2
# 206 0.8305119999998305 18.0
# Average return training: 24.02
# 207 0.8286759999998287 51.0
# Average return training: 24.4
# 208 0.8281359999998281 15.0
# Average return training: 24.34
# 209 0.8275599999998275 16.0
# Average return training: 24.26
# 210 0.8271279999998271 12.0
# Average return training: 24.06
# 211 0.8242479999998242 80.0
# Average return training: 24.73
# 212 0.8228439999998228 39.0
# Average return training: 24.85
# 213 0.8220879999998221 21.0
# Average return training: 24.88
# 214 0.8215479999998215 15.0
# Average return training: 24.55
# 215 0.8207199999998207 23.0
# Average return training: 23.98
# Average return over 25 episodes of playing: 67.2
# 216 0.8196039999998196 31.0
# Average return training: 24.16
# 217 0.819027999999819 16.0
# Average return training: 24.1
# 218 0.8185959999998186 12.0
# Average return training: 23.87
# 219 0.8161479999998161 68.0
# Average return training: 24.21
# 220 0.8152839999998153 24.0
# Average return training: 24.14
# 221 0.8136999999998137 44.0
# Average return training: 24.21
# 222 0.8133399999998133 10.0
# Average return training: 24.18
# 223 0.812007999999812 37.0
# Average return training: 24.39
# 224 0.8108919999998109 31.0
# Average return training: 24.55
# 225 0.8103519999998103 15.0
# Average return training: 24.54
# 226 0.8098119999998098 15.0
# Average return training: 24.54
# 227 0.809055999999809 21.0
# Average return training: 24.48
# 228 0.8076879999998077 38.0
# Average return training: 24.69
# 229 0.8066439999998066 29.0
# Average return training: 24.88
# 230 0.8057079999998057 26.0
# Average return training: 24.94
# 231 0.805023999999805 19.0
# Average return training: 24.98
# 232 0.8043039999998043 20.0
# Average return training: 25.0
# 233 0.8022879999998023 56.0
# Average return training: 24.97
# Average return over 25 episodes of playing: 92.44
# 234 0.8016759999998017 17.0
# Average return training: 24.71
# 235 0.8007039999998007 27.0
# Average return training: 24.87
# 236 0.8000919999998001 17.0
# Average return training: 24.89
# 237 0.7996599999997996 12.0
# Average return training: 24.91
# 238 0.7991559999997991 14.0
# Average return training: 24.8
# 239 0.7987239999997987 12.0
# Average return training: 24.74
# 240 0.7979319999997979 22.0
# Average return training: 24.82
# 241 0.7954479999997954 69.0
# Average return training: 25.39
# 242 0.794979999999795 13.0
# Average return training: 25.33
# 243 0.7942239999997942 21.0
# Average return training: 25.3
# 244 0.7935039999997935 20.0
# Average return training: 25.32
# 245 0.792999999999793 14.0
# Average return training: 25.08
# 246 0.7923879999997924 17.0
# Average return training: 24.74
# 247 0.7916679999997916 20.0
# Average return training: 24.83
# 248 0.790983999999791 19.0
# Average return training: 24.85
# 249 0.7897239999997897 35.0
# Average return training: 25.03
# 250 0.7891839999997892 15.0
# Average return training: 24.99
# 251 0.7887519999997887 12.0
# Average return training: 24.99
# 252 0.7881039999997881 18.0
# Average return training: 24.66
# 253 0.7872399999997872 24.0
# Average return training: 24.56
# 254 0.7867359999997867 14.0
# Average return training: 24.22
# 255 0.786051999999786 19.0
# Average return training: 24.22
# Average return over 25 episodes of playing: 131.52
# 256 0.7839279999997839 59.0
# Average return training: 24.68
# 257 0.7834959999997835 12.0
# Average return training: 24.66
# 258 0.7824519999997824 29.0
# Average return training: 24.68
# 259 0.7820919999997821 10.0
# Average return training: 24.58
# 260 0.7815159999997815 16.0
# Average return training: 24.63
# 261 0.7808679999997808 18.0
# Average return training: 24.69
# 262 0.7791759999997792 47.0
# Average return training: 24.82
# 263 0.777987999999778 33.0
# Average return training: 25.02
# 264 0.7762239999997762 49.0
# Average return training: 25.34
# 265 0.7757199999997757 14.0
# Average return training: 25.28
# 266 0.7744599999997744 35.0
# Average return training: 25.09
# 267 0.7731279999997731 37.0
# Average return training: 25.26
# 268 0.771039999999771 58.0
# Average return training: 25.37
# 269 0.7695279999997695 42.0
# Average return training: 25.66
# 270 0.7686639999997686 24.0
# Average return training: 25.75
# 271 0.7679439999997679 20.0
# Average return training: 25.71
# 272 0.7675479999997675 11.0
# Average return training: 25.69
# 273 0.7664319999997664 31.0
# Average return training: 25.85
# Average return over 25 episodes of playing: 99.68
# 274 0.7658919999997659 15.0
# Average return training: 25.81
# 275 0.7651359999997651 21.0
# Average return training: 25.87
# 276 0.7644519999997644 19.0
# Average return training: 25.89
# 277 0.7641279999997641 9.0
# Average return training: 25.62
# 278 0.7621119999997621 56.0
# Average return training: 25.95
# 279 0.7612119999997612 25.0
# Average return training: 26.04
# 280 0.7598799999997599 37.0
# Average return training: 26.27
# 281 0.7592319999997592 18.0
# Average return training: 26.31
# 282 0.7584039999997584 23.0
# Average return training: 26.4
# 283 0.7573959999997574 28.0
# Average return training: 26.27
# 284 0.7553079999997553 58.0
# Average return training: 26.71
# 285 0.7543359999997543 27.0
# Average return training: 26.87
# 286 0.7539399999997539 11.0
# Average return training: 26.54
# 287 0.7535079999997535 12.0
# Average return training: 26.49
# 288 0.7527519999997527 21.0
# Average return training: 26.34
# 289 0.7523559999997523 11.0
# Average return training: 26.33
# 290 0.7518519999997518 14.0
# Average return training: 26.08
# 291 0.7513119999997513 15.0
# Average return training: 26.1
# 292 0.7499439999997499 38.0
# Average return training: 26.32
# 293 0.7492599999997492 19.0
# Average return training: 26.34
# 294 0.7485039999997485 21.0
# Average return training: 25.98
# Average return over 25 episodes of playing: 46.52
# 295 0.7475679999997475 26.0
# Average return training: 26.13
# 296 0.7464879999997465 30.0
# Average return training: 25.91
# 297 0.7455159999997455 27.0
# Average return training: 25.97
# 298 0.7448319999997448 19.0
# Average return training: 26.02
# 299 0.7442199999997442 17.0
# Average return training: 25.87
# 300 0.7433919999997434 23.0
# Average return training: 25.94
# 301 0.7428519999997428 15.0
# Average return training: 25.46
# 302 0.7414479999997414 39.0
# Average return training: 25.71
# 303 0.7402959999997403 32.0
# Average return training: 25.83
# 304 0.7396839999997397 17.0
# Average return training: 25.87
# 305 0.739071999999739 17.0
# Average return training: 25.58
# 306 0.7384599999997384 17.0
# Average return training: 25.57
# 307 0.7369479999997369 42.0
# Average return training: 25.48
# 308 0.7359399999997359 28.0
# Average return training: 25.61
# 309 0.7355079999997355 12.0
# Average return training: 25.57
# 310 0.735039999999735 13.0
# Average return training: 25.58
# 311 0.7344639999997344 16.0
# Average return training: 24.94
# 312 0.7338519999997338 17.0
# Average return training: 24.72
# 313 0.7332399999997332 17.0
# Average return training: 24.68
# 314 0.7317279999997317 42.0
# Average return training: 24.95
# 315 0.731043999999731 19.0
# Average return training: 24.91
# 316 0.7303959999997304 18.0
# Average return training: 24.78
# Average return over 25 episodes of playing: 269.84
# 317 0.7294959999997295 25.0
# Average return training: 24.87
# 318 0.7283079999997283 33.0
# Average return training: 25.08
# 319 0.7277319999997277 16.0
# Average return training: 24.56
# 320 0.7271199999997271 17.0
# Average return training: 24.49
# 321 0.7263999999997264 20.0
# Average return training: 24.25
# 322 0.7259319999997259 13.0
# Average return training: 24.28
# 323 0.7254999999997255 12.0
# Average return training: 24.03
# 324 0.7249599999997249 15.0
# Average return training: 23.87
# 325 0.7243839999997244 16.0
# Average return training: 23.88
# 326 0.7236999999997237 19.0
# Average return training: 23.92
# 327 0.7231599999997231 15.0
# Average return training: 23.86
# 328 0.7222599999997222 25.0
# Average return training: 23.73
# 329 0.7218279999997218 12.0
# Average return training: 23.56
# 330 0.7203519999997203 41.0
# Average return training: 23.71
# 331 0.7199559999997199 11.0
# Average return training: 23.63
# 332 0.7187319999997187 34.0
# Average return training: 23.77
# 333 0.7182639999997182 13.0
# Average return training: 23.34
# 334 0.7169679999997169 36.0
# Average return training: 23.53
# 335 0.7162839999997163 19.0
# Average return training: 23.45
# 336 0.7157079999997157 16.0
# Average return training: 23.44
# 337 0.7147359999997147 27.0
# Average return training: 23.59
# 338 0.7143039999997143 12.0
# Average return training: 23.57
# 339 0.7136559999997136 18.0
# Average return training: 23.63
# 340 0.712971999999713 19.0
# Average return training: 23.6
# 341 0.7121799999997122 22.0
# Average return training: 23.13
# Average return over 25 episodes of playing: 81.16
# 342 0.7108119999997108 38.0
# Average return training: 23.38
# 343 0.7098399999997098 27.0
# Average return training: 23.44
# 344 0.7089039999997089 26.0
# Average return training: 23.5
# 345 0.708075999999708 23.0
# Average return training: 23.59
# 346 0.7072839999997073 22.0
# Average return training: 23.64
# 347 0.7063479999997063 26.0
# Average return training: 23.7
# 348 0.7049079999997049 40.0
# Average return training: 23.91
# 349 0.7031079999997031 50.0
# Average return training: 24.06
# 350 0.7013079999997013 50.0
# Average return training: 24.41
# 351 0.7005879999997006 20.0
# Average return training: 24.49
# 352 0.6983199999996983 63.0
# Average return training: 24.94
# 353 0.6979599999996979 10.0
# Average return training: 24.8
# 354 0.6974199999996974 15.0
# Average return training: 24.81
# 355 0.6966639999996966 21.0
# Average return training: 24.83
# 356 0.6961599999996961 14.0
# Average return training: 24.38
# 357 0.6945399999996945 45.0
# Average return training: 24.71
# Average return over 25 episodes of playing: 65.48
# 358 0.691983999999692 71.0
# Average return training: 25.13
# 359 0.6912999999996913 19.0
# Average return training: 25.22
# 360 0.6907959999996908 14.0
# Average return training: 25.2
# 361 0.6903639999996903 12.0
# Average return training: 25.14
# 362 0.6895719999996895 22.0
# Average return training: 24.89
# 363 0.6891039999996891 13.0
# Average return training: 24.69
# 364 0.6876279999996876 41.0
# Average return training: 24.61
# 365 0.687015999999687 17.0
# Average return training: 24.64
# 366 0.6865119999996865 14.0
# Average return training: 24.43
# 367 0.6859719999996859 15.0
# Average return training: 24.21
# 368 0.6845319999996845 40.0
# Average return training: 24.03
# 369 0.683991999999684 15.0
# Average return training: 23.76
# 370 0.6831639999996831 23.0
# Average return training: 23.75
# 371 0.6817239999996817 40.0
# Average return training: 23.95
# 372 0.6797799999996798 54.0
# Average return training: 24.38
# 373 0.6792399999996792 15.0
# Average return training: 24.22
# 374 0.6774759999996774 49.0
# Average return training: 24.56
# 375 0.6765759999996765 25.0
# Average return training: 24.6
# Average return over 25 episodes of playing: 90.8
# 376 0.6743439999996743 62.0
# Average return training: 25.03
# 377 0.6733359999996733 28.0
# Average return training: 25.22
# 378 0.6719319999996719 39.0
# Average return training: 25.05
# 379 0.6714279999996714 14.0
# Average return training: 24.94
# 380 0.67005999999967 38.0
# Average return training: 24.95
# 381 0.6695559999996695 14.0
# Average return training: 24.91
# 382 0.667035999999667 70.0
# Average return training: 25.38
# 383 0.6665319999996665 14.0
# Average return training: 25.24
# 384 0.6649119999996649 45.0
# Average return training: 25.11
# 385 0.6619599999996619 82.0
# Average return training: 25.66
# 386 0.6613839999996614 16.0
# Average return training: 25.71
# 387 0.6606999999996607 19.0
# Average return training: 25.78
# 388 0.6599439999996599 21.0
# Average return training: 25.78
# 389 0.6593679999996593 16.0
# Average return training: 25.83
# 390 0.6588279999996588 15.0
# Average return training: 25.84
# 391 0.6581079999996581 20.0
# Average return training: 25.89
# Average return over 25 episodes of playing: 97.08
# 392 0.6572799999996572 23.0
# Average return training: 25.74
# 393 0.6561639999996561 31.0
# Average return training: 25.86
# 394 0.6558039999996558 10.0
# Average return training: 25.75
# 395 0.6553359999996553 13.0
# Average return training: 25.62
# 396 0.6541839999996542 32.0
# Average return training: 25.64
# 397 0.6534999999996535 19.0
# Average return training: 25.56
# 398 0.6523839999996524 31.0
# Average return training: 25.68
# 399 0.6513759999996513 28.0
# Average return training: 25.79
# 400 0.6508719999996508 14.0
# Average return training: 25.7
# 401 0.6493599999996493 42.0
# Average return training: 25.97
# 402 0.6487479999996487 17.0
# Average return training: 25.75
# 403 0.648063999999648 19.0
# Average return training: 25.62
# 404 0.6476319999996476 12.0
# Average return training: 25.57
# 405 0.6425199999996425 142.0
# Average return training: 26.82
# 406 0.6415479999996415 27.0
# Average return training: 26.92
# 407 0.641043999999641 14.0
# Average return training: 26.64
# Average return over 25 episodes of playing: 292.68
# 408 0.6387039999996387 65.0
# Average return training: 27.01
# 409 0.6381279999996381 16.0
# Average return training: 27.05
# 410 0.6352119999996352 81.0
# Average return training: 27.73
# 411 0.6331239999996331 58.0
# Average return training: 28.15
# 412 0.6316479999996316 41.0
# Average return training: 28.39
# 413 0.6297399999996297 53.0
# Average return training: 28.75
# 414 0.6281559999996281 44.0
# Average return training: 28.77
# 415 0.6277959999996278 10.0
# Average return training: 28.68
# 416 0.6273279999996273 13.0
# Average return training: 28.63
# 417 0.6267879999996268 15.0
# Average return training: 28.53
# 418 0.624051999999624 76.0
# Average return training: 28.96
# 419 0.6227199999996227 37.0
# Average return training: 29.17
# Average return over 25 episodes of playing: 199.92
# 420 0.6198399999996198 80.0
# Average return training: 29.8
# 421 0.619047999999619 22.0
# Average return training: 29.82
# 422 0.6178599999996178 33.0
# Average return training: 30.02
# 423 0.6167439999996167 31.0
# Average return training: 30.21
# 424 0.6138999999996139 79.0
# Average return training: 30.85
# 425 0.6124959999996125 39.0
# Average return training: 31.08
# 426 0.6118839999996118 17.0
# Average return training: 31.06
# 427 0.6091839999996091 75.0
# Average return training: 31.66
# 428 0.6075279999996075 46.0
# Average return training: 31.87
# 429 0.6049359999996049 72.0
# Average return training: 32.47
# Average return over 25 episodes of playing: 188.84
# 430 0.5987799999995987 171.0
# Average return training: 33.77
# 431 0.5955759999995955 89.0
# Average return training: 34.55
# 432 0.5924799999995924 86.0
# Average return training: 35.07
# 433 0.5871159999995871 149.0
# Average return training: 36.43
# Average return over 25 episodes of playing: 88.68
# 434 0.5854959999995855 45.0
# Average return training: 36.52
# 435 0.5847039999995847 22.0
# Average return training: 36.55
# 436 0.5839119999995839 22.0
# Average return training: 36.61
# 437 0.5811039999995811 78.0
# Average return training: 37.12
# 438 0.5802759999995802 23.0
# Average return training: 37.23
# 439 0.5765319999995765 104.0
# Average return training: 38.09
# 440 0.576063999999576 13.0
# Average return training: 38.03
# 441 0.5747679999995747 36.0
# Average return training: 38.17
# 442 0.5733279999995733 40.0
# Average return training: 38.19
# 443 0.5729319999995729 11.0
# Average return training: 38.03
# 444 0.5719239999995719 28.0
# Average return training: 38.05
# 445 0.5681439999995681 105.0
# Average return training: 38.87
# Average return over 25 episodes of playing: 109.16
# 446 0.5664519999995664 47.0
# Average return training: 39.12
# 447 0.5645799999995645 52.0
# Average return training: 39.38
# 448 0.5601879999995601 122.0
# Average return training: 40.2
# 449 0.5583159999995583 52.0
# Average return training: 40.22
# 450 0.5530959999995531 145.0
# Average return training: 41.17
# 451 0.5516919999995517 39.0
# Average return training: 41.36
# 452 0.5507919999995508 25.0
# Average return training: 40.98
# Average return over 25 episodes of playing: 111.2
# 453 0.5447799999995447 167.0
# Average return training: 42.55
# 454 0.5414679999995414 92.0
# Average return training: 43.32
# 455 0.5406399999995406 23.0
# Average return training: 43.34
# 456 0.5401719999995401 13.0
# Average return training: 43.33
# 457 0.537003999999537 88.0
# Average return training: 43.76
# 458 0.5363559999995363 18.0
# Average return training: 43.23
# Average return over 25 episodes of playing: 153.04
# 459 0.5298759999995298 180.0
# Average return training: 44.84
# 460 0.5271039999995271 77.0
# Average return training: 45.47
# 461 0.5263119999995263 22.0
# Average return training: 45.57
# 462 0.5253039999995253 28.0
# Average return training: 45.63
# 463 0.5229279999995229 66.0
# Average return training: 46.16
# 464 0.5222079999995222 20.0
# Average return training: 45.95
# 465 0.518031999999518 116.0
# Average return training: 46.94
# 466 0.5173479999995173 19.0
# Average return training: 46.99
# 467 0.5155839999995155 49.0
# Average return training: 47.33
# Average return over 25 episodes of playing: 125.2
# 468 0.5136759999995136 53.0
# Average return training: 47.46
# 469 0.5098959999995099 105.0
# Average return training: 48.36
# 470 0.5048919999995048 139.0
# Average return training: 49.52
# 471 0.504063999999504 23.0
# Average return training: 49.35
# 472 0.5032719999995032 22.0
# Average return training: 49.03
# 473 0.5004639999995004 78.0
# Average return training: 49.66
# 474 0.4998159999995001 18.0
# Average return training: 49.35
# Average return over 25 episodes of playing: 155.6
# 475 0.4956039999995024 117.0
# Average return training: 50.27
# 476 0.49495599999950274 18.0
# Average return training: 49.83
# 477 0.49182399999950444 87.0
# Average return training: 50.42
# 478 0.4892679999995058 71.0
# Average return training: 50.74
# 479 0.4887279999995061 15.0
# Average return training: 50.75
# 480 0.48757599999950674 32.0
# Average return training: 50.69
# 481 0.4828959999995093 130.0
# Average return training: 51.85
# 482 0.4819599999995098 26.0
# Average return training: 51.41
# Average return over 25 episodes of playing: 178.68
# 483 0.47591199999951306 168.0
# Average return training: 52.95
# 484 0.4747239999995137 33.0
# Average return training: 52.83
# 485 0.4738239999995142 25.0
# Average return training: 52.26
# 486 0.47151999999951544 64.0
# Average return training: 52.74
# 487 0.47076399999951585 21.0
# Average return training: 52.76
# 488 0.46964799999951645 31.0
# Average return training: 52.86
# 489 0.46813599999951727 42.0
# Average return training: 53.12
# 490 0.46115199999952106 194.0
# Average return training: 54.91
# Average return over 25 episodes of playing: 433.44
# 491 0.4585239999995225 73.0
# Average return training: 55.44
# 492 0.4581279999995227 11.0
# Average return training: 55.32
# 493 0.4565079999995236 45.0
# Average return training: 55.46
# 494 0.4560399999995238 13.0
# Average return training: 55.49
# 495 0.4553559999995242 19.0
# Average return training: 55.55
# 496 0.4511439999995265 117.0
# Average return training: 56.4
# 497 0.4503879999995269 21.0
# Average return training: 56.42
# 498 0.44747199999952847 81.0
# Average return training: 56.92
# 499 0.4463559999995291 31.0
# Average return training: 56.95
# Average return over 25 episodes of playing: 114.56
# 500 0.44196399999953145 122.0
# Average return training: 58.03
# 501 0.44102799999953196 26.0
# Average return training: 57.87
# 502 0.44012799999953245 25.0
# Average return training: 57.95
# 503 0.439119999999533 28.0
# Average return training: 58.04
# 504 0.43879599999953317 9.0
# Average return training: 58.01
# 505 0.4380399999995336 21.0
# Average return training: 56.8
# 506 0.4364919999995344 43.0
# Average return training: 56.96
# 507 0.4356279999995349 24.0
# Average return training: 57.06
# 508 0.4346559999995354 27.0
# Average return training: 56.68
# 509 0.43364799999953596 28.0
# Average return training: 56.8
# 510 0.43314399999953623 14.0
# Average return training: 56.13
# 511 0.4318839999995369 35.0
# Average return training: 55.9
# 512 0.4309839999995374 25.0
# Average return training: 55.74
# 513 0.4304799999995377 14.0
# Average return training: 55.35
# 514 0.429903999999538 16.0
# Average return training: 55.07
# 515 0.4295079999995382 11.0
# Average return training: 55.08
# 516 0.42518799999954054 120.0
# Average return training: 56.15
# Average return over 25 episodes of playing: 114.6
# 517 0.4210479999995428 115.0
# Average return training: 57.15
# 518 0.41942799999954367 45.0
# Average return training: 56.84
# 519 0.4186719999995441 21.0
# Average return training: 56.68
# 520 0.4145679999995463 114.0
# Average return training: 57.02
# 521 0.41395599999954663 17.0
# Average return training: 56.97
# 522 0.4130559999995471 25.0
# Average return training: 56.89
# 523 0.41006799999954874 83.0
# Average return training: 57.41
# 524 0.40945599999954907 17.0
# Average return training: 56.79
# 525 0.40859199999954954 24.0
# Average return training: 56.64
# 526 0.40819599999954975 11.0
# Average return training: 56.58
# Average return over 25 episodes of playing: 105.16
# 527 0.4045599999995517 101.0
# Average return training: 56.84
# 528 0.40416399999955194 11.0
# Average return training: 56.49
# 529 0.4030839999995525 30.0
# Average return training: 56.07
# 530 0.40157199999955334 42.0
# Average return training: 54.78
# 531 0.3981159999995552 96.0
# Average return training: 54.85
# 532 0.39764799999955547 13.0
# Average return training: 54.12
# 533 0.39339999999955777 118.0
# Average return training: 53.81
# 534 0.391167999999559 62.0
# Average return training: 53.98
# 535 0.3898719999995597 36.0
# Average return training: 54.12
# 536 0.38929599999956 16.0
# Average return training: 54.06
# Average return over 25 episodes of playing: 148.96
# 537 0.3833559999995632 165.0
# Average return training: 54.93
# 538 0.38036799999956483 83.0
# Average return training: 55.53
# 539 0.3759759999995672 122.0
# Average return training: 55.71
# 540 0.3720879999995693 108.0
# Average return training: 56.66
# 541 0.37035999999957026 48.0
# Average return training: 56.78
# Average return over 25 episodes of playing: 138.12
# 542 0.36722799999957195 87.0
# Average return training: 57.25
# 543 0.3643839999995735 79.0
# Average return training: 57.93
# 544 0.36337599999957404 28.0
# Average return training: 57.93
# 545 0.36283599999957433 15.0
# Average return training: 57.03
# 546 0.35505999999957855 216.0
# Average return training: 58.72
# 547 0.35451999999957884 15.0
# Average return training: 58.35
# 548 0.3540519999995791 13.0
# Average return training: 57.26
# 549 0.35318799999957956 24.0
# Average return training: 56.98
# 550 0.35250399999957993 19.0
# Average return training: 55.72
# Average return over 25 episodes of playing: 123.76
# 551 0.34991199999958134 72.0
# Average return training: 56.05
# 552 0.3470679999995829 79.0
# Average return training: 56.59
# 553 0.34616799999958336 25.0
# Average return training: 55.17
# 554 0.3455919999995837 16.0
# Average return training: 54.41
# 555 0.34451199999958426 30.0
# Average return training: 54.48
# 556 0.33662799999958853 219.0
# Average return training: 56.54
# 557 0.33619599999958877 12.0
# Average return training: 55.78
# 558 0.33583599999958896 10.0
# Average return training: 55.7
# Average return over 25 episodes of playing: 140.12
# 559 0.33011199999959207 159.0
# Average return training: 55.49
# 560 0.32942799999959244 19.0
# Average return training: 54.91
# 561 0.324711999999595 131.0
# Average return training: 56.0
# 562 0.3237759999995955 26.0
# Average return training: 55.98
# 563 0.32334399999959573 12.0
# Average return training: 55.44
# 564 0.322803999999596 15.0
# Average return training: 55.39
# Average return over 25 episodes of playing: 222.0
# 565 0.30685599999960467 443.0
# Average return training: 58.66
# 566 0.30573999999960527 31.0
# Average return training: 58.78
# 567 0.304443999999606 36.0
# Average return training: 58.65
# 568 0.30113199999960777 92.0
# Average return training: 59.04
# 569 0.29897199999960894 60.0
# Average return training: 58.59
# Average return over 25 episodes of playing: 361.8
# 570 0.2936439999996118 148.0
# Average return training: 58.68
# 571 0.2931039999996121 15.0
# Average return training: 58.6
# 572 0.29177199999961284 37.0
# Average return training: 58.75
# 573 0.2904039999996136 38.0
# Average return training: 58.35
# 574 0.28809999999961483 64.0
# Average return training: 58.81
# 575 0.285939999999616 60.0
# Average return training: 58.24
# Average return over 25 episodes of playing: 447.48
# 576 0.27423999999962234 325.0
# Average return training: 61.31
# 577 0.26995599999962466 119.0
# Average return training: 61.63
# 578 0.2694879999996249 13.0
# Average return training: 61.05
# 579 0.2687319999996253 21.0
# Average return training: 61.11
# 580 0.26833599999962554 11.0
# Average return training: 60.9
# 581 0.2652759999996272 85.0
# Average return training: 60.45
# 582 0.26484399999962743 12.0
# Average return training: 60.31
# 583 0.26426799999962775 16.0
# Average return training: 58.79
# 584 0.2636559999996281 17.0
# Average return training: 58.63
# Average return over 25 episodes of playing: 260.12
# 585 0.26189199999962903 49.0
# Average return training: 58.87
# 586 0.2613879999996293 14.0
# Average return training: 58.37
# 587 0.2608119999996296 16.0
# Average return training: 58.32
# 588 0.26037999999962985 12.0
# Average return training: 58.13
# 589 0.25433199999963313 168.0
# Average return training: 59.39
# 590 0.2538639999996334 13.0
# Average return training: 57.58
# Average return over 25 episodes of playing: 438.8
# 591 0.23586399999963223 500.0
# Average return training: 61.85
# 592 0.22970799999963082 171.0
# Average return training: 63.45
# Average return over 25 episodes of playing: 500.0
# 593 0.22239999999962914 203.0
# Average return training: 65.03
# Average return over 25 episodes of playing: 500.0
# 594 0.20634399999962547 446.0
# Average return training: 69.36
# 595 0.20508399999962518 35.0
# Average return training: 69.52
# 596 0.2012679999996243 106.0
# Average return training: 69.41
# 597 0.20065599999962416 17.0
# Average return training: 69.37
# 598 0.19698399999962332 102.0
# Average return training: 69.58
# 599 0.1964439999996232 15.0
# Average return training: 69.42
# 600 0.19579599999962305 18.0
# Average return training: 68.38
# 601 0.19521999999962292 16.0
# Average return training: 68.28
# 602 0.19359999999962255 45.0
# Average return training: 68.48
# 603 0.19305999999962242 15.0
# Average return training: 68.35
# 604 0.19244799999962228 17.0
# Average return training: 68.43
# Average return over 25 episodes of playing: 500.0
# 605 0.1889919999996215 96.0
# Average return training: 69.18
# Average return over 25 episodes of playing: 500.0
# 606 0.17099199999961737 500.0
# Average return training: 73.75
# Average return over 100 episodes of trained agent: 500.0
# SEED: 34
# Finishing last run (ID:2nh4pig5) before initializing another...
# <br/>Waiting for W&B process to finish, PID 175... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>Average return over 100 episodes of training</td><td>▁▁▁▁▁▁▁▁▁▁▁▂▁▂▂▂▂▁▁▁▂▁▂▂▂▂▃▄▅▅▆▆▆▆▆▆▆▇▆█</td></tr><tr><td>Average return over 25 episodes of playing</td><td>▂▁▄▃▃▃▄▄▂▂▃▂▁▅▂▂▂▅▄▃▂▂▃▃▃▃▇▂▂▃▃▂▃▆▇▄▇███</td></tr><tr><td>episode</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>Average return over 100 episodes of training</td><td>73.75</td></tr><tr><td>Average return over 25 episodes of playing</td><td>500.0</td></tr><tr><td>episode</td><td>606</td></tr><tr><td>step</td><td>23000</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">super-feather-94</strong>: <a href="https://wandb.ai/raisa/DQN-CartPole/runs/2nh4pig5" target="_blank">https://wandb.ai/raisa/DQN-CartPole/runs/2nh4pig5</a><br/>
# Find logs at: <code>./wandb/run-20220114_183331-2nh4pig5/logs</code><br/>
# Successfully finished last run (ID:2nh4pig5). Initializing new run:<br/>
#                     Syncing run <strong><a href="https://wandb.ai/raisa/DQN-CartPole/runs/3vkmumwi" target="_blank">morning-grass-95</a></strong> to <a href="https://wandb.ai/raisa/DQN-CartPole" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 1 0.9993159999999993 19.0
# 2 0.9987399999999987 16.0
# 3 0.9983439999999983 11.0
# 4 0.9976599999999977 19.0
# 5 0.9966519999999967 28.0
# 6 0.9958239999999958 23.0
# 7 0.9952479999999952 16.0
# 8 0.9935919999999936 46.0
# 9 0.9927999999999928 22.0
# 10 0.9918999999999919 25.0
# 11 0.9913599999999914 15.0
# 12 0.9909279999999909 12.0
# 13 0.9893799999999894 43.0
# 14 0.9879039999999879 41.0
# 15 0.9866439999999866 35.0
# 16 0.9857439999999857 25.0
# 17 0.9851319999999851 17.0
# 18 0.9843399999999843 22.0
# 19 0.9838719999999839 13.0
# 20 0.9831879999999832 19.0
# 21 0.9826479999999826 15.0
# Average return over 25 episodes of playing: 23.68
# 22 0.9817479999999817 25.0
# 23 0.9812439999999812 14.0
# 24 0.9805959999999806 18.0
# 25 0.9801639999999802 12.0
# 26 0.9788319999999788 37.0
# 27 0.9777159999999777 31.0
# 28 0.9763119999999763 39.0
# 29 0.9758079999999758 14.0
# 30 0.9747639999999748 29.0
# 31 0.9739359999999739 23.0
# 32 0.9732879999999733 18.0
# 33 0.9728919999999729 11.0
# 34 0.9719199999999719 27.0
# 35 0.9708759999999709 29.0
# 36 0.9704079999999704 13.0
# 37 0.9680679999999681 65.0
# 38 0.9674919999999675 16.0
# 39 0.966951999999967 15.0
# 40 0.9655479999999655 39.0
# Average return over 25 episodes of playing: 148.24
# 41 0.9634959999999635 57.0
# 42 0.9627759999999628 20.0
# 43 0.9618399999999618 26.0
# 44 0.960975999999961 24.0
# 45 0.9604719999999605 14.0
# 46 0.9600759999999601 11.0
# 47 0.9575919999999576 69.0
# 48 0.9572679999999573 9.0
# 49 0.9563319999999563 26.0
# 50 0.956043999999956 8.0
# 51 0.9547119999999547 37.0
# 52 0.9542799999999543 12.0
# 53 0.9538119999999538 13.0
# 54 0.9523359999999523 41.0
# 55 0.9518319999999518 14.0
# 56 0.9511479999999511 19.0
# 57 0.9492399999999492 53.0
# 58 0.9482319999999482 28.0
# 59 0.9463239999999463 53.0
# Average return over 25 episodes of playing: 209.4
# 60 0.9458919999999459 12.0
# 61 0.945027999999945 24.0
# 62 0.9441999999999442 23.0
# 63 0.9433719999999434 23.0
# 64 0.9403479999999403 84.0
# 65 0.9396639999999397 19.0
# 66 0.9380799999999381 44.0
# 67 0.9362439999999362 51.0
# 68 0.9357759999999358 13.0
# 69 0.9347319999999347 29.0
# 70 0.934047999999934 19.0
# 71 0.9331839999999332 24.0
# 72 0.9326799999999327 14.0
# 73 0.931959999999932 20.0
# 74 0.930987999999931 27.0
# 75 0.9297279999999297 35.0
# 76 0.9281439999999281 44.0
# Average return over 25 episodes of playing: 224.6
# 77 0.9263439999999263 50.0
# 78 0.925047999999925 36.0
# 79 0.9243999999999244 18.0
# 80 0.9234999999999235 25.0
# 81 0.9228159999999228 19.0
# 82 0.922059999999922 21.0
# 83 0.9214839999999215 16.0
# 84 0.9209439999999209 15.0
# 85 0.9203679999999204 16.0
# 86 0.9199359999999199 12.0
# 87 0.9192159999999192 20.0
# 88 0.9178119999999178 39.0
# 89 0.9167679999999168 29.0
# 90 0.9161559999999161 17.0
# 91 0.9156879999999157 13.0
# 92 0.9148959999999149 22.0
# 93 0.9135999999999136 36.0
# 94 0.9128799999999129 20.0
# 95 0.9115839999999116 36.0
# 96 0.9112599999999113 9.0
# 97 0.9105399999999105 20.0
# Average return over 25 episodes of playing: 187.56
# 98 0.9094599999999095 30.0
# 99 0.9085959999999086 24.0
# 100 0.9076239999999076 27.0
# 101 0.907047999999907 16.0
# Average return training: 25.63
# 102 0.9062559999999062 22.0
# Average return training: 25.69
# 103 0.9056799999999057 16.0
# Average return training: 25.74
# 104 0.9051039999999051 16.0
# Average return training: 25.71
# 105 0.9047439999999047 10.0
# Average return training: 25.53
# 106 0.9034479999999034 36.0
# Average return training: 25.66
# 107 0.9022959999999023 32.0
# Average return training: 25.82
# 108 0.9017199999999017 16.0
# Average return training: 25.52
# 109 0.9010719999999011 18.0
# Average return training: 25.48
# 110 0.9005679999999006 14.0
# Average return training: 25.37
# 111 0.9001719999999002 11.0
# Average return training: 25.33
# 112 0.8993439999998993 23.0
# Average return training: 25.44
# 113 0.8978679999998979 41.0
# Average return training: 25.42
# 114 0.8966079999998966 35.0
# Average return training: 25.36
# 115 0.8958159999998958 22.0
# Average return training: 25.23
# 116 0.895059999999895 21.0
# Average return training: 25.19
# 117 0.8943039999998943 21.0
# Average return training: 25.23
# 118 0.8939439999998939 10.0
# Average return training: 25.11
# 119 0.8926479999998926 36.0
# Average return training: 25.34
# Average return over 25 episodes of playing: 240.68
# 120 0.8917479999998917 25.0
# Average return training: 25.4
# 121 0.8906319999998906 31.0
# Average return training: 25.56
# 122 0.8896959999998897 26.0
# Average return training: 25.57
# 123 0.8891199999998891 16.0
# Average return training: 25.59
# 124 0.8884719999998885 18.0
# Average return training: 25.59
# 125 0.8878959999998879 16.0
# Average return training: 25.63
# 126 0.886995999999887 25.0
# Average return training: 25.51
# 127 0.8853399999998853 46.0
# Average return training: 25.66
# 128 0.8841879999998842 32.0
# Average return training: 25.59
# 129 0.8834319999998834 21.0
# Average return training: 25.66
# 130 0.8826759999998827 21.0
# Average return training: 25.58
# 131 0.882027999999882 18.0
# Average return training: 25.53
# 132 0.8806959999998807 37.0
# Average return training: 25.72
# 133 0.8793279999998793 38.0
# Average return training: 25.99
# 134 0.8786439999998786 19.0
# Average return training: 25.91
# 135 0.877995999999878 18.0
# Average return training: 25.8
# 136 0.8767359999998767 35.0
# Average return training: 26.02
# 137 0.8763039999998763 12.0
# Average return training: 25.49
# 138 0.8754399999998754 24.0
# Average return training: 25.57
# Average return over 25 episodes of playing: 89.08
# 139 0.8738919999998739 43.0
# Average return training: 25.85
# 140 0.8732439999998732 18.0
# Average return training: 25.64
# 141 0.8721999999998722 29.0
# Average return training: 25.36
# 142 0.8711919999998712 28.0
# Average return training: 25.44
# 143 0.8703999999998704 22.0
# Average return training: 25.4
# 144 0.8697879999998698 17.0
# Average return training: 25.33
# 145 0.8691759999998692 17.0
# Average return training: 25.36
# 146 0.8674479999998674 48.0
# Average return training: 25.73
# 147 0.8658999999998659 43.0
# Average return training: 25.47
# 148 0.8650719999998651 23.0
# Average return training: 25.61
# 149 0.8645319999998645 15.0
# Average return training: 25.5
# 150 0.8641719999998642 10.0
# Average return training: 25.52
# 151 0.8619039999998619 63.0
# Average return training: 25.78
# 152 0.8613639999998614 15.0
# Average return training: 25.81
# 153 0.8608959999998609 13.0
# Average return training: 25.81
# 154 0.8604279999998604 13.0
# Average return training: 25.53
# 155 0.85999599999986 12.0
# Average return training: 25.51
# 156 0.8585559999998585 40.0
# Average return training: 25.72
# 157 0.857979999999858 16.0
# Average return training: 25.35
# 158 0.8575839999998576 11.0
# Average return training: 25.18
# 159 0.8568279999998568 21.0
# Average return training: 24.86
# 160 0.8561079999998561 20.0
# Average return training: 24.94
# Average return over 25 episodes of playing: 142.4
# 161 0.8551719999998552 26.0
# Average return training: 24.96
# 162 0.8546679999998547 14.0
# Average return training: 24.87
# 163 0.8531919999998532 41.0
# Average return training: 25.05
# 164 0.8522559999998522 26.0
# Average return training: 24.47
# 165 0.8518599999998518 11.0
# Average return training: 24.39
# 166 0.8512119999998512 18.0
# Average return training: 24.13
# 167 0.8504199999998504 22.0
# Average return training: 23.84
# 168 0.8498079999998498 17.0
# Average return training: 23.88
# 169 0.8493399999998493 13.0
# Average return training: 23.72
# 170 0.8488719999998489 13.0
# Average return training: 23.66
# 171 0.8483319999998483 15.0
# Average return training: 23.57
# 172 0.8476839999998477 18.0
# Average return training: 23.61
# 173 0.8472519999998472 12.0
# Average return training: 23.53
# 174 0.8466399999998466 17.0
# Average return training: 23.43
# 175 0.8458119999998458 23.0
# Average return training: 23.31
# 176 0.8447679999998448 29.0
# Average return training: 23.16
# 177 0.8438319999998438 26.0
# Average return training: 22.92
# 178 0.8431839999998432 18.0
# Average return training: 22.74
# 179 0.8423559999998423 23.0
# Average return training: 22.79
# 180 0.8416719999998417 19.0
# Average return training: 22.73
# 181 0.8411679999998412 14.0
# Average return training: 22.68
# 182 0.8402679999998403 25.0
# Average return training: 22.72
# 183 0.8381799999998382 58.0
# Average return training: 23.14
# Average return over 25 episodes of playing: 69.52
# 184 0.8374239999998374 21.0
# Average return training: 23.2
# 185 0.8367759999998368 18.0
# Average return training: 23.22
# 186 0.836055999999836 20.0
# Average return training: 23.3
# 187 0.8351199999998351 26.0
# Average return training: 23.36
# 188 0.8338239999998338 36.0
# Average return training: 23.33
# 189 0.8332479999998332 16.0
# Average return training: 23.2
# 190 0.8326719999998327 16.0
# Average return training: 23.19
# 191 0.832059999999832 17.0
# Average return training: 23.23
# 192 0.8304759999998305 44.0
# Average return training: 23.45
# 193 0.8298639999998298 17.0
# Average return training: 23.26
# 194 0.8267319999998267 87.0
# Average return training: 23.93
# 195 0.8260839999998261 18.0
# Average return training: 23.75
# 196 0.8251839999998252 25.0
# Average return training: 23.91
# 197 0.8246439999998246 15.0
# Average return training: 23.86
# 198 0.8234919999998235 32.0
# Average return training: 23.88
# 199 0.8225559999998225 26.0
# Average return training: 23.9
# 200 0.8208279999998208 48.0
# Average return training: 24.11
# 201 0.8201079999998201 20.0
# Average return training: 24.15
# Average return over 25 episodes of playing: 71.84
# 202 0.8197119999998197 11.0
# Average return training: 24.04
# 203 0.818019999999818 47.0
# Average return training: 24.35
# 204 0.8172279999998172 22.0
# Average return training: 24.41
# 205 0.8168319999998168 11.0
# Average return training: 24.42
# 206 0.8161479999998161 19.0
# Average return training: 24.25
# 207 0.8145639999998145 44.0
# Average return training: 24.37
# 208 0.8141679999998142 11.0
# Average return training: 24.32
# 209 0.8135559999998135 17.0
# Average return training: 24.31
# 210 0.8129079999998129 18.0
# Average return training: 24.35
# 211 0.8115399999998115 38.0
# Average return training: 24.62
# 212 0.8104239999998104 31.0
# Average return training: 24.7
# 213 0.8097759999998098 18.0
# Average return training: 24.47
# 214 0.8089119999998089 24.0
# Average return training: 24.36
# 215 0.8079399999998079 27.0
# Average return training: 24.41
# 216 0.8062119999998062 48.0
# Average return training: 24.68
# 217 0.8055639999998055 18.0
# Average return training: 24.65
# 218 0.804987999999805 16.0
# Average return training: 24.71
# 219 0.8045919999998046 11.0
# Average return training: 24.46
# 220 0.8033319999998033 35.0
# Average return training: 24.56
# 221 0.8023959999998024 26.0
# Average return training: 24.51
# Average return over 25 episodes of playing: 78.64
# 222 0.8017839999998018 17.0
# Average return training: 24.42
# 223 0.8011359999998011 18.0
# Average return training: 24.44
# 224 0.7987959999997988 65.0
# Average return training: 24.91
# 225 0.798039999999798 21.0
# ...
# 371 0.6541479999996541 34.0
# Average return training: 28.21
# 372 0.6536079999996536 15.0
# Average return training: 27.93
# 373 0.6522399999996522 38.0
# Average return training: 28.17
# 374 0.651015999999651 34.0
# Average return training: 28.36
# 375 0.647055999999647 110.0
# Average return training: 29.33
# 376 0.6437799999996437 91.0
# Average return training: 30.03
# 377 0.6424119999996424 38.0
# Average return training: 29.61
# 378 0.642051999999642 10.0
# Average return training: 29.42
# 379 0.6416199999996416 12.0
# Average return training: 29.4
# 380 0.6404679999996404 32.0
# Average return training: 29.47
# Average return over 25 episodes of playing: 500.0
# 381 0.6390999999996391 38.0
# Average return training: 29.62
# 382 0.6359319999996359 88.0
# Average return training: 30.36
# 383 0.6351039999996351 23.0
# Average return training: 30.27
# 384 0.6332679999996332 51.0
# Average return training: 30.59
# 385 0.632043999999632 34.0
# Average return training: 30.68
# 386 0.6311799999996311 24.0
# Average return training: 30.73
# 387 0.6299199999996299 35.0
# Average return training: 30.74
# 388 0.6294519999996294 13.0
# Average return training: 30.6
# 389 0.6276519999996276 50.0
# Average return training: 30.95
# 390 0.6271479999996271 14.0
# Average return training: 30.99
# 391 0.6261039999996261 29.0
# Average return training: 31.16
# 392 0.6256719999996256 12.0
# Average return training: 31.06
# Average return over 25 episodes of playing: 129.28
# 393 0.6185079999996185 199.0
# Average return training: 32.89
# 394 0.6164919999996165 56.0
# Average return training: 33.27
# 395 0.614979999999615 42.0
# Average return training: 33.51
# 396 0.6144399999996144 15.0
# Average return training: 33.02
# 397 0.6108039999996108 101.0
# Average return training: 33.83
# 398 0.6099399999996099 24.0
# Average return training: 33.89
# 399 0.6084999999996085 40.0
# Average return training: 34.18
# 400 0.6071679999996071 37.0
# Average return training: 33.92
# 401 0.6066639999996066 14.0
# Average return training: 33.84
# 402 0.606087999999606 16.0
# Average return training: 33.85
# 403 0.6054759999996054 17.0
# Average return training: 33.88
# 404 0.6049359999996049 15.0
# Average return training: 33.82
# 405 0.604035999999604 25.0
# Average return training: 33.39
# Average return over 25 episodes of playing: 266.08
# 406 0.6033879999996034 18.0
# Average return training: 33.22
# 407 0.6028839999996028 14.0
# Average return training: 33.16
# 408 0.6023079999996023 16.0
# Average return training: 32.07
# 409 0.6013359999996013 27.0
# Average return training: 32.19
# 410 0.6005079999996005 23.0
# Average return training: 32.3
# 411 0.5998599999995998 18.0
# Average return training: 32.3
# 412 0.5988519999995988 28.0
# Average return training: 32.06
# 413 0.5962599999995962 72.0
# Average return training: 32.51
# 414 0.5956839999995956 16.0
# Average return training: 32.43
# 415 0.5946759999995946 28.0
# Average return training: 32.41
# 416 0.5940999999995941 16.0
# Average return training: 32.42
# 417 0.5935239999995935 16.0
# Average return training: 32.14
# 418 0.591075999999591 68.0
# Average return training: 32.59
# 419 0.59006799999959 28.0
# Average return training: 32.6
# 420 0.5886999999995887 38.0
# Average return training: 32.57
# 421 0.5871519999995871 43.0
# Average return training: 32.79
# Average return over 25 episodes of playing: 271.68
# 422 0.5859279999995859 34.0
# Average return training: 32.36
# 423 0.5854239999995854 14.0
# Average return training: 32.36
# 424 0.5845959999995846 23.0
# Average return training: 32.27
# 425 0.5811759999995811 95.0
# Average return training: 33.12
# 426 0.5786559999995786 70.0
# Average return training: 33.64
# 427 0.575055999999575 100.0
# Average return training: 34.44
# 428 0.5731839999995731 52.0
# Average return training: 34.83
# 429 0.5727519999995727 12.0
# Average return training: 34.82
# 430 0.5718159999995718 26.0
# Average return training: 34.69
# 431 0.5702679999995702 43.0
# Average return training: 35.0
# Average return over 25 episodes of playing: 256.68
# 432 0.5667039999995667 99.0
# Average return training: 35.79
# 433 0.561987999999562 131.0
# Average return training: 36.89
# 434 0.5615559999995615 12.0
# Average return training: 36.73
# 435 0.561087999999561 13.0
# Average return training: 36.74
# 436 0.5561919999995562 136.0
# Average return training: 37.97
# 437 0.5557959999995558 11.0
# Average return training: 37.77
# 438 0.5548959999995549 25.0
# Average return training: 37.86
# 439 0.5536359999995536 35.0
# Average return training: 37.78
# 440 0.5504679999995504 88.0
# Average return training: 38.26
# Average return over 25 episodes of playing: 101.28
# 441 0.5497479999995497 20.0
# Average return training: 37.91
# 442 0.548019999999548 48.0
# Average return training: 38.1
# 443 0.545067999999545 82.0
# Average return training: 38.76
# 444 0.5443119999995443 21.0
# Average return training: 38.74
# 445 0.5434119999995434 25.0
# Average return training: 38.83
# 446 0.5428359999995428 16.0
# Average return training: 38.75
# 447 0.5423319999995423 14.0
# Average return training: 38.39
# 448 0.5418279999995418 14.0
# Average return training: 38.36
# 449 0.5413599999995413 13.0
# Average return training: 38.38
# 450 0.5386239999995386 76.0
# Average return training: 38.98
# 451 0.5379039999995379 20.0
# Average return training: 38.93
# 452 0.5367159999995367 33.0
# Average return training: 39.09
# 453 0.5346999999995347 56.0
# Average return training: 39.5
# 454 0.5322159999995322 69.0
# Average return training: 39.62
# Average return over 25 episodes of playing: 104.8
# 455 0.5316039999995316 17.0
# Average return training: 39.05
# 456 0.5278239999995278 105.0
# Average return training: 39.61
# 457 0.5272119999995272 17.0
# Average return training: 39.04
# 458 0.526059999999526 32.0
# Average return training: 39.15
# 459 0.5254479999995254 17.0
# Average return training: 39.14
# 460 0.5226399999995226 78.0
# Average return training: 39.67
# 461 0.5203719999995203 63.0
# Average return training: 40.01
# 462 0.5199039999995199 13.0
# Average return training: 39.55
# 463 0.5163759999995163 98.0
# Average return training: 40.38
# 464 0.5151159999995151 35.0
# Average return training: 40.54
# Average return over 25 episodes of playing: 115.8
# 465 0.512055999999512 85.0
# Average return training: 41.15
# 466 0.5085639999995085 97.0
# Average return training: 41.79
# 467 0.5079879999995079 16.0
# Average return training: 41.8
# 468 0.5071599999995071 23.0
# Average return training: 41.91
# 469 0.5067639999995067 11.0
# Average return training: 41.92
# 470 0.5061879999995061 16.0
# Average return training: 41.44
# 471 0.5055039999995055 19.0
# Average return training: 41.29
# 472 0.5047119999995047 22.0
# Average return training: 41.36
# 473 0.504063999999504 18.0
# Average return training: 41.16
# 474 0.5035599999995035 14.0
# Average return training: 40.96
# 475 0.5028399999995028 20.0
# Average return training: 40.06
# 476 0.4991319999995005 103.0
# Average return training: 40.18
# 477 0.4987359999995007 11.0
# Average return training: 39.91
# 478 0.49808799999950104 18.0
# Average return training: 39.99
# 479 0.49718799999950153 25.0
# Average return training: 40.12
# 480 0.4966479999995018 15.0
# Average return training: 39.95
# 481 0.49625199999950204 11.0
# Average return training: 39.68
# Average return over 25 episodes of playing: 121.36
# 482 0.49308399999950375 88.0
# Average return training: 39.68
# 483 0.490815999999505 63.0
# Average return training: 40.08
# 484 0.4904199999995052 11.0
# Average return training: 39.68
# 485 0.48660399999950726 106.0
# Average return training: 40.4
# 486 0.4842999999995085 64.0
# Average return training: 40.8
# 487 0.4837599999995088 15.0
# Average return training: 40.6
# 488 0.4790079999995114 132.0
# Average return training: 41.79
# Average return over 25 episodes of playing: 137.12
# 489 0.4771719999995124 51.0
# Average return training: 41.8
# 490 0.4765959999995127 16.0
# Average return training: 41.82
# 491 0.4758759999995131 20.0
# Average return training: 41.73
# 492 0.47555199999951325 9.0
# Average return training: 41.7
# 493 0.47465199999951374 25.0
# Average return training: 39.96
# 494 0.4737879999995142 24.0
# Average return training: 39.64
# 495 0.4717359999995153 57.0
# Average return training: 39.79
# 496 0.4700799999995162 46.0
# Average return training: 40.1
# 497 0.46943199999951657 18.0
# Average return training: 39.27
# 498 0.4655079999995187 109.0
# Average return training: 40.12
# 499 0.46507599999951893 12.0
# Average return training: 39.84
# 500 0.4644279999995193 18.0
# Average return training: 39.65
# 501 0.4634199999995198 28.0
# Average return training: 39.79
# Average return over 25 episodes of playing: 154.12
# 502 0.45927999999952207 115.0
# Average return training: 40.78
# 503 0.4586679999995224 17.0
# Average return training: 40.78
# 504 0.45823599999952264 12.0
# Average return training: 40.75
# 505 0.457587999999523 18.0
# Average return training: 40.68
# 506 0.4572279999995232 10.0
# Average return training: 40.6
# 507 0.4544199999995247 78.0
# Average return training: 41.24
# 508 0.45377199999952506 18.0
# Average return training: 41.26
# 509 0.4496679999995273 114.0
# Average return training: 42.13
# 510 0.44912799999952757 15.0
# Average return training: 42.05
# 511 0.4485519999995279 16.0
# Average return training: 42.03
# 512 0.44790399999952824 18.0
# Average return training: 41.93
# 513 0.44711199999952866 22.0
# Average return training: 41.43
# 514 0.4461399999995292 27.0
# Average return training: 41.54
# 515 0.4422879999995313 107.0
# Average return training: 42.33
# Average return over 25 episodes of playing: 136.68
# 516 0.44124399999953184 29.0
# Average return training: 42.46
# 517 0.43717599999953405 113.0
# Average return training: 43.43
# 518 0.4330359999995363 115.0
# Average return training: 43.9
# 519 0.42828399999953887 132.0
# Average return training: 44.94
# 520 0.42619599999954 58.0
# Average return training: 45.14
# 521 0.4252239999995405 27.0
# Average return training: 44.98
# Average return over 25 episodes of playing: 134.48
# 522 0.4204719999995431 132.0
# Average return training: 45.96
# 523 0.42003999999954333 12.0
# Average return training: 45.94
# 524 0.41870799999954406 37.0
# Average return training: 46.08
# 525 0.4175199999995447 33.0
# Average return training: 45.46
# 526 0.41629599999954536 34.0
# Average return training: 45.1
# 527 0.4146039999995463 47.0
# Average return training: 44.57
# 528 0.41395599999954663 18.0
# Average return training: 44.23
# 529 0.4112919999995481 74.0
# Average return training: 44.85
# 530 0.4099959999995488 36.0
# Average return training: 44.95
# 531 0.4084839999995496 42.0
# Average return training: 44.94
# Average return over 25 episodes of playing: 472.6
# 532 0.4056759999995511 78.0
# Average return training: 44.73
# 533 0.40509999999955143 16.0
# Average return training: 43.58
# 534 0.40319199999955246 53.0
# Average return training: 43.99
# 535 0.3983319999995551 135.0
# Average return training: 45.21
# 536 0.3945879999995571 104.0
# Average return training: 44.89
# 537 0.39401199999955744 16.0
# Average return training: 44.94
# 538 0.39325599999955785 21.0
# Average return training: 44.9
# 539 0.39253599999955824 20.0
# Average return training: 44.75
# 540 0.39199599999955853 15.0
# Average return training: 44.02
# 541 0.39138399999955886 17.0
# Average return training: 43.99
# 542 0.3897999999995597 44.0
# Average return training: 43.95
# 543 0.38897199999956017 23.0
# Average return training: 43.36
# Average return over 25 episodes of playing: 110.4
# 544 0.3851919999995622 105.0
# Average return training: 44.2
# 545 0.38454399999956257 18.0
# Average return training: 44.13
# 546 0.38382399999956296 20.0
# Average return training: 44.17
# 547 0.3832119999995633 17.0
# Average return training: 44.2
# 548 0.3824199999995637 22.0
# Average return training: 44.28
# 549 0.3813039999995643 31.0
# Average return training: 44.46
# 550 0.38029599999956487 28.0
# Average return training: 43.98
# 551 0.3796479999995652 18.0
# Average return training: 43.96
# 552 0.37885599999956565 22.0
# Average return training: 43.85
# 553 0.3784239999995659 12.0
# Average return training: 43.41
# 554 0.37759599999956633 23.0
# Average return training: 42.95
# 555 0.37719999999956655 11.0
# Average return training: 42.89
# 556 0.3737439999995684 96.0
# Average return training: 42.8
# 557 0.37219599999956926 43.0
# Average return training: 43.06
# 558 0.3711879999995698 28.0
# Average return training: 43.02
# Average return over 25 episodes of playing: 99.16
# 559 0.3663999999995724 133.0
# Average return training: 44.18
# 560 0.36128799999957517 142.0
# Average return training: 44.82
# 561 0.35981199999957597 41.0
# Average return training: 44.6
# 562 0.3591639999995763 18.0
# Average return training: 44.65
# 563 0.35815599999957687 28.0
# Average return training: 43.95
# 564 0.3528999999995797 146.0
# Average return training: 45.06
# Average return over 25 episodes of playing: 147.88
# 565 0.34937199999958163 98.0
# Average return training: 45.19
# 566 0.3484719999995821 25.0
# Average return training: 44.47
# 567 0.34803999999958235 12.0
# Average return training: 44.43
# 568 0.3446199999995842 95.0
# Average return training: 45.15
# 569 0.3411639999995861 96.0
# Average return training: 46.0
# 570 0.335763999999589 150.0
# Average return training: 47.34
# 571 0.33489999999958947 24.0
# Average return training: 47.39
# Average return over 25 episodes of playing: 112.64
# 572 0.3311559999995915 104.0
# Average return training: 48.21
# 573 0.3245319999995951 184.0
# Average return training: 49.87
# 574 0.32384799999959546 19.0
# Average return training: 49.92
# 575 0.3231999999995958 18.0
# Average return training: 49.9
# 576 0.3223359999995963 24.0
# Average return training: 49.11
# 577 0.31722399999959905 142.0
# Average return training: 50.42
# 578 0.31650399999959944 20.0
# Average return training: 50.44
# Average return over 25 episodes of playing: 93.28
# 579 0.3149199999996003 44.0
# Average return training: 50.63
# 580 0.31441599999960057 14.0
# Average return training: 50.62
# 581 0.31095999999960244 96.0
# Average return training: 51.47
# 582 0.3065679999996048 122.0
# Average return training: 51.81
# 583 0.30573999999960527 23.0
# Average return training: 51.41
# 584 0.3021759999996072 99.0
# Average return training: 52.29
# 585 0.2980719999996094 114.0
# Average return training: 52.37
# Average return over 25 episodes of playing: 103.04
# 586 0.29749599999960974 16.0
# Average return training: 51.89
# 587 0.29382399999961173 102.0
# Average return training: 52.76
# 588 0.29303199999961216 22.0
# Average return training: 51.66
# 589 0.29234799999961253 19.0
# Average return training: 51.34
# 590 0.291519999999613 23.0
# Average return training: 51.41
# 591 0.29029599999961364 34.0
# Average return training: 51.55
# 592 0.28399599999961705 175.0
# Average return training: 53.21
# Average return over 25 episodes of playing: 381.92
# 593 0.2747079999996221 258.0
# Average return training: 55.54
# 594 0.2741679999996224 15.0
# Average return training: 55.45
# 595 0.27348399999962275 19.0
# Average return training: 55.07
# Average return over 25 episodes of playing: 127.52
# 596 0.2602719999996299 367.0
# Average return training: 58.28
# 597 0.25947999999963034 22.0
# Average return training: 58.32
# 598 0.24954399999963536 276.0
# Average return training: 59.99
# 599 0.2488239999996352 20.0
# Average return training: 60.07
# 600 0.24803199999963502 22.0
# Average return training: 60.11
# 601 0.24421599999963414 106.0
# Average return training: 60.89
# Average return over 25 episodes of playing: 411.6
# 602 0.24108399999963342 87.0
# Average return training: 60.61
# 603 0.23683599999963245 118.0
# Average return training: 61.62
# 604 0.22949199999963077 204.0
# Average return training: 63.54
# Average return over 25 episodes of playing: 439.36
# 605 0.22412799999962954 149.0
# Average return training: 64.85
# 606 0.21116799999962657 360.0
# Average return training: 68.35
# Average return over 25 episodes of playing: 421.56
# 607 0.1951479999996229 445.0
# Average return training: 72.02
# Average return over 25 episodes of playing: 500.0
# 608 0.18571599999962074 262.0
# Average return training: 74.46
# 609 0.1851399999996206 16.0
# Average return training: 73.48
# 610 0.18319599999962016 54.0
# Average return training: 73.87
# 611 0.18211599999961992 30.0
# Average return training: 74.01
# Average return over 25 episodes of playing: 500.0
# 612 0.1641159999996158 500.0
# Average return training: 78.83
# Average return over 25 episodes of playing: 500.0
# 613 0.14611599999961167 500.0
# Average return training: 83.61
# Average return over 25 episodes of playing: 487.32
# 614 0.12811599999960754 500.0
# Average return training: 88.34
# Average return over 100 episodes of trained agent: 496.64
