# %%
# Importing needed librarys
import torch
import torch.nn as nn
import gym
import numpy as np
import random
import wandb
from copy import deepcopy
import statistics

# %%
# Setting seeds
def make_deterministic(seed):
  torch.manual_seed(seed)
  random.seed(seed)
  np.random.seed(seed)

# %%
# Building a class for the neural network
class Neural_Network(nn.Module):
  def __init__(self, in_dim, out_dim, hidden_dim):
        super(Neural_Network, self).__init__()
        self.input_layer = nn.Linear(in_dim, hidden_dim[0])
        self.hidden_layer = nn.Linear(hidden_dim[0], hidden_dim[1])
        self.output_layer = nn.Linear(hidden_dim[1], out_dim)
       
  def forward (self, x, activation_function = nn.ReLU()):
    x = activation_function(self.input_layer(x))
    x = activation_function(self.hidden_layer(x))
    output = self.output_layer(x)
    return output

# %%
# Defining function for epsilon greedy actions
def eps_greedy(state, online_model, eps):
  with torch.no_grad():
    if (np.random.rand() > eps):
      value, inds  = torch.max(online_model(state), dim=0)
      return inds.item()
    else:
      action = np.random.choice(env.action_space.n)
      return action

# %%
 # Defining function for playing during and after training to obtain performance of the agent
def play(episodes, step, end, envs):
  y = 0
  x = 0
  returns = []

  for i in range(0, episodes):
    j = i+1
    memory_states = [] 
    memory_actions = [] 
    memory_rewards = [] 
    memory_terminal = [] 
    memory_states_next = []

    state = envs.reset()
    while True:
      action = eps_greedy(state = torch.tensor(state).float() , online_model = online_model, eps = -1)
      state_next, reward, done, _ = envs.step(action)
      memory_rewards.append(reward)
      memory_terminal.append(done)
      state = state_next

      if done:
        x = sum(memory_rewards)
        state = envs.reset()
        returns.append(x)
        break

  if end:
    avg_return = sum(returns[-100:]) / 100
    print("Average return over 100 episodes of trained agent:", avg_return)
  else:
    avg_return = sum(returns[-25:]) / 25
    wandb.log({"Average return over 25 episodes of playing": avg_return,"step": step})
    print("Average return over 25 episodes of playing:", avg_return)

  return avg_return

# %%
##### Prioritized Double DQN Algorithm ###########

# Seeds for repeatable training results
SEEDS = (12, 34, 56)

# Creating two environments: One for training and for playing
env = gym.make("CartPole-v1")
env2 = gym.make("CartPole-v1")

# Looping over different seeds for training different agents
for seed in SEEDS:
  make_deterministic(seed)
  print("SEED:", seed)
  wandb.init(project="Prior-Exp-Replay-CartPole", entity="raisa")
  config = wandb.config

  # Defining hyperparameters
  gamma = 0.99 # gamma
  eps_max = 1 # maximum value for epsilon
  eps_min = 0.1 # minimum value for epsilon
  eps_decay = (1-0.1) / 25000 # decaying factor for epsilon
  learning_rate = 0.0025 # learning rate
  batch_size = 64 # batch size
  num_episodes = 1000 # maximum number of episodes
  min_memory = 100 # size of replay memory at start of training
  max_memory = 1000 # maximum size of replay memory
  hidden_dims = [128, 64] # size of hidden layers in the neural network
  act_period =  150 # update frequency of target neural network
  beta = 0.5 # needed for calculating prioritization weights
  l = 0.02 # ensures that states with td error of 0 are visited
  alpha = 0.8 # specifies degree of prioritization

  # Logging hyperparameters
  config.learning_rate = learning_rate
  config.gamma = gamma
  config.batch_size = batch_size
  config.num_episodes = num_episodes
  config.max_memory = max_memory
  config.min_memory = min_memory
  config.hidden_dim = hidden_dims
  config.act_period = act_period
  config.eps_max = eps_max
  config.eps_min = eps_min
  config.eps_decay = eps_decay
  config.beta = beta
  config.l = l
  config.alpha = alpha
  config.seed = seed

  # Setting the seed for the environments
  env.seed(seed)
  env.action_space.seed(seed)
  env2.seed(seed)
  env2.action_space.seed(seed)

  # Initialisation replay memory
  memory_states = [] 
  memory_actions = [] 
  memory_rewards = [] 
  memory_terminal = []
  memory_td_error = []
  memory_states_next = []
  reward_durch = []
  reward_werte = []

  # Initializing list for average returns during training
  returns_train = []
  # Initializing list for average returns during playing
  returns_play = []

  # Creating neural networks and setting optimizer
  online_model = (Neural_Network(in_dim = int(np.prod(env.observation_space.shape)), out_dim = env.action_space.n, hidden_dim=hidden_dims)) 
  target_model = (Neural_Network(in_dim = int(np.prod(env.observation_space.shape)), out_dim = env.action_space.n, hidden_dim=hidden_dims)) 
  optimizer = torch.optim.Adam(online_model.parameters(), lr=learning_rate)
  target_model = deepcopy(online_model) 

  # Storing minimum experiences in replay memory
  state = env.reset()
  for step in range(0, min_memory):
    action = env.action_space.sample()
    state_next, reward, done, _ = env.step(action)
    memory_actions.append(action)
    memory_states.append(state)
    memory_states_next.append(state_next)
    memory_rewards.append(reward)
    memory_terminal.append(done)
    memory_td_error.append(0)
    state = state_next

    if done:
      state = env.reset()

  epsi = eps_max
  step = 0

  # Training the agent for number of episodes
  for episode in range(0, num_episodes):
    state = env.reset()
    reward_sum = 0
    while True:
      step += 1

      # Deleting first element of replay memory if max_memory length is reached
      if(len(memory_states) > max_memory):
        memory_actions.pop(0)
        memory_states.pop(0)
        memory_states_next.pop(0)
        memory_rewards.pop(0)
        memory_terminal.pop(0)
        memory_td_error.pop(0)

      # Taking epsilon greedy action and storing experience in replay memory
      epsi = max(epsi - eps_decay, eps_min)
      action = eps_greedy(state = torch.tensor(state).float() , online_model = online_model, eps = epsi)
      state_next, reward, done, _ = env.step(action)
      td_error = max(memory_td_error)
      memory_actions.append(action)
      memory_states.append(state)
      memory_states_next.append(state_next)
      memory_rewards.append(reward)
      memory_terminal.append(done)
      memory_td_error.append(td_error)
      state = state_next

      reward_sum+=reward

      # Calculating the likelihood of choosing experiences and the weights of experiences
      probs = [z + l for z in memory_td_error]
      new_probs = [pow(z,alpha) for z in probs]
      sum_probs = sum(new_probs)
      choose_probs = [(z/sum_probs) for z in new_probs]
      weights = [(len(memory_states) * z) ** -beta for z in choose_probs]
      sum_weights = sum(weights)
      norm_weights = [(z/sum_weights) for z in weights]
      
      # Selecting prioritized batch of experiences
      rand_index = np.random.choice(len(memory_states_next), size=batch_size, replace=False, p = choose_probs)
      batch_states = torch.tensor(np.array(memory_states)[rand_index], dtype=torch.float32) 
      batch_states_next = torch.tensor(np.array(memory_states_next)[rand_index], dtype=torch.float32) 
      batch_rewards = torch.tensor(np.array(memory_rewards)[rand_index], dtype=torch.float32) 
      batch_actions = torch.tensor(np.array(memory_actions)[rand_index], dtype=torch.int64) 
      batch_terminal = torch.tensor(np.array(memory_terminal)[rand_index], dtype=torch.int64) 
      batch_td_error = torch.tensor(np.array(memory_td_error)[rand_index],dtype=torch.float32) 

      # Calculating q-values for training
      with torch.no_grad():
        # Calculating q-values for next possible states
        q_values_next = online_model(batch_states_next)
        # Calculating indices of max q-values
        _, inds = torch.max(q_values_next,dim=1)
        inds = torch.reshape(input = inds, shape = (batch_size, 1))
        # Evaluating these actions with the help of the target model
        max_q_values_next = torch.gather(target_model(batch_states_next), 1, inds)
        max_q_values_next = (torch.reshape(max_q_values_next, (-1,)))
        # Calculating the target q-values 
        q_target = (batch_rewards + gamma * (1 - batch_terminal) * max_q_values_next)
    
      # Calculating the expected q-values
      q_exp = online_model(batch_states)
      batch_actions = torch.reshape(input = batch_actions, shape = (batch_size, 1))
      q_exp = torch.gather(input = q_exp, dim = 1, index = batch_actions)
      q_exp = (torch.reshape(q_exp, (-1,))) 

      # Calculating loss
      error = q_target - q_exp
      norm_weights = torch.tensor(norm_weights)
      loss = (norm_weights[rand_index] * error).pow(2).mean() 
      optimizer.zero_grad()

      # Backpropagating the loss
      loss.backward()

      # Taking an optimization step
      optimizer.step()

      # Updating td errors
      s = 0
      for x in rand_index:
        memory_td_error[x] = abs(error[s]).item()
        s += 1

      # Copying weights of the online network in the target network every act_period steps
      if step % act_period == 0:
        target_model = deepcopy(online_model) 

      # Playing every 500 steps to obtain the performance of the DQN agent
      if step % 500 == 0:
        avg_return_play = play(episodes = 25, step = step, end = False, envs = env2)
        returns_play.append(avg_return_play)
      
      # If an episode has to come to an end, reset environment and print the reward for the last episode
      if done:
        print(episode + 1, epsi, reward_sum)
        returns_train.append(reward_sum)

        # If episode > 100, then print the average reward for the last hundred episodes 
        if episode + 1  > 100:
          x = sum(returns_train[-100:])/100
          print("Average return training:", x)
          # Logging the training average return
          wandb.log({"Average return over 100 episodes of training": x, "episode": episode + 1})  
        break

      # If training steps >= 2500 and the agent has obtained an average reward of 475 during last 5 times of playing, end training
      if step >= 2500:
        if sum(returns_play[-5:]) / 5 >= 475:
          break

  # Playing after training to obtain end results
  play(episodes = 100, step = step, end = True, envs = env2)
# Out:
# SEED: 12
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                     Syncing run <strong><a href="https://wandb.ai/raisa/Prior-Exp-Replay-CartPole/runs/1i5qoosa" target="_blank">elated-bird-64</a></strong> to <a href="https://wandb.ai/raisa/Prior-Exp-Replay-CartPole" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 1 0.9994959999999995 14.0
# 2 0.9975519999999976 54.0
# 3 0.996975999999997 16.0
# 4 0.9963279999999963 18.0
# 5 0.9956079999999956 20.0
# 6 0.9952119999999952 11.0
# 7 0.9941679999999942 29.0
# 8 0.9935199999999935 18.0
# 9 0.9922959999999923 34.0
# 10 0.9916119999999916 19.0
# 11 0.9911439999999911 13.0
# 12 0.9903879999999904 21.0
# 13 0.9897759999999898 17.0
# 14 0.9888759999999889 25.0
# 15 0.988011999999988 24.0
# 16 0.9860679999999861 54.0
# 17 0.9857079999999857 10.0
# 18 0.9851679999999852 15.0
# 19 0.9844119999999844 21.0
# 20 0.9835839999999836 23.0
# 21 0.9829359999999829 18.0
# 22 0.9825399999999825 11.0
# Average return over 25 episodes of playing: 9.4
# 23 0.9818559999999819 19.0
# 24 0.981027999999981 23.0
# 25 0.9804159999999804 17.0
# 26 0.9796599999999797 21.0
# 27 0.9791559999999792 14.0
# 28 0.9787239999999787 12.0
# 29 0.9782919999999783 12.0
# 30 0.9772839999999773 28.0
# 31 0.9768519999999768 12.0
# 32 0.9746559999999747 61.0
# 33 0.9742959999999743 10.0
# 34 0.9731439999999731 32.0
# 35 0.9726759999999727 13.0
# 36 0.9718839999999719 22.0
# 37 0.9711639999999712 20.0
# 38 0.9705159999999705 18.0
# 39 0.9695079999999695 28.0
# 40 0.9686079999999686 25.0
# 41 0.9681759999999682 12.0
# 42 0.9673839999999674 22.0
# 43 0.9669159999999669 13.0
# 44 0.9658719999999659 29.0
# 45 0.964971999999965 25.0
# 46 0.9642159999999642 21.0
# Average return over 25 episodes of playing: 48.16
# 47 0.9636399999999636 16.0
# 48 0.9632439999999632 11.0
# 49 0.9624519999999624 22.0
# 50 0.9618039999999618 18.0
# 51 0.9610839999999611 20.0
# 52 0.9602559999999603 23.0
# 53 0.9589239999999589 37.0
# 54 0.9583119999999583 17.0
# 55 0.9576279999999576 19.0
# 56 0.9569439999999569 19.0
# 57 0.9561879999999562 21.0
# 58 0.9554319999999554 21.0
# 59 0.9547839999999548 18.0
# 60 0.9544239999999544 10.0
# 61 0.953955999999954 13.0
# 62 0.953055999999953 25.0
# 63 0.9525879999999526 13.0
# 64 0.9518679999999519 20.0
# 65 0.9504999999999505 38.0
# 66 0.9499239999999499 16.0
# 67 0.9491679999999492 21.0
# 68 0.9486279999999486 15.0
# 69 0.9477639999999478 24.0
# 70 0.946035999999946 48.0
# Average return over 25 episodes of playing: 485.56
# 71 0.9454959999999455 15.0
# 72 0.9449199999999449 16.0
# 73 0.9431559999999432 49.0
# 74 0.942003999999942 32.0
# 75 0.9413919999999414 17.0
# 76 0.940995999999941 11.0
# 77 0.9405279999999405 13.0
# 78 0.94005999999994 13.0
# 79 0.9396999999999397 10.0
# 80 0.9391959999999392 14.0
# 81 0.9384399999999384 21.0
# 82 0.9378999999999379 15.0
# 83 0.9365679999999366 37.0
# 84 0.9351999999999352 38.0
# 85 0.9337599999999338 40.0
# 86 0.9325359999999325 34.0
# 87 0.931959999999932 16.0
# 88 0.9314199999999314 15.0
# 89 0.930987999999931 12.0
# 90 0.9298359999999298 32.0
# 91 0.9281799999999282 46.0
# Average return over 25 episodes of playing: 295.0
# 92 0.9255519999999255 73.0
# 93 0.9242559999999242 36.0
# 94 0.9237159999999237 15.0
# 95 0.9224199999999224 36.0
# 96 0.9196839999999197 76.0
# 97 0.9193239999999193 10.0
# 98 0.9188919999999189 12.0
# 99 0.9183159999999183 16.0
# 100 0.9174879999999175 23.0
# 101 0.9167679999999168 20.0
# Average return training: 22.98
# 102 0.916011999999916 21.0
# Average return training: 22.65
# 103 0.9146079999999146 39.0
# Average return training: 22.88
# 104 0.9141759999999142 12.0
# Average return training: 22.82
# 105 0.9136359999999136 15.0
# Average return training: 22.77
# 106 0.9123399999999123 36.0
# Average return training: 23.02
# 107 0.9119079999999119 12.0
# Average return training: 22.85
# 108 0.9107199999999107 33.0
# Average return training: 23.0
# 109 0.91003599999991 19.0
# Average return training: 22.85
# Average return over 25 episodes of playing: 246.0
# 110 0.9093159999999093 20.0
# Average return training: 22.86
# 111 0.9078399999999078 41.0
# Average return training: 23.14
# 112 0.9074439999999074 11.0
# Average return training: 23.04
# 113 0.9063279999999063 31.0
# Average return training: 23.18
# 114 0.9048519999999048 41.0
# Average return training: 23.34
# 115 0.9025479999999025 64.0
# Average return training: 23.74
# 116 0.9021519999999021 11.0
# Average return training: 23.31
# 117 0.9014679999999015 19.0
# Average return training: 23.4
# 118 0.900963999999901 14.0
# Average return training: 23.39
# 119 0.9002799999999003 19.0
# Average return training: 23.37
# 120 0.8998119999998998 13.0
# Average return training: 23.27
# 121 0.8979039999998979 53.0
# Average return training: 23.62
# 122 0.8975799999998976 9.0
# Average return training: 23.6
# 123 0.8956359999998956 54.0
# Average return training: 23.95
# 124 0.8923599999998924 91.0
# Average return training: 24.63
# Average return over 25 episodes of playing: 153.24
# 125 0.8917119999998917 18.0
# Average return training: 24.64
# 126 0.8910999999998911 17.0
# Average return training: 24.6
# 127 0.8898039999998898 36.0
# Average return training: 24.82
# 128 0.8892999999998893 14.0
# Average return training: 24.84
# 129 0.8883999999998884 25.0
# Average return training: 24.97
# 130 0.8874279999998874 27.0
# Average return training: 24.96
# 131 0.8866359999998866 22.0
# Average return training: 25.06
# 132 0.8845119999998845 59.0
# Average return training: 25.04
# 133 0.8838999999998839 17.0
# Average return training: 25.11
# 134 0.8835399999998835 10.0
# Average return training: 24.89
# 135 0.8825679999998826 27.0
# Average return training: 25.03
# 136 0.8821719999998822 11.0
# Average return training: 24.92
# 137 0.8801919999998802 55.0
# Average return training: 25.27
# 138 0.8778879999998779 64.0
# Average return training: 25.73
# 139 0.8755479999998755 65.0
# Average return training: 26.1
# 140 0.8745399999998745 28.0
# Average return training: 26.13
# 141 0.874035999999874 14.0
# Average return training: 26.15
# Average return over 25 episodes of playing: 195.36
# 142 0.8727759999998728 35.0
# Average return training: 26.28
# 143 0.871983999999872 22.0
# Average return training: 26.37
# 144 0.8715879999998716 11.0
# Average return training: 26.19
# 145 0.871011999999871 16.0
# Average return training: 26.1
# 146 0.8705439999998705 13.0
# Average return training: 26.02
# 147 0.8700759999998701 13.0
# Average return training: 25.99
# 148 0.8688159999998688 35.0
# Average return training: 26.23
# 149 0.867051999999867 49.0
# Average return training: 26.5
# 150 0.8658639999998659 33.0
# Average return training: 26.65
# 151 0.8654319999998654 12.0
# Average return training: 26.57
# 152 0.8646039999998646 23.0
# Average return training: 26.57
# 153 0.864027999999864 16.0
# Average return training: 26.36
# 154 0.8632719999998633 21.0
# Average return training: 26.4
# 155 0.8600679999998601 89.0
# Average return training: 27.1
# 156 0.858987999999859 30.0
# Average return training: 27.21
# 157 0.8578719999998579 31.0
# Average return training: 27.31
# Average return over 25 episodes of playing: 147.52
# 158 0.8547399999998547 87.0
# Average return training: 27.97
# 159 0.8535159999998535 34.0
# Average return training: 28.13
# 160 0.8526879999998527 23.0
# Average return training: 28.26
# 161 0.8522919999998523 11.0
# Average return training: 28.24
# 162 0.851067999999851 34.0
# Average return training: 28.33
# 163 0.8488719999998489 61.0
# Average return training: 28.81
# 164 0.8481159999998481 21.0
# Average return training: 28.82
# 165 0.8476119999998476 14.0
# Average return training: 28.58
# 166 0.8468559999998468 21.0
# Average return training: 28.63
# 167 0.8455599999998455 36.0
# Average return training: 28.78
# 168 0.8449119999998449 18.0
# Average return training: 28.81
# 169 0.8437239999998437 33.0
# Average return training: 28.9
# 170 0.8430759999998431 18.0
# Average return training: 28.6
# 171 0.8425359999998425 15.0
# Average return training: 28.6
# 172 0.8414199999998414 31.0
# Average return training: 28.75
# 173 0.8406279999998406 22.0
# Average return training: 28.48
# 174 0.8397999999998398 23.0
# Average return training: 28.39
# 175 0.8387199999998387 30.0
# Average return training: 28.52
# Average return over 25 episodes of playing: 184.68
# 176 0.836991999999837 48.0
# Average return training: 28.89
# 177 0.8360919999998361 25.0
# Average return training: 29.01
# 178 0.8357319999998357 10.0
# Average return training: 28.98
# 179 0.8331039999998331 73.0
# Average return training: 29.61
# 180 0.8327079999998327 11.0
# Average return training: 29.58
# 181 0.8316999999998317 28.0
# Average return training: 29.65
# 182 0.8311239999998311 16.0
# Average return training: 29.66
# 183 0.8304399999998304 19.0
# Average return training: 29.48
# 184 0.8295039999998295 26.0
# Average return training: 29.36
# 185 0.8288199999998288 19.0
# Average return training: 29.15
# 186 0.8283879999998284 12.0
# Average return training: 28.93
# 187 0.827991999999828 11.0
# Average return training: 28.88
# 188 0.8271639999998271 23.0
# Average return training: 28.96
# 189 0.8266239999998266 15.0
# Average return training: 28.99
# 190 0.826011999999826 17.0
# Average return training: 28.84
# 191 0.8253279999998253 19.0
# Average return training: 28.57
# 192 0.8248599999998248 13.0
# Average return training: 27.97
# 193 0.8216559999998216 89.0
# Average return training: 28.5
# 194 0.8201799999998202 41.0
# Average return training: 28.76
# Average return over 25 episodes of playing: 168.0
# 195 0.819027999999819 32.0
# Average return training: 28.72
# 196 0.8177679999998178 35.0
# Average return training: 28.31
# 197 0.8162199999998162 43.0
# Average return training: 28.64
# 198 0.8151759999998152 29.0
# Average return training: 28.81
# 199 0.8143119999998143 24.0
# Average return training: 28.89
# 200 0.8134119999998134 25.0
# Average return training: 28.91
# 201 0.8112519999998112 60.0
# Average return training: 29.31
# 202 0.8104959999998105 21.0
# Average return training: 29.31
# 203 0.8087679999998088 48.0
# Average return training: 29.4
# 204 0.8082279999998082 15.0
# Average return training: 29.43
# 205 0.8076519999998076 16.0
# Average return training: 29.44
# 206 0.8055639999998055 58.0
# Average return training: 29.66
# 207 0.8049519999998049 17.0
# Average return training: 29.71
# 208 0.8044119999998044 15.0
# Average return training: 29.53
# 209 0.802971999999803 40.0
# Average return training: 29.74
# 210 0.8023239999998023 18.0
# Average return training: 29.72
# Average return over 25 episodes of playing: 138.36
# 211 0.8018559999998018 13.0
# Average return training: 29.44
# 212 0.799047999999799 78.0
# Average return training: 30.11
# 213 0.7982559999997982 22.0
# Average return training: 30.02
# 214 0.7971759999997972 30.0
# Average return training: 29.91
# 215 0.7965639999997965 17.0
# Average return training: 29.44
# 216 0.796059999999796 14.0
# Average return training: 29.47
# 217 0.7953399999997953 20.0
# Average return training: 29.48
# 218 0.7931799999997932 60.0
# Average return training: 29.94
# 219 0.7906959999997907 69.0
# Average return training: 30.44
# 220 0.7895439999997895 32.0
# Average return training: 30.63
# 221 0.7883919999997884 32.0
# Average return training: 30.42
# 222 0.7872039999997872 33.0
# Average return training: 30.66
# 223 0.7868439999997868 10.0
# Average return training: 30.22
# 224 0.7861239999997861 20.0
# Average return training: 29.51
# 225 0.7841439999997841 55.0
# Average return training: 29.88
# Average return over 25 episodes of playing: 135.72
# 226 0.7823799999997824 49.0
# Average return training: 30.2
# 227 0.7816599999997816 20.0
# Average return training: 30.04
# 228 0.7810839999997811 16.0
# Average return training: 30.06
# 229 0.7796439999997796 40.0
# Average return training: 30.21
# 230 0.7793199999997793 9.0
# Average return training: 30.03
# 231 0.7789599999997789 10.0
# Average return training: 29.91
# 232 0.7785639999997785 11.0
# Average return training: 29.43
# 233 0.7773039999997773 35.0
# Average return training: 29.61
# 234 0.7758639999997758 40.0
# Average return training: 29.91
# 235 0.7752879999997753 16.0
# Average return training: 29.8
# 236 0.7743879999997744 25.0
# Average return training: 29.94
# 237 0.7739559999997739 12.0
# Average return training: 29.51
# 238 0.7721199999997721 51.0
# Average return training: 29.38
# 239 0.7715799999997716 15.0
# Average return training: 28.88
# 240 0.7708239999997708 21.0
# Average return training: 28.81
# 241 0.7693119999997693 42.0
# Average return training: 29.09
# 242 0.7689519999997689 10.0
# Average return training: 28.84
# 243 0.7679079999997679 29.0
# Average return training: 28.91
# Average return over 25 episodes of playing: 98.96
# 244 0.7652439999997652 74.0
# Average return training: 29.54
# 245 0.7647399999997647 14.0
# Average return training: 29.52
# 246 0.7641639999997641 16.0
# Average return training: 29.55
# 247 0.7632279999997632 26.0
# Average return training: 29.68
# 248 0.7623279999997623 25.0
# Average return training: 29.58
# 249 0.7616079999997616 20.0
# Average return training: 29.29
# 250 0.761031999999761 16.0
# Average return training: 29.12
# 251 0.75998799999976 29.0
# Average return training: 29.29
# 252 0.7594119999997594 16.0
# Average return training: 29.22
# 253 0.7585839999997586 23.0
# Average return training: 29.29
# 254 0.7581519999997581 12.0
# Average return training: 29.2
# 255 0.7577919999997578 10.0
# Average return training: 28.41
# 256 0.7573599999997573 12.0
# Average return training: 28.23
# 257 0.7568919999997569 13.0
# Average return training: 28.05
# 258 0.7535799999997536 92.0
# Average return training: 28.1
# 259 0.753003999999753 16.0
# Average return training: 27.92
# 260 0.7523199999997523 19.0
# Average return training: 27.88
# 261 0.7498719999997498 68.0
# Average return training: 28.45
# Average return over 25 episodes of playing: 118.56
# 262 0.7469559999997469 81.0
# Average return training: 28.92
# 263 0.7463799999997464 16.0
# Average return training: 28.47
# 264 0.7459119999997459 13.0
# Average return training: 28.39
# 265 0.7444719999997444 40.0
# Average return training: 28.65
# 266 0.7438959999997439 16.0
# Average return training: 28.6
# 267 0.7434279999997434 13.0
# Average return training: 28.37
# 268 0.7414479999997414 55.0
# Average return training: 28.74
# 269 0.740979999999741 13.0
# Average return training: 28.54
# 270 0.7405479999997405 12.0
# Average return training: 28.48
# 271 0.7400799999997401 13.0
# Average return training: 28.46
# 272 0.7395039999997395 16.0
# Average return training: 28.31
# 273 0.7388199999997388 19.0
# Average return training: 28.28
# 274 0.7370919999997371 48.0
# Average return training: 28.53
# 275 0.7364799999997365 17.0
# Average return training: 28.4
# 276 0.7349679999997349 42.0
# Average return training: 28.34
# 277 0.7343919999997344 16.0
# Average return training: 28.25
# 278 0.7337439999997337 18.0
# Average return training: 28.33
# 279 0.7309359999997309 78.0
# Average return training: 28.38
# 280 0.7301799999997302 21.0
# Average return training: 28.48
# Average return over 25 episodes of playing: 115.96
# 281 0.7292439999997292 26.0
# Average return training: 28.46
# 282 0.728055999999728 33.0
# Average return training: 28.63
# 283 0.7275519999997275 14.0
# Average return training: 28.58
# 284 0.7269039999997269 18.0
# Average return training: 28.5
# 285 0.7254279999997254 41.0
# Average return training: 28.72
# 286 0.7248519999997248 16.0
# Average return training: 28.76
# 287 0.7242399999997242 17.0
# Average return training: 28.82
# 288 0.7236279999997236 17.0
# Average return training: 28.76
# 289 0.7231239999997231 14.0
# Average return training: 28.75
# 290 0.7215759999997216 43.0
# Average return training: 29.01
# 291 0.7211079999997211 13.0
# Average return training: 28.95
# 292 0.7197399999997197 38.0
# Average return training: 29.2
# 293 0.7192359999997192 14.0
# Average return training: 28.45
# 294 0.7183719999997183 24.0
# Average return training: 28.28
# 295 0.7174719999997174 25.0
# Average return training: 28.21
# 296 0.7169319999997169 15.0
# Average return training: 28.01
# 297 0.7157439999997157 33.0
# Average return training: 27.91
# 298 0.715059999999715 19.0
# Average return training: 27.81
# 299 0.7145559999997145 14.0
# Average return training: 27.71
# 300 0.7141599999997141 11.0
# Average return training: 27.57
# 301 0.7137639999997137 11.0
# Average return training: 27.08
# 302 0.7126119999997126 32.0
# Average return training: 27.19
# Average return over 25 episodes of playing: 276.48
# 303 0.7114959999997115 31.0
# Average return training: 27.02
# 304 0.7109559999997109 15.0
# Average return training: 27.02
# 305 0.7105959999997106 10.0
# Average return training: 26.96
# 306 0.7101279999997101 13.0
# Average return training: 26.51
# 307 0.7096239999997096 14.0
# Average return training: 26.48
# 308 0.7082919999997083 37.0
# Average return training: 26.7
# 309 0.7078959999997079 11.0
# Average return training: 26.41
# 310 0.7074999999997075 11.0
# Average return training: 26.34
# 311 0.7063479999997063 32.0
# Average return training: 26.53
# 312 0.7057359999997057 17.0
# Average return training: 25.92
# 313 0.7048719999997048 24.0
# Average return training: 25.94
# 314 0.7044399999997044 12.0
# Average return training: 25.76
# 315 0.7034679999997034 27.0
# Average return training: 25.86
# 316 0.7028559999997028 17.0
# Average return training: 25.89
# 317 0.7012359999997012 45.0
# Average return training: 26.14
# 318 0.7001919999997002 29.0
# Average return training: 25.83
# 319 0.6997599999996997 12.0
# Average return training: 25.26
# 320 0.6985359999996985 34.0
# Average return training: 25.28
# 321 0.6975279999996975 28.0
# Average return training: 25.24
# 322 0.6970959999996971 12.0
# Average return training: 25.03
# 323 0.6962679999996962 23.0
# Average return training: 25.16
# 324 0.6956919999996957 16.0
# Average return training: 25.12
# 325 0.695043999999695 18.0
# Average return training: 24.75
# 326 0.6945759999996945 13.0
# Average return training: 24.39
# 327 0.6941079999996941 13.0
# Average return training: 24.32
# Average return over 25 episodes of playing: 132.64
# 328 0.693063999999693 29.0
# Average return training: 24.45
# 329 0.6923439999996923 20.0
# Average return training: 24.25
# 330 0.691047999999691 36.0
# Average return training: 24.52
# 331 0.6874119999996874 101.0
# Average return training: 25.43
# 332 0.6865839999996866 23.0
# Average return training: 25.55
# 333 0.6856839999996857 25.0
# Average return training: 25.45
# 334 0.6848199999996848 24.0
# Average return training: 25.29
# 335 0.6828039999996828 56.0
# Average return training: 25.69
# 336 0.6823359999996823 13.0
# Average return training: 25.57
# 337 0.6818679999996818 13.0
# Average return training: 25.58
# 338 0.6813279999996813 15.0
# Average return training: 25.22
# 339 0.681003999999681 9.0
# Average return training: 25.16
# 340 0.6801399999996801 24.0
# Average return training: 25.19
# 341 0.6795279999996795 17.0
# Average return training: 24.94
# 342 0.6779439999996779 44.0
# Average return training: 25.28
# 343 0.6772239999996772 20.0
# Average return training: 25.19
# Average return over 25 episodes of playing: 101.24
# 344 0.6745599999996745 74.0
# Average return training: 25.19
# 345 0.6738399999996738 20.0
# Average return training: 25.25
# 346 0.673083999999673 21.0
# Average return training: 25.3
# 347 0.6725079999996725 16.0
# Average return training: 25.2
# 348 0.672003999999672 14.0
# Average return training: 25.09
# 349 0.6715719999996715 12.0
# Average return training: 25.01
# 350 0.6706359999996706 26.0
# Average return training: 25.11
# 351 0.6698079999996698 23.0
# Average return training: 25.05
# 352 0.6692319999996692 16.0
# Average return training: 25.05
# 353 0.6683679999996683 24.0
# Average return training: 25.06
# 354 0.6593679999996593 250.0
# Average return training: 27.44
# Average return over 25 episodes of playing: 119.64
# 355 0.6576759999996576 47.0
# Average return training: 27.81
# 356 0.656991999999657 19.0
# Average return training: 27.88
# 357 0.6563799999996563 17.0
# Average return training: 27.92
# 358 0.6552279999996552 32.0
# Average return training: 27.32
# 359 0.6545439999996545 19.0
# Average return training: 27.35
# 360 0.6542199999996542 9.0
# Average return training: 27.25
# 361 0.6536799999996536 15.0
# Average return training: 26.72
# 362 0.6527079999996527 27.0
# Average return training: 26.18
# 363 0.651987999999652 20.0
# Average return training: 26.22
# 364 0.6506199999996506 38.0
# Average return training: 26.47
# 365 0.6499359999996499 19.0
# Average return training: 26.26
# 366 0.6477759999996477 60.0
# Average return training: 26.7
# 367 0.6445719999996445 89.0
# Average return training: 27.46
# 368 0.6428079999996428 49.0
# Average return training: 27.4
# 369 0.6411159999996411 47.0
# Average return training: 27.74
# Average return over 25 episodes of playing: 89.84
# 370 0.6383439999996383 77.0
# Average return training: 28.39
# 371 0.6375159999996375 23.0
# Average return training: 28.49
# 372 0.6369039999996369 17.0
# Average return training: 28.5
# 373 0.6356799999996356 34.0
# Average return training: 28.65
# 374 0.6335919999996336 58.0
# Average return training: 28.75
# 375 0.6312879999996313 64.0
# Average return training: 29.22
# 376 0.6305679999996305 20.0
# Average return training: 29.0
# 377 0.6299199999996299 18.0
# Average return training: 29.02
# 378 0.6285519999996285 38.0
# Average return training: 29.22
# 379 0.6278679999996278 19.0
# Average return training: 28.63
# 380 0.6273639999996273 14.0
# Average return training: 28.56
# 381 0.6267879999996268 16.0
# Average return training: 28.46
# 382 0.6263559999996263 12.0
# Average return training: 28.25
# 383 0.6246639999996246 47.0
# Average return training: 28.58
# 384 0.6234399999996234 34.0
# Average return training: 28.74
# Average return over 25 episodes of playing: 92.56
# 385 0.6218199999996218 45.0
# Average return training: 28.78
# 386 0.6198039999996198 56.0
# Average return training: 29.18
# 387 0.6182919999996183 42.0
# Average return training: 29.43
# 388 0.6177519999996177 15.0
# Average return training: 29.41
# 389 0.6167799999996167 27.0
# Average return training: 29.54
# 390 0.611991999999612 133.0
# Average return training: 30.44
# 391 0.6114879999996115 14.0
# Average return training: 30.45
# 392 0.6107679999996107 20.0
# Average return training: 30.27
# 393 0.6103719999996103 11.0
# Average return training: 30.24
# 394 0.6099399999996099 12.0
# Average return training: 30.12
# 395 0.605007999999605 137.0
# Average return training: 31.24
# 396 0.6042879999996043 20.0
# Average return training: 31.29
# Average return over 25 episodes of playing: 118.28
# 397 0.6024159999996024 52.0
# Average return training: 31.48
# 398 0.5991399999995991 91.0
# Average return training: 32.2
# 399 0.5954679999995954 102.0
# Average return training: 33.08
# 400 0.5938479999995938 45.0
# Average return training: 33.42
# 401 0.5932359999995932 17.0
# Average return training: 33.48
# 402 0.5919399999995919 36.0
# Average return training: 33.52
# 403 0.5915799999995915 10.0
# Average return training: 33.31
# 404 0.5911479999995911 12.0
# Average return training: 33.28
# 405 0.5903199999995903 23.0
# Average return training: 33.41
# 406 0.5895999999995896 20.0
# Average return training: 33.48
# 407 0.5881959999995882 39.0
# Average return training: 33.73
# 408 0.5874399999995874 21.0
# Average return training: 33.57
# Average return over 25 episodes of playing: 158.56
# 409 0.5832639999995832 116.0
# Average return training: 34.62
# 410 0.5826159999995826 18.0
# Average return training: 34.69
# 411 0.5805279999995805 58.0
# Average return training: 34.95
# 412 0.5799159999995799 17.0
# Average return training: 34.95
# 413 0.5793759999995793 15.0
# Average return training: 34.86
# 414 0.5785119999995785 24.0
# Average return training: 34.98
# 415 0.5778279999995778 19.0
# Average return training: 34.9
# 416 0.5771799999995771 18.0
# Average return training: 34.91
# 417 0.5763879999995764 22.0
# Average return training: 34.68
# 418 0.5746239999995746 49.0
# Average return training: 34.88
# 419 0.5739039999995739 20.0
# Average return training: 34.96
# 420 0.5731119999995731 22.0
# Average return training: 34.84
# 421 0.5723199999995723 22.0
# Average return training: 34.78
# 422 0.5717079999995717 17.0
# Average return training: 34.83
# Average return over 25 episodes of playing: 154.24
# 423 0.5673879999995673 120.0
# Average return training: 35.8
# 424 0.5647239999995647 74.0
# Average return training: 36.38
# 425 0.5642919999995643 12.0
# Average return training: 36.32
# 426 0.5636079999995636 19.0
# Average return training: 36.38
# 427 0.5628519999995628 21.0
# Average return training: 36.46
# 428 0.561015999999561 51.0
# Average return training: 36.68
# 429 0.5603679999995603 18.0
# Average return training: 36.66
# 430 0.5596839999995596 19.0
# Average return training: 36.49
# 431 0.5591079999995591 16.0
# Average return training: 35.64
# 432 0.5586399999995586 13.0
# Average return training: 35.54
# 433 0.5572719999995572 38.0
# Average return training: 35.67
# 434 0.5568039999995568 13.0
# Average return training: 35.56
# 435 0.5554359999995554 38.0
# Average return training: 35.38
# 436 0.5545719999995545 24.0
# Average return training: 35.49
# 437 0.5539599999995539 17.0
# Average return training: 35.53
# 438 0.5533119999995533 18.0
# Average return training: 35.56
# 439 0.5526999999995527 17.0
# Average return training: 35.64
# 440 0.5518719999995518 23.0
# Average return training: 35.63
# 441 0.5508639999995508 28.0
# Average return training: 35.74
# Average return over 25 episodes of playing: 114.2
# 442 0.5493159999995493 43.0
# Average return training: 35.73
# 443 0.5471919999995472 59.0
# Average return training: 36.12
# 444 0.5463999999995464 22.0
# Average return training: 35.6
# 445 0.5453559999995453 29.0
# Average return training: 35.69
# 446 0.5449599999995449 11.0
# Average return training: 35.59
# 447 0.5442759999995442 19.0
# Average return training: 35.62
# 448 0.5433039999995433 27.0
# Average return training: 35.75
# 449 0.5429079999995429 11.0
# Average return training: 35.74
# 450 0.54006399999954 79.0
# Average return training: 36.27
# 451 0.5396319999995396 12.0
# Average return training: 36.16
# 452 0.5388759999995388 21.0
# Average return training: 36.21
# 453 0.5381559999995381 20.0
# Average return training: 36.17
# 454 0.537039999999537 31.0
# Average return training: 33.98
# 455 0.5365359999995365 14.0
# Average return training: 33.65
# 456 0.5356359999995356 25.0
# Average return training: 33.71
# 457 0.5353119999995353 9.0
# Average return training: 33.63
# 458 0.5348079999995348 14.0
# Average return training: 33.45
# 459 0.5343039999995343 14.0
# Average return training: 33.4
# Average return over 25 episodes of playing: 142.36
# 460 0.531999999999532 64.0
# Average return training: 33.95
# 461 0.5314959999995315 14.0
# Average return training: 33.94
# 462 0.5287239999995287 77.0
# Average return training: 34.44
# 463 0.526023999999526 75.0
# Average return training: 34.99
# 464 0.5252679999995252 21.0
# Average return training: 34.82
# 465 0.5247279999995247 15.0
# Average return training: 34.78
# 466 0.5243319999995243 11.0
# Average return training: 34.29
# 467 0.5236119999995236 20.0
# Average return training: 33.6
# 468 0.5229639999995229 18.0
# Average return training: 33.29
# 469 0.5220999999995221 24.0
# Average return training: 33.06
# 470 0.519075999999519 84.0
# Average return training: 33.13
# 471 0.5178519999995178 34.0
# Average return training: 33.24
# 472 0.5146839999995146 88.0
# Average return training: 33.95
# 473 0.5141079999995141 16.0
# Average return training: 33.77
# Average return over 25 episodes of playing: 102.4
# 474 0.5128479999995128 35.0
# Average return training: 33.54
# 475 0.5121639999995121 19.0
# Average return training: 33.09
# 476 0.5115879999995115 16.0
# Average return training: 33.05
# 477 0.5108679999995108 20.0
# Average return training: 33.07
# 478 0.5099319999995099 26.0
# Average return training: 32.95
# 479 0.5087079999995087 34.0
# Average return training: 33.1
# 480 0.5082399999995082 13.0
# Average return training: 33.09
# 481 0.5075919999995075 18.0
# Average return training: 33.11
# 482 0.5069439999995069 18.0
# Average return training: 33.17
# 483 0.5055759999995055 38.0
# Average return training: 33.08
# 484 0.5051439999995051 12.0
# Average return training: 32.86
# 485 0.5013999999995014 104.0
# Average return training: 33.45
# 486 0.49974399999950014 46.0
# Average return training: 33.35
# 487 0.4993119999995004 12.0
# Average return training: 33.05
# 488 0.49841199999950087 25.0
# Average return training: 33.15
# 489 0.49733199999950145 30.0
# Average return training: 33.18
# Average return over 25 episodes of playing: 122.88
# 490 0.494523999999503 78.0
# Average return training: 32.63
# 491 0.4935519999995035 27.0
# Average return training: 32.76
# 492 0.48955599999950566 111.0
# Average return training: 33.67
# 493 0.48901599999950596 15.0
# Average return training: 33.71
# 494 0.4885479999995062 13.0
# Average return training: 33.72
# 495 0.4874679999995068 30.0
# Average return training: 32.65
# 496 0.487071999999507 11.0
# Average return training: 32.56
# 497 0.48606399999950756 28.0
# Average return training: 32.32
# 498 0.48552399999950785 15.0
# Average return training: 31.56
# 499 0.48498399999950814 15.0
# Average return training: 30.69
# 500 0.48408399999950863 25.0
# Average return training: 30.49
# 501 0.4836159999995089 13.0
# Average return training: 30.45
# 502 0.4830759999995092 15.0
# Average return training: 30.24
# 503 0.48235599999950957 20.0
# Average return training: 30.34
# 504 0.48109599999951025 35.0
# Average return training: 30.57
# 505 0.4802679999995107 23.0
# Average return training: 30.57
# Average return over 25 episodes of playing: 109.2
# 506 0.47609199999951296 116.0
# Average return training: 31.53
# 507 0.47519199999951345 25.0
# Average return training: 31.39
# 508 0.4719519999995152 90.0
# Average return training: 32.08
# 509 0.4711959999995156 21.0
# Average return training: 31.13
# 510 0.4700799999995162 31.0
# Average return training: 31.26
# 511 0.46928799999951665 22.0
# Average return training: 30.9
# 512 0.46874799999951694 15.0
# Average return training: 30.88
# 513 0.4675599999995176 33.0
# Average return training: 31.06
# 514 0.4669839999995179 16.0
# Average return training: 30.98
# 515 0.4661919999995183 22.0
# Average return training: 31.01
# 516 0.46579599999951854 11.0
# Average return training: 30.94
# 517 0.46503999999951895 21.0
# Average return training: 30.93
# 518 0.46449999999951924 15.0
# Average return training: 30.59
# 519 0.46359999999951973 25.0
# Average return training: 30.64
# 520 0.46313199999952 13.0
# Average return training: 30.55
# 521 0.4625919999995203 15.0
# Average return training: 30.48
# 522 0.4614039999995209 33.0
# Average return training: 30.64
# 523 0.4609359999995212 13.0
# Average return training: 29.57
# Average return over 25 episodes of playing: 98.96
# 524 0.45971199999952184 34.0
# Average return training: 29.17
# 525 0.45909999999952217 17.0
# Average return training: 29.22
# 526 0.4571559999995232 54.0
# Average return training: 29.57
# 527 0.45675999999952344 11.0
# Average return training: 29.47
# 528 0.455679999999524 30.0
# Average return training: 29.26
# 529 0.45380799999952504 52.0
# Average return training: 29.6
# 530 0.4531239999995254 19.0
# Average return training: 29.6
# 531 0.44912799999952757 111.0
# Average return training: 30.55
# 532 0.4481199999995281 28.0
# Average return training: 30.7
# 533 0.44678799999952884 37.0
# Average return training: 30.69
# 534 0.4452399999995297 43.0
# Average return training: 30.99
# 535 0.44469999999952997 15.0
# Average return training: 30.76
# 536 0.4442319999995302 13.0
# Average return training: 30.65
# 537 0.44214399999953136 58.0
# Average return training: 31.06
# Average return over 25 episodes of playing: 107.28
# 538 0.44124399999953184 25.0
# Average return training: 31.13
# 539 0.43991199999953257 37.0
# Average return training: 31.33
# 540 0.4359879999995347 109.0
# Average return training: 32.19
# 541 0.43512399999953516 24.0
# Average return training: 32.15
# 542 0.43382799999953586 36.0
# Average return training: 32.08
# 543 0.43238799999953664 40.0
# Average return training: 31.89
# 544 0.43073199999953754 46.0
# Average return training: 32.13
# 545 0.4272759999995394 96.0
# Average return training: 32.8
# 546 0.42680799999953967 13.0
# Average return training: 32.82
# 547 0.4247559999995408 57.0
# Average return training: 33.2
# 548 0.42428799999954103 13.0
# Average return training: 33.06
# Average return over 25 episodes of playing: 105.92
# 549 0.42183999999954236 68.0
# Average return training: 33.63
# 550 0.42133599999954263 14.0
# Average return training: 32.98
# 551 0.4205079999995431 23.0
# Average return training: 33.09
# 552 0.4199679999995434 15.0
# Average return training: 33.03
# 553 0.41870799999954406 35.0
# Average return training: 33.18
# 554 0.4177359999995446 27.0
# Average return training: 33.14
# 555 0.4166199999995452 31.0
# Average return training: 33.31
# 556 0.41615199999954544 13.0
# Average return training: 33.19
# 557 0.4156479999995457 14.0
# Average return training: 33.24
# 558 0.4147119999995462 26.0
# Average return training: 33.36
# 559 0.4140279999995466 19.0
# Average return training: 33.41
# 560 0.4125879999995474 40.0
# Average return training: 33.17
# 561 0.4120119999995477 16.0
# Average return training: 33.19
# 562 0.41150799999954796 14.0
# Average return training: 32.56
# 563 0.4104639999995485 29.0
# Average return training: 32.1
# 564 0.40934799999954913 31.0
# Average return training: 32.2
# 565 0.4086639999995495 19.0
# Average return training: 32.24
# 566 0.4075119999995501 32.0
# Average return training: 32.45
# 567 0.4069719999995504 15.0
# Average return training: 32.4
# Average return over 25 episodes of playing: 101.6
# 568 0.4057119999995511 35.0
# Average return training: 32.57
# 569 0.4044519999995518 35.0
# Average return training: 32.68
# 570 0.40229199999955295 60.0
# Average return training: 32.44
# 571 0.4017879999995532 14.0
# Average return training: 32.24
# 572 0.40099599999955365 22.0
# Average return training: 31.58
# 573 0.40041999999955397 16.0
# Average return training: 31.58
# 574 0.39987999999955426 15.0
# Average return training: 31.38
# 575 0.39858399999955496 36.0
# Average return training: 31.55
# 576 0.39710799999955576 41.0
# Average return training: 31.8
# 577 0.39642399999955613 19.0
# Average return training: 31.79
# 578 0.39563199999955656 22.0
# Average return training: 31.75
# 579 0.3916719999995587 110.0
# Average return training: 32.51
# 580 0.39048399999955935 33.0
# Average return training: 32.71
# 581 0.3900159999995596 13.0
# Average return training: 32.66
# 582 0.38958399999955984 12.0
# Average return training: 32.6
# 583 0.38886399999956023 20.0
# Average return training: 32.42
# 584 0.38807199999956066 22.0
# Average return training: 32.52
# Average return over 25 episodes of playing: 108.8
# 585 0.3842919999995627 105.0
# Average return training: 32.53
# 586 0.38328399999956325 28.0
# Average return training: 32.35
# 587 0.3824199999995637 24.0
# Average return training: 32.47
# 588 0.3791799999995655 90.0
# Average return training: 33.12
# 589 0.3783519999995659 23.0
# Average return training: 33.05
# 590 0.3770559999995666 36.0
# Average return training: 32.63
# 591 0.3735639999995685 97.0
# Average return training: 33.33
# 592 0.37277199999956895 22.0
# Average return training: 32.44
# 593 0.37151199999956963 35.0
# Average return training: 32.64
# Average return over 25 episodes of playing: 92.96
# 594 0.36686799999957215 129.0
# Average return training: 33.8
# 595 0.365283999999573 44.0
# Average return training: 33.94
# 596 0.3647439999995733 15.0
# Average return training: 33.98
# 597 0.363483999999574 35.0
# Average return training: 34.05
# 598 0.36301599999957423 13.0
# Average return training: 34.03
# 599 0.36243999999957455 16.0
# Average return training: 34.04
# 600 0.36153999999957503 25.0
# Average return training: 34.04
# 601 0.36117999999957523 10.0
# Average return training: 34.01
# 602 0.3573279999995773 107.0
# Average return training: 34.93
# 603 0.35689599999957755 12.0
# Average return training: 34.85
# 604 0.35617599999957794 20.0
# Average return training: 34.7
# 605 0.3556719999995782 14.0
# Average return training: 34.61
# 606 0.3546279999995788 29.0
# Average return training: 33.74
# 607 0.35415999999957903 13.0
# Average return training: 33.62
# 608 0.35358399999957935 16.0
# Average return training: 32.88
# 609 0.35300799999957966 16.0
# Average return training: 32.83
# 610 0.3525399999995799 13.0
# Average return training: 32.65
# 611 0.35207199999958017 13.0
# Average return training: 32.56
# Average return over 25 episodes of playing: 93.0
# 612 0.35174799999958034 9.0
# Average return training: 32.5
# 613 0.35045199999958104 36.0
# Average return training: 32.53
# 614 0.35005599999958126 11.0
# Average return training: 32.48
# 615 0.34857999999958206 41.0
# Average return training: 32.67
# 616 0.34746399999958266 31.0
# Average return training: 32.87
# 617 0.3466359999995831 23.0
# Average return training: 32.89
# 618 0.34598799999958346 18.0
# Average return training: 32.92
# 619 0.34227999999958547 103.0
# Average return training: 33.7
# 620 0.3392919999995871 83.0
# Average return training: 34.4
# 621 0.33882399999958734 13.0
# Average return training: 34.38
# 622 0.33824799999958766 16.0
# Average return training: 34.21
# 623 0.3378159999995879 12.0
# Average return training: 34.2
# Average return over 25 episodes of playing: 96.96
# 624 0.33396399999959 107.0
# Average return training: 34.93
# 625 0.3335319999995902 12.0
# Average return training: 34.88
# 626 0.3329919999995905 15.0
# Average return training: 34.49
# 627 0.3316959999995912 36.0
# Average return training: 34.74
# 628 0.3311199999995915 16.0
# Average return training: 34.6
# 629 0.32759199999959343 98.0
# Average return training: 35.06
# 630 0.3270879999995937 14.0
# Average return training: 35.01
# 631 0.32571999999959445 38.0
# Average return training: 34.28
# 632 0.32474799999959497 27.0
# Average return training: 34.27
# 633 0.32186799999959653 80.0
# Average return training: 34.7
# 634 0.31941999999959786 68.0
# Average return training: 34.95
# 635 0.31887999999959815 15.0
# Average return training: 34.95
# 636 0.3182319999995985 18.0
# Average return training: 35.0
# 637 0.31761999999959883 17.0
# Average return training: 34.59
# 638 0.31646799999959946 32.0
# Average return training: 34.66
# Average return over 25 episodes of playing: 101.36
# 639 0.3158559999995998 17.0
# Average return training: 34.46
# 640 0.31538799999960004 13.0
# Average return training: 33.5
# 641 0.3120039999996019 94.0
# Average return training: 34.2
# 642 0.30746799999960434 126.0
# Average return training: 35.1
# 643 0.3060999999996051 38.0
# Average return training: 35.08
# 644 0.30469599999960584 39.0
# Average return training: 35.01
# 645 0.30411999999960615 16.0
# Average return training: 34.21
# 646 0.3000159999996084 114.0
# Average return training: 35.22
# Average return over 25 episodes of playing: 148.4
# 647 0.29504799999961107 138.0
# Average return training: 36.03
# 648 0.28439199999961684 296.0
# Average return training: 38.86
# 649 0.2837079999996172 19.0
# Average return training: 38.37
# 650 0.2824839999996179 34.0
# Average return training: 38.57
# Average return over 25 episodes of playing: 94.2
# 651 0.2664279999996266 446.0
# Average return training: 42.8
# Average return over 25 episodes of playing: 128.0
# 652 0.26109999999962946 148.0
# Average return training: 44.13
# 653 0.2560239999996322 141.0
# Average return training: 45.19
# 654 0.25335999999963366 74.0
# Average return training: 45.66
# 655 0.24453999999963422 245.0
# Average return training: 47.8
# Average return over 25 episodes of playing: 124.12
# 656 0.24396399999963408 16.0
# Average return training: 47.83
# 657 0.239247999999633 131.0
# Average return training: 49.0
# 658 0.23514399999963206 114.0
# Average return training: 49.88
# 659 0.2292039999996307 165.0
# Average return training: 51.34
# Average return over 25 episodes of playing: 244.88
# 660 0.2230479999996293 171.0
# Average return training: 52.65
# 661 0.21717999999962795 163.0
# Average return training: 54.12
# 662 0.20976399999962625 206.0
# Average return training: 56.04
# Average return over 25 episodes of playing: 228.56
# 663 0.20263599999962462 198.0
# Average return training: 57.73
# 664 0.19626399999962316 177.0
# Average return training: 59.19
# 665 0.19478799999962282 41.0
# Average return training: 59.41
# Average return over 25 episodes of playing: 110.44
# 666 0.1889919999996215 161.0
# Average return training: 60.7
# 667 0.18834399999962134 18.0
# Average return training: 60.73
# 668 0.18719199999962108 32.0
# Average return training: 60.7
# 669 0.18650799999962092 19.0
# Average return training: 60.54
# 670 0.1838439999996203 74.0
# Average return training: 60.68
# 671 0.1785519999996191 147.0
# Average return training: 62.01
# 672 0.17444799999961816 114.0
# Average return training: 62.93
# Average return over 25 episodes of playing: 500.0
# 673 0.16962399999961705 134.0
# Average return training: 64.11
# 674 0.16425999999961582 149.0
# Average return training: 65.45
# 675 0.15954399999961474 131.0
# Average return training: 66.4
# 676 0.15489999999961368 129.0
# Average return training: 67.28
# 677 0.15446799999961358 12.0
# Average return training: 67.21
# Average return over 25 episodes of playing: 142.12
# 678 0.14899599999961233 152.0
# Average return training: 68.51
# 679 0.1440279999996112 138.0
# Average return training: 68.79
# 680 0.14355999999961108 13.0
# Average return training: 68.59
# 681 0.13909599999961006 124.0
# Average return training: 69.7
# Average return over 25 episodes of playing: 100.44
# 682 0.13499199999960912 114.0
# Average return training: 70.72
# 683 0.13088799999960818 114.0
# Average return training: 71.66
# 684 0.12678399999960724 114.0
# Average return training: 72.58
# 685 0.12635199999960714 12.0
# Average return training: 71.65
# 686 0.12217599999960728 116.0
# Average return training: 72.53
# 687 0.12181599999960734 10.0
# Average return training: 72.39
# Average return over 25 episodes of playing: 115.08
# 688 0.11789199999960795 109.0
# Average return training: 72.58
# 689 0.11367999999960861 117.0
# Average return training: 73.52
# 690 0.10957599999960925 114.0
# Average return training: 74.3
# 691 0.10579599999960984 105.0
# Average return training: 74.38
# 692 0.10183599999961046 110.0
# Average return training: 75.26
# Average return over 25 episodes of playing: 122.04
# 693 0.1 106.0
# Average return training: 75.97
# 694 0.1 120.0
# Average return training: 75.88
# 695 0.1 111.0
# Average return training: 76.55
# 696 0.1 112.0
# Average return training: 77.52
# Average return over 25 episodes of playing: 107.0
# 697 0.1 114.0
# Average return training: 78.31
# 698 0.1 108.0
# Average return training: 79.26
# 699 0.1 115.0
# Average return training: 80.25
# 700 0.1 123.0
# Average return training: 81.23
# 701 0.1 128.0
# Average return training: 82.41
# Average return over 25 episodes of playing: 108.96
# 702 0.1 132.0
# Average return training: 82.66
# 703 0.1 21.0
# Average return training: 82.75
# 704 0.1 112.0
# Average return training: 83.67
# 705 0.1 139.0
# Average return training: 84.92
# Average return over 25 episodes of playing: 109.28
# 706 0.1 116.0
# Average return training: 85.79
# 707 0.1 116.0
# Average return training: 86.82
# 708 0.1 107.0
# Average return training: 87.73
# 709 0.1 113.0
# Average return training: 88.7
# 710 0.1 119.0
# Average return training: 89.76
# 711 0.1 20.0
# Average return training: 89.83
# Average return over 25 episodes of playing: 107.36
# 712 0.1 114.0
# Average return training: 90.88
# 713 0.1 118.0
# Average return training: 91.7
# 714 0.1 27.0
# Average return training: 91.86
# 715 0.1 13.0
# Average return training: 91.58
# 716 0.1 19.0
# Average return training: 91.46
# 717 0.1 110.0
# Average return training: 92.33
# 718 0.1 15.0
# Average return training: 92.3
# Average return over 25 episodes of playing: 98.48
# 719 0.1 111.0
# Average return training: 92.38
# 720 0.1 109.0
# Average return training: 92.64
# 721 0.1 114.0
# Average return training: 93.65
# 722 0.1 32.0
# Average return training: 93.81
# 723 0.1 16.0
# Average return training: 93.85
# 724 0.1 116.0
# Average return training: 93.94
# Average return over 25 episodes of playing: 116.96
# 725 0.1 106.0
# Average return training: 94.88
# 726 0.1 137.0
# Average return training: 96.1
# 727 0.1 12.0
# Average return training: 95.86
# 728 0.1 129.0
# Average return training: 96.99
# Average return over 25 episodes of playing: 312.72
# 729 0.1 408.0
# Average return training: 100.09
# 730 0.1 14.0
# Average return training: 100.09
# 731 0.1 162.0
# Average return training: 101.33
# Average return over 25 episodes of playing: 120.24
# 732 0.1 148.0
# Average return training: 102.54
# 733 0.1 65.0
# Average return training: 102.39
# 734 0.1 275.0
# Average return training: 104.46
# Average return over 25 episodes of playing: 176.76
# 735 0.1 301.0
# Average return training: 107.32
# Average return over 25 episodes of playing: 478.32
# 736 0.1 437.0
# Average return training: 111.51
# Average return over 25 episodes of playing: 268.24
# 737 0.1 443.0
# Average return training: 115.77
# Average return over 25 episodes of playing: 500.0
# 738 0.1 500.0
# Average return training: 120.45
# Average return over 25 episodes of playing: 500.0
# 739 0.1 500.0
# Average return training: 125.28
# Average return over 25 episodes of playing: 500.0
# 740 0.1 500.0
# Average return training: 130.15
# Average return over 25 episodes of playing: 500.0
# 741 0.1 500.0
# Average return training: 134.21
# 742 0.1 249.0
# Average return training: 135.44
# Average return over 25 episodes of playing: 500.0
# Average return over 100 episodes of trained agent: 500.0
# SEED: 34
# Finishing last run (ID:1i5qoosa) before initializing another...
# <br/>Waiting for W&B process to finish, PID 179... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>Average return over 100 episodes of training</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▁▂▂▂▂▂▂▂▂▃▄▅▅█</td></tr><tr><td>Average return over 25 episodes of playing</td><td>▁▂▅▃▄▄▃▃▃▅▃▃▂▃▃▃▂▂▂▂▂▂▂▃▃▃▄█▃▃▂▂▂▃▅▃▅███</td></tr><tr><td>episode</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>Average return over 100 episodes of training</td><td>135.44</td></tr><tr><td>Average return over 25 episodes of playing</td><td>500.0</td></tr><tr><td>episode</td><td>742</td></tr><tr><td>step</td><td>33000</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">elated-bird-64</strong>: <a href="https://wandb.ai/raisa/Prior-Exp-Replay-CartPole/runs/1i5qoosa" target="_blank">https://wandb.ai/raisa/Prior-Exp-Replay-CartPole/runs/1i5qoosa</a><br/>
# Find logs at: <code>./wandb/run-20220114_191509-1i5qoosa/logs</code><br/>
# Successfully finished last run (ID:1i5qoosa). Initializing new run:<br/>
#                     Syncing run <strong><a href="https://wandb.ai/raisa/Prior-Exp-Replay-CartPole/runs/gcikgkdb" target="_blank">fresh-sunset-65</a></strong> to <a href="https://wandb.ai/raisa/Prior-Exp-Replay-CartPole" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 1 0.9986679999999987 37.0
# 2 0.9983079999999983 10.0
# 3 0.9978399999999978 13.0
# 4 0.9967959999999968 29.0
# 5 0.995967999999996 23.0
# 6 0.9954999999999955 13.0
# 7 0.9947079999999947 22.0
# 8 0.9943839999999944 9.0
# 9 0.9937359999999937 18.0
# 10 0.9927999999999928 26.0
# 11 0.9924039999999924 11.0
# 12 0.9908199999999908 44.0
# 13 0.9899199999999899 25.0
# 14 0.988947999999989 27.0
# 15 0.9884439999999884 14.0
# 16 0.988011999999988 12.0
# 17 0.9861399999999861 52.0
# 18 0.9858159999999858 9.0
# 19 0.9844839999999845 37.0
# 20 0.9841959999999842 8.0
# 21 0.9833319999999833 24.0
# Average return over 25 episodes of playing: 15.4
# 22 0.9817119999999817 45.0
# 23 0.9811359999999811 16.0
# 24 0.9805959999999806 15.0
# 25 0.9801999999999802 11.0
# 26 0.9798039999999798 11.0
# 27 0.9789039999999789 25.0
# 28 0.9773559999999774 43.0
# 29 0.9758079999999758 43.0
# 30 0.9753399999999753 13.0
# 31 0.9748359999999748 14.0
# 32 0.9742599999999743 16.0
# 33 0.9730719999999731 33.0
# 34 0.9724239999999724 18.0
# 35 0.9715959999999716 23.0
# 36 0.9707679999999708 23.0
# 37 0.9703359999999703 12.0
# 38 0.9695439999999695 22.0
# 39 0.9676359999999676 53.0
# 40 0.9666279999999666 28.0
# 41 0.9657639999999658 24.0
# 42 0.9654039999999654 10.0
# 43 0.9647199999999647 19.0
# Average return over 25 episodes of playing: 48.0
# 44 0.9634959999999635 34.0
# 45 0.9627039999999627 22.0
# 46 0.9621279999999621 16.0
# 47 0.961011999999961 31.0
# 48 0.95996799999996 29.0
# 49 0.9587799999999588 33.0
# 50 0.9566199999999566 60.0
# 51 0.9557559999999558 24.0
# 52 0.9547119999999547 29.0
# 53 0.953955999999954 21.0
# 54 0.9531639999999532 22.0
# 55 0.9526959999999527 13.0
# 56 0.9518679999999519 23.0
# 57 0.9511119999999511 21.0
# 58 0.9498879999999499 34.0
# 59 0.9472959999999473 72.0
# Average return over 25 episodes of playing: 156.12
# 60 0.9458559999999459 40.0
# 61 0.9452079999999452 18.0
# 62 0.9444879999999445 20.0
# 63 0.9436959999999437 22.0
# 64 0.9429399999999429 21.0
# 65 0.941967999999942 27.0
# 66 0.940959999999941 28.0
# 67 0.9405279999999405 12.0
# 68 0.9396639999999397 24.0
# 69 0.9387639999999388 25.0
# 70 0.938007999999938 21.0
# 71 0.9375399999999375 13.0
# 72 0.9364959999999365 29.0
# 73 0.9345519999999345 54.0
# ...
# Average return training: 38.45
# 382 0.5789079999995789 20.0
# Average return training: 38.3
# 383 0.5783679999995783 15.0
# Average return training: 35.92
# 384 0.5764239999995764 54.0
# Average return training: 36.34
# 385 0.5757759999995757 18.0
# Average return training: 36.02
# 386 0.5745879999995746 33.0
# Average return training: 36.17
# 387 0.574047999999574 15.0
# Average return training: 36.15
# 388 0.5724999999995725 43.0
# Average return training: 36.38
# 389 0.5712759999995712 34.0
# Average return training: 36.46
# 390 0.5687919999995688 69.0
# Average return training: 36.74
# 391 0.5684319999995684 10.0
# Average return training: 36.09
# Average return over 25 episodes of playing: 336.6
# 392 0.5668839999995668 43.0
# Average return training: 36.14
# 393 0.5663799999995663 14.0
# Average return training: 35.54
# 394 0.5655879999995655 22.0
# Average return training: 35.57
# 395 0.5651919999995652 11.0
# Average return training: 35.52
# 396 0.5619519999995619 90.0
# Average return training: 35.99
# 397 0.5585679999995585 94.0
# Average return training: 36.8
# 398 0.558027999999558 15.0
# Average return training: 36.49
# 399 0.5526639999995526 149.0
# Average return training: 37.76
# 400 0.551007999999551 46.0
# Average return training: 37.85
# Average return over 25 episodes of playing: 144.6
# 401 0.5474799999995474 98.0
# Average return training: 38.69
# 402 0.5458599999995458 45.0
# Average return training: 38.98
# 403 0.54006399999954 161.0
# Average return training: 40.44
# 404 0.5395239999995395 15.0
# Average return training: 40.05
# 405 0.5375439999995375 55.0
# Average return training: 40.05
# 406 0.5367159999995367 23.0
# Average return training: 39.08
# 407 0.5336559999995336 85.0
# Average return training: 39.55
# Average return over 25 episodes of playing: 117.16
# 408 0.5305959999995306 85.0
# Average return training: 40.28
# 409 0.5269239999995269 102.0
# Average return training: 41.15
# 410 0.5245479999995245 66.0
# Average return training: 41.17
# 411 0.5238999999995239 18.0
# Average return training: 41.17
# 412 0.5198679999995198 112.0
# Average return training: 41.46
# Average return over 25 episodes of playing: 137.92
# 413 0.5103279999995103 265.0
# Average return training: 43.83
# 414 0.5085999999995086 48.0
# Average return training: 44.19
# 415 0.5024799999995024 170.0
# Average return training: 45.55
# 416 0.5016879999995016 22.0
# Average return training: 45.48
# 417 0.4972599999995015 123.0
# Average return training: 46.56
# 418 0.49639599999950196 24.0
# Average return training: 46.7
# Average return over 25 episodes of playing: 122.04
# 419 0.4959999999995022 11.0
# Average return training: 46.68
# 420 0.4952439999995026 21.0
# Average return training: 46.71
# 421 0.49347999999950354 49.0
# Average return training: 47.05
# 422 0.48998799999950543 97.0
# Average return training: 46.8
# 423 0.48959199999950564 11.0
# Average return training: 46.7
# 424 0.4877919999995066 50.0
# Average return training: 46.39
# 425 0.48739599999950683 11.0
# Average return training: 46.04
# 426 0.48642399999950736 27.0
# Average return training: 46.17
# 427 0.4857759999995077 18.0
# Average return training: 46.23
# 428 0.4841559999995086 45.0
# Average return training: 46.06
# 429 0.4835799999995089 16.0
# Average return training: 45.94
# 430 0.4832199999995091 10.0
# Average return training: 45.83
# 431 0.4822839999995096 26.0
# Average return training: 45.55
# 432 0.4814199999995101 24.0
# Average return training: 44.96
# 433 0.48055599999951054 24.0
# Average return training: 45.06
# 434 0.47979999999951095 21.0
# Average return training: 45.09
# 435 0.47889999999951144 25.0
# Average return training: 44.54
# Average return over 25 episodes of playing: 93.44
# 436 0.4774599999995122 40.0
# Average return training: 44.57
# 437 0.4765959999995127 24.0
# Average return training: 44.21
# 438 0.4756239999995132 27.0
# Average return training: 44.29
# 439 0.47479599999951366 23.0
# Average return training: 44.36
# 440 0.47375199999951423 29.0
# Average return training: 44.39
# 441 0.46961199999951647 115.0
# Average return training: 45.34
# 442 0.4689999999995168 17.0
# Average return training: 44.96
# 443 0.46838799999951714 17.0
# Average return training: 44.84
# 444 0.4665879999995181 50.0
# Average return training: 44.09
# 445 0.46557999999951866 28.0
# Average return training: 44.03
# 446 0.4643559999995193 34.0
# Average return training: 44.18
# 447 0.4638159999995196 15.0
# Average return training: 44.04
# 448 0.4632759999995199 15.0
# Average return training: 43.51
# 449 0.46007199999952164 89.0
# Average return training: 44.25
# Average return over 25 episodes of playing: 97.76
# 450 0.4582719999995226 50.0
# Average return training: 44.57
# 451 0.4574079999995231 24.0
# Average return training: 44.63
# 452 0.45693999999952334 13.0
# Average return training: 44.53
# 453 0.45639999999952363 15.0
# Average return training: 44.3
# 454 0.45560799999952406 22.0
# Average return training: 44.23
# 455 0.4545639999995246 29.0
# Average return training: 44.23
# 456 0.4540599999995249 14.0
# Average return training: 43.59
# 457 0.45265599999952566 39.0
# Average return training: 43.76
# 458 0.45211599999952595 15.0
# Average return training: 43.8
# 459 0.45081999999952665 36.0
# Average return training: 44.02
# 460 0.450135999999527 19.0
# Average return training: 44.02
# 461 0.4488759999995277 35.0
# Average return training: 44.26
# 462 0.44826399999952804 17.0
# Average return training: 44.28
# 463 0.4478319999995283 12.0
# Average return training: 43.93
# 464 0.4468959999995288 26.0
# Average return training: 43.11
# 465 0.4459239999995293 27.0
# Average return training: 43.04
# 466 0.4420719999995314 107.0
# Average return training: 43.56
# Average return over 25 episodes of playing: 101.72
# 467 0.43955199999953276 70.0
# Average return training: 44.12
# 468 0.43883199999953315 20.0
# Average return training: 43.51
# 469 0.43843599999953337 11.0
# Average return training: 43.18
# 470 0.4378599999995337 16.0
# Average return training: 42.98
# 471 0.4356279999995349 62.0
# Average return training: 43.42
# 472 0.4349079999995353 20.0
# Average return training: 43.45
# 473 0.43386399999953584 29.0
# Average return training: 43.46
# 474 0.43166799999953703 61.0
# Average return training: 43.43
# 475 0.4266999999995397 138.0
# Average return training: 44.56
# 476 0.42626799999953996 12.0
# Average return training: 44.44
# Average return over 25 episodes of playing: 98.64
# 477 0.4233879999995415 80.0
# Average return training: 45.1
# 478 0.4227039999995419 19.0
# Average return training: 44.32
# 479 0.42205599999954224 18.0
# Average return training: 44.08
# 480 0.42147999999954255 16.0
# Average return training: 44.08
# 481 0.4202919999995432 33.0
# Average return training: 44.26
# 482 0.41647599999954527 106.0
# Average return training: 45.12
# 483 0.41579199999954564 19.0
# Average return training: 45.16
# 484 0.41525199999954593 15.0
# Average return training: 44.77
# 485 0.4142439999995465 28.0
# Average return training: 44.87
# 486 0.4138119999995467 12.0
# Average return training: 44.66
# 487 0.413271999999547 15.0
# Average return training: 44.66
# 488 0.4123359999995475 26.0
# Average return training: 44.49
# 489 0.4104999999995485 51.0
# Average return training: 44.66
# 490 0.4099599999995488 15.0
# Average return training: 44.12
# Average return over 25 episodes of playing: 115.32
# 491 0.40488399999955155 141.0
# Average return training: 45.43
# 492 0.40434399999955184 15.0
# Average return training: 45.15
# 493 0.396675999999556 213.0
# Average return training: 47.14
# 494 0.3963159999995562 10.0
# Average return training: 47.02
# 495 0.394803999999557 42.0
# Average return training: 47.33
# 496 0.39419199999955734 17.0
# Average return training: 46.6
# 497 0.3926439999995582 43.0
# Average return training: 46.09
# 498 0.3914559999995588 33.0
# Average return training: 46.27
# 499 0.3885399999995604 81.0
# Average return training: 45.59
# 500 0.3881439999995606 11.0
# Average return training: 45.24
# Average return over 25 episodes of playing: 148.76
# 501 0.38767599999956087 13.0
# Average return training: 44.39
# 502 0.38605599999956175 45.0
# Average return training: 44.39
# 503 0.3842559999995627 50.0
# Average return training: 43.28
# 504 0.38385999999956294 11.0
# Average return training: 43.24
# 505 0.3833559999995632 14.0
# Average return training: 42.83
# 506 0.3791439999995655 117.0
# Average return training: 43.77
# 507 0.3776319999995663 42.0
# Average return training: 43.34
# 508 0.3738159999995684 106.0
# Average return training: 43.55
# 509 0.37291599999956887 25.0
# Average return training: 42.78
# Average return over 25 episodes of playing: 130.6
# 510 0.3688119999995711 114.0
# Average return training: 43.26
# 511 0.3643839999995735 123.0
# Average return training: 44.31
# 512 0.36355599999957394 23.0
# Average return training: 43.42
# 513 0.36283599999957433 20.0
# Average return training: 40.97
# 514 0.3588399999995765 111.0
# Average return training: 41.6
# 515 0.3580479999995769 22.0
# Average return training: 40.12
# 516 0.35711199999957743 26.0
# Average return training: 40.16
# 517 0.35541999999957835 47.0
# Average return training: 39.4
# Average return over 25 episodes of playing: 113.12
# 518 0.3498399999995814 155.0
# Average return training: 40.71
# 519 0.34530399999958383 126.0
# Average return training: 41.86
# 520 0.341343999999586 110.0
# Average return training: 42.75
# 521 0.3409479999995862 11.0
# Average return training: 42.37
# 522 0.3403719999995865 16.0
# Average return training: 41.56
# 523 0.3397959999995868 16.0
# Average return training: 41.61
# 524 0.33497199999958943 134.0
# Average return training: 42.45
# Average return over 25 episodes of playing: 128.92
# 525 0.3307599999995917 117.0
# Average return training: 43.51
# 526 0.32978799999959224 27.0
# Average return training: 43.51
# 527 0.32568399999959446 114.0
# Average return training: 44.47
# 528 0.3250359999995948 18.0
# Average return training: 44.2
# 529 0.3238119999995955 34.0
# Average return training: 44.38
# 530 0.32330799999959575 14.0
# Average return training: 44.42
# 531 0.322839999999596 13.0
# Average return training: 44.29
# 532 0.3224439999995962 11.0
# Average return training: 44.16
# 533 0.3163599999995995 169.0
# Average return training: 45.61
# Average return over 25 episodes of playing: 123.96
# 534 0.31553199999959997 23.0
# Average return training: 45.63
# 535 0.31095999999960244 127.0
# Average return training: 46.65
# 536 0.3069999999996046 110.0
# Average return training: 47.35
# 537 0.3066399999996048 10.0
# Average return training: 47.21
# 538 0.30278799999960687 107.0
# Average return training: 48.01
# 539 0.3023559999996071 12.0
# Average return training: 47.9
# 540 0.30174399999960744 17.0
# Average return training: 47.78
# 541 0.3008799999996079 24.0
# Average return training: 46.87
# Average return over 25 episodes of playing: 123.36
# 542 0.2976039999996097 91.0
# Average return training: 47.61
# 543 0.2971719999996099 12.0
# Average return training: 47.56
# 544 0.29285199999961226 120.0
# Average return training: 48.26
# 545 0.2922399999996126 17.0
# Average return training: 48.15
# 546 0.28802799999961487 117.0
# Average return training: 48.98
# 547 0.28367199999961723 121.0
# Average return training: 50.04
# 548 0.28309599999961754 16.0
# Average return training: 50.05
# Average return over 25 episodes of playing: 121.72
# 549 0.27881199999961986 119.0
# Average return training: 50.35
# 550 0.27420399999962236 128.0
# Average return training: 51.13
# 551 0.27369999999962263 14.0
# Average return training: 51.03
# 552 0.2724759999996233 34.0
# Average return training: 51.24
# 553 0.27197199999962357 14.0
# Average return training: 51.23
# 554 0.2672559999996261 131.0
# Average return training: 52.32
# Average return over 25 episodes of playing: 124.12
# 555 0.2608119999996296 179.0
# Average return training: 53.82
# 556 0.26005599999963 21.0
# Average return training: 53.89
# 557 0.2595159999996303 15.0
# Average return training: 53.65
# 558 0.2553039999996326 117.0
# Average return training: 54.67
# 559 0.2506959999996351 128.0
# Average return training: 55.59
# 560 0.2465919999996347 114.0
# Average return training: 56.54
# 561 0.24608799999963457 14.0
# Average return training: 56.33
# 562 0.2453319999996344 21.0
# Average return training: 56.37
# Average return over 25 episodes of playing: 130.44
# 563 0.24115599999963344 116.0
# Average return training: 57.41
# 564 0.23687199999963246 119.0
# Average return training: 58.34
# 565 0.2321919999996314 130.0
# Average return training: 59.37
# 566 0.23150799999963123 19.0
# Average return training: 58.49
# 567 0.2270439999996302 124.0
# Average return training: 59.03
# Average return over 25 episodes of playing: 113.84
# 568 0.2226879999996292 121.0
# Average return training: 60.04
# 569 0.2191959999996284 97.0
# Average return training: 60.9
# 570 0.217431999999628 49.0
# Average return training: 61.23
# 571 0.21296799999962698 124.0
# Average return training: 61.85
# 572 0.20882799999962603 115.0
# Average return training: 62.8
# Average return over 25 episodes of playing: 114.36
# 573 0.2073879999996257 40.0
# Average return training: 62.91
# 574 0.20310399999962472 119.0
# Average return training: 63.49
# 575 0.19885599999962375 118.0
# Average return training: 63.29
# 576 0.19831599999962363 15.0
# Average return training: 63.32
# 577 0.19766799999962348 18.0
# Average return training: 62.7
# 578 0.1933479999996225 120.0
# Average return training: 63.71
# Average return over 25 episodes of playing: 117.52
# 579 0.18931599999962156 112.0
# Average return training: 64.65
# 580 0.18881199999962145 14.0
# Average return training: 64.63
# 581 0.1847079999996205 114.0
# Average return training: 65.44
# 582 0.18405999999962036 18.0
# Average return training: 64.56
# 583 0.1798479999996194 117.0
# Average return training: 65.54
# 584 0.1729359999996178 192.0
# Average return training: 67.31
# Average return over 25 episodes of playing: 135.72
# 585 0.16789599999961666 140.0
# Average return training: 68.43
# 586 0.16346799999961564 123.0
# Average return training: 69.54
# 587 0.15900399999961462 124.0
# Average return training: 70.63
# 588 0.15403599999961348 138.0
# Average return training: 71.75
# Average return over 25 episodes of playing: 99.48
# 589 0.14960799999961247 123.0
# Average return training: 72.47
# 590 0.14921199999961238 11.0
# Average return training: 72.43
# 591 0.1488159999996123 11.0
# Average return training: 71.13
# 592 0.14690799999961185 53.0
# Average return training: 71.51
# 593 0.14204799999961074 135.0
# Average return training: 70.73
# 594 0.1413999999996106 18.0
# Average return training: 70.81
# 595 0.1366839999996095 131.0
# Average return training: 71.7
# Average return over 25 episodes of playing: 248.8
# 596 0.13247199999960854 117.0
# Average return training: 72.7
# 597 0.1279359999996075 126.0
# Average return training: 73.53
# 598 0.12721599999960734 20.0
# Average return training: 73.4
# 599 0.12653199999960718 19.0
# Average return training: 72.78
# 600 0.12213999999960728 122.0
# Average return training: 73.89
# 601 0.1213839999996074 21.0
# Average return training: 73.97
# 602 0.12026799999960758 31.0
# Average return training: 73.83
# 603 0.11915199999960775 31.0
# Average return training: 73.64
# Average return over 25 episodes of playing: 226.52
# 604 0.11475999999960844 122.0
# Average return training: 74.75
# 605 0.11029599999960914 124.0
# Average return training: 75.85
# 606 0.1060839999996098 117.0
# Average return training: 75.85
# 607 0.10194399999961044 115.0
# Average return training: 76.58
# 608 0.1015839999996105 10.0
# Average return training: 75.62
# 609 0.10111599999961057 13.0
# Average return training: 75.5
# 610 0.10068399999961064 12.0
# Average return training: 74.48
# Average return over 25 episodes of playing: 119.16
# 611 0.1 231.0
# Average return training: 75.56
# 612 0.1 141.0
# Average return training: 76.74
# Average return over 25 episodes of playing: 302.6
# 613 0.1 224.0
# Average return training: 78.78
# 614 0.1 312.0
# Average return training: 80.79
# 615 0.1 107.0
# Average return training: 81.64
# Average return over 25 episodes of playing: 104.08
# 616 0.1 10.0
# Average return training: 81.48
# 617 0.1 121.0
# Average return training: 82.22
# Average return over 25 episodes of playing: 492.64
# 618 0.1 500.0
# Average return training: 85.67
# 619 0.1 275.0
# Average return training: 87.16
# Average return over 25 episodes of playing: 500.0
# 620 0.1 500.0
# Average return training: 91.06
# Average return over 25 episodes of playing: 500.0
# 621 0.1 367.0
# Average return training: 94.62
# Average return over 25 episodes of playing: 500.0
# 622 0.1 500.0
# Average return training: 99.46
# Average return over 25 episodes of playing: 500.0
# Average return over 100 episodes of trained agent: 500.0
