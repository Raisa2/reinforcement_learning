# %%
# Importing needed librarys
import torch
import torch.nn as nn
import gym
import numpy as np
import random
import wandb
from copy import deepcopy

# %%
# Setting seeds
def make_deterministic(seed):
  torch.manual_seed(seed)
  random.seed(seed)
  np.random.seed(seed)

# %%
# Building a class for the neural network
class Neural_Network(nn.Module):
  def __init__(self, in_dim, out_dim, hidden_dim, pre_value, pre_action):
        super(Neural_Network, self).__init__()
        config.pre_value = pre_value
        config.pre_action = pre_action
        self.input_layer = nn.Linear(in_dim, hidden_dim[0])
        self.hidden_layer = nn.Linear(hidden_dim[0], hidden_dim[1])
        # Layers for state-value function
        self.value_function_pre = nn.Linear(hidden_dim[1], pre_value)
        self.value_function = nn.Linear(pre_value, 1)
        # Layers for advantage function
        self.advantage_function_pre = nn.Linear(hidden_dim[1], pre_action)
        self.advantage_function = nn.Linear(pre_action, out_dim)
       
  def forward (self, x, activation_function = nn.ReLU()):
    x = activation_function(self.input_layer(x))
    x = activation_function(self.hidden_layer(x))
    # Calculating advantage function
    a_pre = self.advantage_function_pre(x)
    a = self.advantage_function(a_pre)
    # Calculating state-value function
    v_pre = self.value_function_pre(x)
    v = self.value_function(v_pre)
    a_mean = a.mean(-1, keepdim = True)
    # Calculating q-values
    output = v + (a - a_mean)
    return output

# %%
# Defining function for epsilon greedy actions
def eps_greedy(state, online_model, eps):
  with torch.no_grad():
    if (np.random.rand() > eps):
      value, inds  = torch.max(online_model(state), dim=0)
      return inds.item()
    else:
      action = np.random.choice(env.action_space.n)
      return action

# %%
# Defining function for playing during and after training to obtain performance of the agent
def play(episodes, step, end, envs):
  x = 0
  returns = []

  for i in range(0, episodes):
    memory_states = [] 
    memory_actions = [] 
    memory_rewards = [] 
    memory_terminal = [] 
    memory_states_next = []

    state = envs.reset()
    while True:
      action = eps_greedy(state = torch.tensor(state).float() , online_model = online_model, eps = -1)
      state_next, reward, done, _ = envs.step(action)
      memory_actions.append(action)
      memory_states.append(state)
      memory_states_next.append(state_next)
      memory_rewards.append(reward)
      memory_terminal.append(done)
      state = state_next

      if done:
        x = sum(memory_rewards)
        state = envs.reset()
        returns.append(x)
        break

  if end:
    avg_return = sum(returns[-100:]) / 100
    print("Average return over 100 episodes of trained agent:", avg_return)
  else:
    avg_return = sum(returns[-25:]) / 25
    wandb.log({"Average return over 25 episodes of playing": avg_return,"step": step})
    print("Average return over 25 episodes of playing:", avg_return)

  return avg_return

# %%
##### Dueling Double DQN Algorithm ###########

# Seeds for repeatable training results
SEEDS = (12, 34, 56)

# Creating two environments: One for training and for playing
env = gym.make("CartPole-v1")
env2 = gym.make("CartPole-v1")

# Looping over different seeds for training different agents
for seed in SEEDS:
  make_deterministic(seed)
  print("SEED:", seed)
  wandb.init(project="DuelingDDQN-CartPole", entity="raisa")
  config = wandb.config

  # Defining hyperparameters
  gamma = 0.99 # gamma
  eps_max = 1 # maximum value for epsilon
  eps_min = 0.1 # minimum value for epsilon
  eps_decay = (1-0.1) / 25000 # decaying factor for epsilon
  learning_rate = 0.0025 # learning rate
  batch_size = 64 # batch size
  num_episodes = 1000 # maximum number of episodes
  min_memory = 100 # size of replay memory at start of training
  max_memory =  1000 # maximum size of replay memory
  hidden_dims = [128, 64] # size of hidden layers in the neural network
  hidden_dim_action = 10 # size of hidden layer for computing advantage function
  hidden_dim_state =  10 # size of hidden layer for computing state-value function
  act_period = 150 # update frequency of target neural network
  criterion = nn.MSELoss() # loss function
  tau = 0.9 # update factor for target net weights

  # Logging hyperparameters
  config.learning_rate = learning_rate
  config.gamma = gamma
  config.batch_size = batch_size
  config.num_episodes = num_episodes
  config.max_memory = max_memory
  config.min_memory = min_memory
  config.hidden_dim = hidden_dims
  config.act_period = act_period
  config.eps_max = eps_max
  config.eps_min = eps_min
  config.eps_decay = eps_decay
  config.hidden_dim_action = hidden_dim_action
  config.hidden_dim_state = hidden_dim_state
  config.tau = tau
  config.seed = seed

  # Setting the seed for the environments
  env.seed(seed)
  env.action_space.seed(seed)
  env2.seed(seed)
  env2.action_space.seed(seed)

  # Initializing replay memory
  memory_states = [] 
  memory_actions = [] 
  memory_rewards = [] 
  memory_terminal = [] 
  memory_states_next = []
  reward_durch = []
  reward_werte = []

  # Initializing list for average returns during training
  returns_train = []
  # Initializing list for average returns during playing
  returns_play = []

  # Creating neural networks and setting optimizer
  online_model = (Neural_Network(in_dim = int(np.prod(env.observation_space.shape)), out_dim = env.action_space.n, hidden_dim=hidden_dims, pre_value = hidden_dim_state, pre_action = hidden_dim_action)) 
  target_model = (Neural_Network(in_dim = int(np.prod(env.observation_space.shape)), out_dim = env.action_space.n, hidden_dim=hidden_dims, pre_value = hidden_dim_state, pre_action = hidden_dim_action)) 
  optimizer = torch.optim.Adam(online_model.parameters(), lr=learning_rate)
  target_model = deepcopy(online_model) 

  # Storing minimum experiences in replay memory
  state = env.reset()
  for step in range(0, min_memory):
    action = env.action_space.sample()
    state_next, reward, done, _ = env.step(action)
    memory_actions.append(action)
    memory_states.append(state)
    memory_states_next.append(state_next)
    memory_rewards.append(reward)
    memory_terminal.append(done)
    state = state_next

    if done:
      state = env.reset()

  epsi = eps_max
  step = 0

  # Training agent for number of episodes
  for episode in range(0, num_episodes):
    state = env.reset()
    reward_sum = 0
    while True:
      step += 1

    # Deleting first element of replay memory if max_memory length is reached
      if(len(memory_states) > max_memory):
        memory_actions.pop(0)
        memory_states.pop(0)
        memory_states_next.pop(0)
        memory_rewards.pop(0)
        memory_terminal.pop(0)

    # Taking epsilon greedy action and store experience in replay memory
      epsi = max(epsi - eps_decay, eps_min)
      action = eps_greedy(state = torch.tensor(state).float() , online_model = online_model, eps = epsi)
      state_next, reward, done, _ = env.step(action)
      memory_actions.append(action)
      memory_states.append(state)
      memory_states_next.append(state_next)
      memory_rewards.append(reward)
      memory_terminal.append(done)
      state = state_next

      reward_sum+=reward

    # Selecting random batch of experiences
      rand_index = np.random.choice(len(memory_states_next), size=batch_size, replace=False)
      batch_states = torch.tensor(np.array(memory_states)[rand_index], dtype=torch.float32) 
      batch_states_next = torch.tensor(np.array(memory_states_next)[rand_index], dtype=torch.float32) 
      batch_rewards = torch.tensor(np.array(memory_rewards)[rand_index], dtype=torch.float32) 
      batch_actions = torch.tensor(np.array(memory_actions)[rand_index], dtype=torch.int64) 
      batch_terminal = torch.tensor(np.array(memory_terminal)[rand_index], dtype=torch.int64) 
    
    # Calculating q-values for training
      with torch.no_grad():
      # Calculating q-values for next possible states
        q_values_next = online_model(batch_states_next)
      # Calculating indices of max q-values
        _, inds = torch.max(q_values_next,dim=1)
        inds = torch.reshape(input = inds, shape = (batch_size, 1))
      # Evaluating these actions with the help of target model
        max_q_values_next = torch.gather(target_model(batch_states_next), 1, inds)
        max_q_values_next = (torch.reshape(max_q_values_next, (-1,)))
      # Calculating the target q-values 
        q_target = (batch_rewards + gamma * (1 - batch_terminal) * max_q_values_next)
  
      # Calculating the expected q-values
      q_exp = online_model(batch_states)
      batch_actions = torch.reshape(input = batch_actions, shape = (batch_size, 1))
      q_exp = torch.gather(input = q_exp, dim = 1, index = batch_actions)
      q_exp = (torch.reshape(q_exp, (-1,))) 

      # Calculating loss
      loss = criterion(q_target, q_exp) 

      optimizer.zero_grad()

      # Backpropagating the loss
      loss.backward()

      # Taking an optimization step
      optimizer.step()

      # Updating target network softer every act_period steps
      if step % act_period == 0:
        for target, online in zip(target_model.parameters(), online_model.parameters()):
          target.data.mul_(1 - tau)
          target.data.add_(tau * online.data)

      # Playing every 500 steps to obtain the performance of the agent
      if step % 500 == 0:
        avg_return_play = play(episodes = 25, step = step, end = False, envs = env2)
        returns_play.append(avg_return_play)
      
      # If an episode has to come to an end, reset environment and print the reward for the last episode
      if done:
        print(episode + 1, epsi, reward_sum)
        returns_train.append(reward_sum)

        # If episode > 100, then print the average reward for the last hundred episodes 
        if episode + 1  > 100:
          x = sum(returns_train[-100:])/100
          print("Average return training:", x)
          # Logging the training average return
          wandb.log({"Average return over 100 episodes of training": x, "episode": episode + 1})  
        break

    # If training steps >= 2500 and the agent has obtained an average reward of 475 during last 5 times of playing, end training
    if step >= 2500:
      if sum(returns_play[-5:]) / 5 >= 475:
        break

  # Playing after training to obtain end results
  play(episodes = 100, step = step, end = True, envs = env2)
# Out:
# SEED: 12
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                     Syncing run <strong><a href="https://wandb.ai/raisa/DuelingDDQN-CartPole/runs/2cvwy64i" target="_blank">happy-microwave-39</a></strong> to <a href="https://wandb.ai/raisa/DuelingDDQN-CartPole" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 1 0.9996039999999996 11.0
# 2 0.9991719999999992 12.0
# 3 0.9984159999999984 21.0
# 4 0.9971919999999972 34.0
# 5 0.9962559999999963 26.0
# 6 0.9957879999999958 13.0
# 7 0.993987999999994 50.0
# 8 0.9935919999999936 11.0
# 9 0.9931599999999932 12.0
# 10 0.9925119999999925 18.0
# 11 0.9918999999999919 17.0
# 12 0.9914679999999915 12.0
# 13 0.9907839999999908 19.0
# 14 0.9896319999999896 32.0
# 15 0.9888039999999888 23.0
# 16 0.9880839999999881 20.0
# 17 0.9871479999999871 26.0
# 18 0.9858879999999859 35.0
# 19 0.9852399999999852 18.0
# 20 0.9846279999999846 17.0
# 21 0.9842319999999842 11.0
# 22 0.9835479999999835 19.0
# 23 0.9820719999999821 41.0
# Average return over 25 episodes of playing: 19.88
# 24 0.9815319999999815 15.0
# 25 0.980955999999981 16.0
# 26 0.9804159999999804 15.0
# 27 0.9797319999999797 19.0
# 28 0.9787599999999788 27.0
# 29 0.978003999999978 21.0
# 30 0.9775359999999775 13.0
# 31 0.976995999999977 15.0
# 32 0.9751239999999751 52.0
# 33 0.9733599999999734 49.0
# 34 0.971991999999972 38.0
# 35 0.971055999999971 26.0
# 36 0.9705879999999706 13.0
# 37 0.9691119999999691 41.0
# 38 0.9683559999999684 21.0
# 39 0.9678879999999679 13.0
# 40 0.9668799999999669 28.0
# 41 0.9652959999999653 44.0
# 42 0.9642879999999643 28.0
# Average return over 25 episodes of playing: 263.08
# 43 0.9637839999999638 14.0
# 44 0.9628479999999628 26.0
# 45 0.9621999999999622 18.0
# 46 0.9608679999999609 37.0
# 47 0.9598239999999598 29.0
# 48 0.9582759999999583 43.0
# 49 0.9567999999999568 41.0
# 50 0.9564039999999564 11.0
# 51 0.9547479999999547 46.0
# 52 0.9540999999999541 18.0
# 53 0.9537399999999537 10.0
# 54 0.9525879999999526 32.0
# 55 0.9507159999999507 52.0
# 56 0.9502839999999503 12.0
# 57 0.9494199999999494 24.0
# 58 0.9473679999999474 57.0
# Average return over 25 episodes of playing: 166.48
# 59 0.9457479999999457 45.0
# 60 0.9452439999999452 14.0
# 61 0.9447399999999447 14.0
# 62 0.9442359999999442 14.0
# 63 0.9438399999999438 11.0
# 64 0.9433719999999434 13.0
# 65 0.9426159999999426 21.0
# 66 0.9418239999999418 22.0
# 67 0.9410679999999411 21.0
# 68 0.9405279999999405 15.0
# 69 0.9390879999999391 40.0
# 70 0.9381159999999381 27.0
# 71 0.9376839999999377 12.0
# 72 0.9370719999999371 17.0
# 73 0.9363519999999363 20.0
# 74 0.9358479999999358 14.0
# 75 0.9353799999999354 13.0
# 76 0.9348399999999348 15.0
# 77 0.9343719999999344 13.0
# 78 0.9339039999999339 13.0
# 79 0.933039999999933 24.0
# 80 0.9317799999999318 35.0
# 81 0.9312039999999312 16.0
# 82 0.9307359999999307 13.0
# 83 0.9302319999999302 14.0
# 84 0.9292239999999292 28.0
# 85 0.9287559999999287 13.0
# Average return over 25 episodes of playing: 146.08
# 86 0.9274959999999275 35.0
# 87 0.9267399999999267 21.0
# 88 0.926019999999926 20.0
# 89 0.9252639999999253 21.0
# 90 0.9248319999999248 12.0
# 91 0.9239319999999239 25.0
# 92 0.9233559999999233 16.0
# 93 0.9226359999999226 20.0
# 94 0.9215559999999215 30.0
# 95 0.9198999999999199 46.0
# 96 0.9193599999999194 15.0
# 97 0.9188919999999189 13.0
# 98 0.9184239999999184 13.0
# 99 0.9177759999999178 18.0
# 100 0.9171279999999171 18.0
# 101 0.9151479999999151 55.0
# Average return training: 23.46
# 102 0.9143559999999143 22.0
# Average return training: 23.56
# 103 0.9135279999999135 23.0
# Average return training: 23.58
# 104 0.9128439999999128 19.0
# Average return training: 23.43
# 105 0.9121959999999122 18.0
# Average return training: 23.35
# 106 0.9115839999999116 17.0
# Average return training: 23.39
# 107 0.9111519999999111 12.0
# Average return training: 23.01
# Average return over 25 episodes of playing: 66.68
# 108 0.9096039999999096 43.0
# Average return training: 23.33
# 109 0.9087759999999088 23.0
# Average return training: 23.44
# 110 0.9081639999999082 17.0
# Average return training: 23.43
# 111 0.9075879999999076 16.0
# Average return training: 23.42
# 112 0.907047999999907 15.0
# Average return training: 23.45
# 113 0.9063279999999063 20.0
# Average return training: 23.46
# 114 0.9056439999999056 19.0
# Average return training: 23.33
# 115 0.9050679999999051 16.0
# Average return training: 23.26
# 116 0.9043479999999043 20.0
# Average return training: 23.26
# 117 0.9038079999999038 15.0
# Average return training: 23.15
# 118 0.9029079999999029 25.0
# Average return training: 23.05
# 119 0.9019359999999019 27.0
# Average return training: 23.14
# 120 0.9011799999999012 21.0
# Average return training: 23.18
# 121 0.9003159999999003 24.0
# Average return training: 23.31
# 122 0.8997759999998998 15.0
# Average return training: 23.27
# 123 0.8993799999998994 11.0
# Average return training: 22.97
# 124 0.8987319999998987 18.0
# Average return training: 23.0
# 125 0.898047999999898 19.0
# Average return training: 23.03
# 126 0.8974719999998975 16.0
# Average return training: 23.04
# 127 0.8969319999998969 15.0
# Average return training: 23.0
# 128 0.8962119999998962 20.0
# Average return training: 22.93
# 129 0.8957079999998957 14.0
# Average return training: 22.86
# 130 0.8948799999998949 23.0
# Average return training: 22.96
# 131 0.8940879999998941 22.0
# Average return training: 23.03
# 132 0.8927919999998928 36.0
# Average return training: 22.87
# 133 0.8923239999998923 13.0
# Average return training: 22.51
# Average return over 25 episodes of playing: 44.04
# 134 0.890991999999891 37.0
# Average return training: 22.5
# 135 0.8903799999998904 17.0
# Average return training: 22.41
# 136 0.8891199999998891 35.0
# Average return training: 22.63
# 137 0.8882559999998882 24.0
# Average return training: 22.46
# 138 0.8838279999998838 123.0
# Average return training: 23.48
# 139 0.8817039999998817 59.0
# Average return training: 23.94
# 140 0.8811999999998812 14.0
# Average return training: 23.8
# 141 0.8792919999998793 53.0
# Average return training: 23.89
# 142 0.8788599999998788 12.0
# Average return training: 23.73
# 143 0.8780679999998781 22.0
# Average return training: 23.81
# 144 0.8765199999998765 43.0
# Average return training: 23.98
# 145 0.8760879999998761 12.0
# Average return training: 23.92
# 146 0.8752959999998753 22.0
# Average return training: 23.77
# Average return over 25 episodes of playing: 116.64
# 147 0.8734599999998734 51.0
# Average return training: 23.99
# 148 0.8729199999998729 15.0
# Average return training: 23.71
# 149 0.8724159999998724 14.0
# Average return training: 23.44
# 150 0.8719479999998719 13.0
# Average return training: 23.46
# 151 0.8707959999998708 32.0
# Average return training: 23.32
# 152 0.86996799999987 23.0
# Average return training: 23.37
# 153 0.8692479999998692 20.0
# Average return training: 23.47
# 154 0.8688879999998689 10.0
# Average return training: 23.25
# 155 0.8685279999998685 10.0
# Average return training: 22.83
# 156 0.868023999999868 14.0
# Average return training: 22.85
# 157 0.8675559999998675 13.0
# Average return training: 22.74
# 158 0.8656479999998656 53.0
# Average return training: 22.7
# 159 0.8645319999998645 31.0
# Average return training: 22.56
# 160 0.863991999999864 15.0
# Average return training: 22.57
# 161 0.8627679999998628 34.0
# Average return training: 22.77
# 162 0.8622999999998623 13.0
# Average return training: 22.76
# 163 0.8619039999998619 11.0
# Average return training: 22.76
# 164 0.8602119999998602 47.0
# Average return training: 23.1
# 165 0.8581959999998582 56.0
# Average return training: 23.45
# 166 0.8576919999998577 14.0
# Average return training: 23.37
# 167 0.8569359999998569 21.0
# Average return training: 23.37
# 168 0.856035999999856 25.0
# Average return training: 23.47
# Average return over 25 episodes of playing: 97.84
# 169 0.8554959999998555 15.0
# Average return training: 23.22
# 170 0.853983999999854 42.0
# Average return training: 23.37
# 171 0.8531199999998531 24.0
# Average return training: 23.49
# 172 0.8522559999998522 24.0
# Average return training: 23.56
# 173 0.8516079999998516 18.0
# Average return training: 23.54
# 174 0.8496279999998496 55.0
# Average return training: 23.95
# 175 0.8492319999998492 11.0
# Average return training: 23.93
# 176 0.8478279999998478 39.0
# Average return training: 24.17
# 177 0.8464599999998464 38.0
# Average return training: 24.42
# 178 0.8458479999998458 17.0
# Average return training: 24.46
# 179 0.8450919999998451 21.0
# Average return training: 24.43
# 180 0.8445159999998445 16.0
# Average return training: 24.24
# 181 0.8438679999998439 18.0
# Average return training: 24.26
# 182 0.8413839999998414 69.0
# Average return training: 24.82
# 183 0.8407359999998407 18.0
# Average return training: 24.86
# 184 0.8396919999998397 29.0
# Average return training: 24.87
# 185 0.8388999999998389 22.0
# Average return training: 24.96
# 186 0.8383599999998383 15.0
# Average return training: 24.76
# Average return over 25 episodes of playing: 99.72
# 187 0.8377479999998377 17.0
# Average return training: 24.72
# 188 0.8373159999998373 12.0
# Average return training: 24.64
# 189 0.8364879999998365 23.0
# Average return training: 24.66
# 190 0.8358759999998359 17.0
# Average return training: 24.71
# 191 0.8354439999998354 12.0
# Average return training: 24.58
# 192 0.835047999999835 11.0
# Average return training: 24.53
# 193 0.8336079999998336 40.0
# Average return training: 24.73
# 194 0.8331759999998332 12.0
# Average return training: 24.55
# 195 0.8316639999998316 42.0
# Average return training: 24.51
# 196 0.8312679999998313 11.0
# Average return training: 24.47
# 197 0.8308359999998308 12.0
# Average return training: 24.46
# 198 0.8302239999998302 17.0
# Average return training: 24.5
# 199 0.8293599999998293 24.0
# Average return training: 24.56
# 200 0.8274159999998274 54.0
# Average return training: 24.92
# 201 0.8245359999998245 80.0
# Average return training: 25.17
# 202 0.824067999999824 13.0
# Average return training: 25.08
# 203 0.8236359999998236 12.0
# Average return training: 24.97
# 204 0.8228799999998229 21.0
# Average return training: 24.99
# 205 0.8223039999998223 16.0
# Average return training: 24.97
# 206 0.8219079999998219 11.0
# Average return training: 24.91
# 207 0.8207559999998207 32.0
# Average return training: 25.11
# 208 0.8203239999998203 12.0
# Average return training: 24.8
# Average return over 25 episodes of playing: 117.76
# 209 0.8193159999998193 28.0
# Average return training: 24.85
# 210 0.8188479999998188 13.0
# Average return training: 24.81
# 211 0.8155719999998156 91.0
# Average return training: 25.56
# 212 0.8146359999998146 26.0
# Average return training: 25.67
# 213 0.8127279999998127 53.0
# Average return training: 26.0
# 214 0.8116839999998117 29.0
# Average return training: 26.1
# 215 0.811071999999811 17.0
# Average return training: 26.11
# 216 0.8103519999998103 20.0
# Average return training: 26.11
# 217 0.8097039999998097 18.0
# Average return training: 26.14
# 218 0.8086599999998086 29.0
# Average return training: 26.18
# 219 0.8083359999998083 9.0
# Average return training: 26.0
# 220 0.8076879999998077 18.0
# Average return training: 25.97
# 221 0.8071119999998071 16.0
# Average return training: 25.89
# 222 0.8065359999998065 16.0
# Average return training: 25.9
# 223 0.806031999999806 14.0
# Average return training: 25.93
# 224 0.8053119999998053 20.0
# Average return training: 25.95
# 225 0.8031519999998031 60.0
# Average return training: 26.36
# Average return over 25 episodes of playing: 68.0
# 226 0.8019279999998019 34.0
# Average return training: 26.54
# 227 0.8013519999998013 16.0
# Average return training: 26.55
# 228 0.8008119999998008 15.0
# Average return training: 26.5
# 229 0.8001999999998002 17.0
# Average return training: 26.53
# 230 0.7997679999997998 12.0
# Average return training: 26.42
# 231 0.798975999999799 22.0
# Average return training: 26.42
# 232 0.7972839999997973 47.0
# Average return training: 26.53
# 233 0.7965639999997965 20.0
# Average return training: 26.6
# 234 0.7953399999997953 34.0
# Average return training: 26.57
# 235 0.794979999999795 10.0
# Average return training: 26.5
# 236 0.7938279999997938 32.0
# Average return training: 26.47
# 237 0.7932879999997933 15.0
# Average return training: 26.38
# 238 0.7918839999997919 39.0
# Average return training: 25.54
# 239 0.7909119999997909 27.0
# Average return training: 25.22
# 240 0.7888599999997888 57.0
# Average return training: 25.65
# 241 0.7882839999997883 16.0
# Average return training: 25.28
# 242 0.7875639999997875 20.0
# Average return training: 25.36
# 243 0.7862319999997862 37.0
# Average return training: 25.51
# 244 0.7858719999997859 10.0
# Average return training: 25.18
# 245 0.7847919999997848 30.0
# Average return training: 25.36
# Average return over 25 episodes of playing: 113.0
# 246 0.7838919999997839 25.0
# Average return training: 25.39
# 247 0.7832799999997833 17.0
# Average return training: 25.05
# 248 0.7827039999997827 16.0
# Average return training: 25.06
# 249 0.7821999999997822 14.0
# Average return training: 25.06
# 250 0.7812639999997812 26.0
# Average return training: 25.19
# 251 0.7804719999997805 22.0
# Average return training: 25.09
# 252 0.7794639999997794 28.0
# Average return training: 25.14
# 253 0.7775559999997775 53.0
# Average return training: 25.47
# 254 0.7768719999997769 19.0
# Average return training: 25.56
# 255 0.7762959999997763 16.0
# Average return training: 25.62
# 256 0.7754679999997754 23.0
# Average return training: 25.71
# 257 0.7747479999997747 20.0
# Average return training: 25.78
# 258 0.7739199999997739 23.0
# Average return training: 25.48
# 259 0.7723719999997724 43.0
# Average return training: 25.6
# 260 0.7698159999997698 71.0
# Average return training: 26.16
# 261 0.7692039999997692 17.0
# Average return training: 25.99
# 262 0.7683399999997683 24.0
# Average return training: 26.1
# 263 0.7679079999997679 12.0
# Average return training: 26.11
# Average return over 25 episodes of playing: 114.72
# 264 0.7638039999997638 114.0
# Average return training: 26.78
# 265 0.762003999999762 50.0
# Average return training: 26.72
# 266 0.7613919999997614 17.0
# Average return training: 26.75
# 267 0.7608879999997609 14.0
# Average return training: 26.68
# 268 0.7604559999997604 12.0
# Average return training: 26.55
# 269 0.7591959999997592 35.0
# Average return training: 26.75
# 270 0.7587639999997587 12.0
# Average return training: 26.45
# 271 0.7577559999997577 28.0
# Average return training: 26.49
# 272 0.7571439999997571 17.0
# Average return training: 26.42
# 273 0.7567119999997567 12.0
# Average return training: 26.36
# 274 0.7562079999997562 14.0
# Average return training: 25.95
# 275 0.7557759999997558 12.0
# Average return training: 25.96
# 276 0.755055999999755 20.0
# Average return training: 25.77
# 277 0.7541919999997542 24.0
# Average return training: 25.63
# 278 0.7538319999997538 10.0
# Average return training: 25.56
# 279 0.7534359999997534 11.0
# Average return training: 25.46
# 280 0.752967999999753 13.0
# Average return training: 25.43
# 281 0.7521759999997522 22.0
# Average return training: 25.47
# 282 0.7516359999997516 15.0
# Average return training: 24.93
# 283 0.7511319999997511 14.0
# Average return training: 24.89
# 284 0.7503759999997504 21.0
# Average return training: 24.81
# 285 0.7495839999997496 22.0
# Average return training: 24.81
# 286 0.7490799999997491 14.0
# Average return training: 24.8
# 287 0.7485399999997485 15.0
# Average return training: 24.78
# Average return over 25 episodes of playing: 97.68
# 288 0.7475679999997475 27.0
# Average return training: 24.93
# 289 0.746991999999747 16.0
# Average return training: 24.86
# 290 0.7463079999997463 19.0
# Average return training: 24.88
# 291 0.7458759999997459 12.0
# Average return training: 24.88
# 292 0.745047999999745 23.0
# Average return training: 25.0
# 293 0.7444359999997444 17.0
# Average return training: 24.77
# 294 0.743967999999744 13.0
# Average return training: 24.78
# 295 0.7434279999997434 15.0
# Average return training: 24.51
# 296 0.7429239999997429 14.0
# Average return training: 24.54
# 297 0.7423119999997423 17.0
# Average return training: 24.59
# 298 0.7416279999997416 19.0
# Average return training: 24.61
# 299 0.7406559999997406 27.0
# Average return training: 24.64
# 300 0.7402959999997403 10.0
# Average return training: 24.2
# 301 0.7398639999997398 12.0
# Average return training: 23.52
# 302 0.7393239999997393 15.0
# Average return training: 23.54
# 303 0.7386399999997386 19.0
# Average return training: 23.61
# 304 0.7373079999997373 37.0
# Average return training: 23.77
# 305 0.7357959999997358 42.0
# Average return training: 24.03
# 306 0.7348239999997348 27.0
# Average return training: 24.19
# 307 0.7344999999997345 9.0
# Average return training: 23.96
# 308 0.7338879999997339 17.0
# Average return training: 24.01
# 309 0.7331679999997331 20.0
# Average return training: 23.93
# 310 0.7326999999997327 13.0
# Average return training: 23.93
# 311 0.7322319999997322 13.0
# Average return training: 23.15
# 312 0.7315839999997316 18.0
# Average return training: 23.07
# 313 0.7311159999997311 13.0
# Average return training: 22.67
# 314 0.7305399999997305 16.0
# Average return training: 22.54
# 315 0.7301799999997302 10.0
# Average return training: 22.47
# Average return over 25 episodes of playing: 93.56
# 316 0.7294239999997294 21.0
# Average return training: 22.48
# 317 0.7288479999997288 16.0
# Average return training: 22.46
# 318 0.7275519999997275 36.0
# Average return training: 22.53
# 319 0.7271919999997272 10.0
# Average return training: 22.54
# 320 0.7263279999997263 24.0
# Average return training: 22.6
# 321 0.7258959999997259 12.0
# Average return training: 22.56
# 322 0.7251039999997251 22.0
# Average return training: 22.62
# 323 0.7235559999997235 43.0
# Average return training: 22.91
# 324 0.7231239999997231 12.0
# Average return training: 22.83
# 325 0.7227639999997227 10.0
# Average return training: 22.33
# 326 0.7214319999997214 37.0
# Average return training: 22.36
# 327 0.7209639999997209 13.0
# Average return training: 22.33
# 328 0.7204959999997205 13.0
# Average return training: 22.31
# 329 0.72002799999972 13.0
# Average return training: 22.27
# 330 0.7195239999997195 14.0
# Average return training: 22.29
# 331 0.7183359999997183 33.0
# Average return training: 22.4
# 332 0.7175079999997175 23.0
# Average return training: 22.16
# 333 0.7139079999997139 100.0
# Average return training: 22.96
# 334 0.7133679999997133 15.0
# Average return training: 22.77
# 335 0.712971999999713 11.0
# Average return training: 22.78
# Average return over 25 episodes of playing: 70.32
# 336 0.711999999999712 27.0
# Average return training: 22.73
# 337 0.7112079999997112 22.0
# Average return training: 22.8
# 338 0.7104519999997104 21.0
# Average return training: 22.62
# 339 0.7087599999997087 47.0
# Average return training: 22.82
# 340 0.7078239999997078 26.0
# Average return training: 22.51
# 341 0.7069599999997069 24.0
# Average return training: 22.59
# 342 0.7055199999997055 40.0
# Average return training: 22.79
# 343 0.7047999999997048 20.0
# Average return training: 22.62
# 344 0.7039359999997039 24.0
# Average return training: 22.76
# 345 0.7035399999997035 11.0
# Average return training: 22.57
# 346 0.7031799999997032 10.0
# Average return training: 22.42
# 347 0.7015599999997015 45.0
# Average return training: 22.7
# 348 0.700983999999701 16.0
# Average return training: 22.7
# 349 0.6995079999996995 41.0
# Average return training: 22.97
# 350 0.6975279999996975 55.0
# Average return training: 23.26
# 351 0.6968079999996968 20.0
# Average return training: 23.24
# 352 0.6958359999996958 27.0
# Average return training: 23.23
# 353 0.6947559999996947 30.0
# Average return training: 23.0
# 354 0.6943239999996943 12.0
# Average return training: 22.93
# Average return over 25 episodes of playing: 105.96
# 355 0.6936399999996936 19.0
# Average return training: 22.96
# 356 0.6901119999996901 98.0
# Average return training: 23.71
# 357 0.6878079999996878 64.0
# Average return training: 24.15
# 358 0.686043999999686 49.0
# Average return training: 24.41
# 359 0.6851799999996852 24.0
# Average return training: 24.22
# 360 0.682047999999682 87.0
# Average return training: 24.38
# 361 0.6811839999996812 24.0
# Average return training: 24.45
# 362 0.6804999999996805 19.0
# Average return training: 24.4
# 363 0.67999599999968 14.0
# Average return training: 24.42
# 364 0.6790959999996791 25.0
# Average return training: 23.53
# 365 0.6785559999996785 15.0
# Average return training: 23.18
# 366 0.6773319999996773 34.0
# Average return training: 23.35
# Average return over 25 episodes of playing: 87.04
# 367 0.6757839999996758 43.0
# Average return training: 23.64
# 368 0.6752439999996752 15.0
# Average return training: 23.67
# 369 0.6741279999996741 31.0
# Average return training: 23.63
# 370 0.6729399999996729 33.0
# Average return training: 23.84
# 371 0.6717159999996717 34.0
# Average return training: 23.9
# 372 0.6712119999996712 14.0
# Average return training: 23.87
# 373 0.6707799999996708 12.0
# Average return training: 23.87
# 374 0.6696639999996696 31.0
# Average return training: 24.04
# 375 0.6666759999996666 83.0
# Average return training: 24.75
# 376 0.6656679999996656 28.0
# Average return training: 24.83
# 377 0.665055999999665 17.0
# Average return training: 24.76
# 378 0.6643719999996643 19.0
# Average return training: 24.85
# 379 0.663975999999664 11.0
# Average return training: 24.85
# 380 0.6623559999996623 45.0
# Average return training: 25.17
# 381 0.6615999999996616 21.0
# Average return training: 25.16
# 382 0.6583239999996583 91.0
# Average return training: 25.92
# Average return over 25 episodes of playing: 77.84
# 383 0.6573159999996573 28.0
# Average return training: 26.06
# 384 0.654075999999654 90.0
# Average return training: 26.75
# 385 0.6498639999996498 117.0
# Average return training: 27.7
# 386 0.6494319999996494 12.0
# Average return training: 27.68
# 387 0.6439599999996439 152.0
# Average return training: 29.05
# 388 0.6434559999996434 14.0
# Average return training: 28.92
# 389 0.6426639999996426 22.0
# Average return training: 28.98
# 390 0.6406479999996406 56.0
# Average return training: 29.35
# Average return over 25 episodes of playing: 219.4
# 391 0.6375879999996376 85.0
# Average return training: 30.08
# 392 0.637011999999637 16.0
# Average return training: 30.01
# 393 0.6358599999996358 32.0
# Average return training: 30.16
# 394 0.632979999999633 80.0
# Average return training: 30.83
# 395 0.6323679999996323 17.0
# Average return training: 30.85
# 396 0.6319719999996319 11.0
# Average return training: 30.82
# 397 0.6313959999996314 16.0
# Average return training: 30.81
# 398 0.6311079999996311 8.0
# Average return training: 30.7
# 399 0.6291999999996292 53.0
# Average return training: 30.96
# 400 0.6273279999996273 52.0
# Average return training: 31.38
# 401 0.6267159999996267 17.0
# Average return training: 31.43
# 402 0.6262119999996262 14.0
# Average return training: 31.42
# 403 0.6237639999996237 68.0
# Average return training: 31.91
# 404 0.6231879999996232 16.0
# Average return training: 31.7
# 405 0.622071999999622 31.0
# Average return training: 31.59
# Average return over 25 episodes of playing: 259.84
# 406 0.6212439999996212 23.0
# Average return training: 31.55
# 407 0.6207039999996207 15.0
# Average return training: 31.61
# 408 0.6202719999996202 12.0
# Average return training: 31.56
# 409 0.6198399999996198 12.0
# Average return training: 31.48
# 410 0.6191559999996191 19.0
# Average return training: 31.54
# 411 0.6179319999996179 34.0
# Average return training: 31.75
# 412 0.6174639999996174 13.0
# Average return training: 31.7
# 413 0.6132519999996132 117.0
# Average return training: 32.74
# 414 0.6123879999996124 24.0
# Average return training: 32.82
# 415 0.6119199999996119 13.0
# Average return training: 32.85
# 416 0.6114159999996114 14.0
# Average return training: 32.78
# 417 0.6106599999996106 21.0
# Average return training: 32.83
# 418 0.6086439999996086 56.0
# Average return training: 33.03
# 419 0.6082119999996082 12.0
# Average return training: 33.05
# 420 0.6078159999996078 11.0
# Average return training: 32.92
# 421 0.6073479999996073 13.0
# Average return training: 32.93
# 422 0.6057999999996058 43.0
# Average return training: 33.14
# Average return over 25 episodes of playing: 117.44
# 423 0.601983999999602 106.0
# Average return training: 33.77
# 424 0.5998599999995998 59.0
# Average return training: 34.24
# 425 0.5981679999995981 47.0
# Average return training: 34.61
# 426 0.5969079999995969 35.0
# Average return training: 34.59
# 427 0.5953239999995953 44.0
# Average return training: 34.9
# 428 0.5947479999995947 16.0
# Average return training: 34.93
# 429 0.5941719999995941 16.0
# Average return training: 34.96
# 430 0.5933799999995933 22.0
# Average return training: 35.04
# 431 0.5927319999995927 18.0
# Average return training: 34.89
# 432 0.5912199999995912 42.0
# Average return training: 35.08
# 433 0.5905359999995905 19.0
# Average return training: 34.27
# 434 0.5895999999995896 26.0
# Average return training: 34.38
# Average return over 25 episodes of playing: 104.32
# 435 0.5858199999995858 105.0
# Average return training: 35.32
# 436 0.5854239999995854 11.0
# Average return training: 35.16
# 437 0.5847759999995847 18.0
# Average return training: 35.12
# 438 0.5843079999995843 13.0
# Average return training: 35.04
# 439 0.5839119999995839 11.0
# Average return training: 34.68
# 440 0.5823999999995824 42.0
# Average return training: 34.84
# 441 0.5814639999995814 26.0
# Average return training: 34.86
# 442 0.5804559999995804 28.0
# Average return training: 34.74
# 443 0.5795199999995795 26.0
# Average return training: 34.8
# 444 0.579015999999579 14.0
# Average return training: 34.7
# 445 0.5782239999995782 22.0
# Average return training: 34.81
# 446 0.5771439999995771 30.0
# Average return training: 35.01
# 447 0.5757399999995757 39.0
# Average return training: 34.95
# 448 0.5718159999995718 109.0
# Average return training: 35.88
# 449 0.5709519999995709 24.0
# Average return training: 35.71
# 450 0.5703759999995703 16.0
# Average return training: 35.32
# 451 0.5686119999995686 49.0
# Average return training: 35.61
# Average return over 25 episodes of playing: 90.2
# 452 0.5644719999995644 115.0
# Average return training: 36.49
# 453 0.5637159999995637 21.0
# Average return training: 36.4
# 454 0.5631399999995631 16.0
# Average return training: 36.44
# 455 0.5623839999995623 21.0
# Average return training: 36.46
# 456 0.5615559999995615 23.0
# Average return training: 35.71
# 457 0.561051999999561 14.0
# Average return training: 35.21
# 458 0.5606199999995606 12.0
# Average return training: 34.84
# 459 0.5602239999995602 11.0
# Average return training: 34.71
# 460 0.5595039999995595 20.0
# Average return training: 34.04
# 461 0.5577039999995577 50.0
# Average return training: 34.3
# 462 0.5571279999995571 16.0
# Average return training: 34.27
# 463 0.5557599999995557 38.0
# Average return training: 34.51
# 464 0.5549319999995549 23.0
# Average return training: 34.49
# 465 0.5542839999995542 18.0
# Average return training: 34.52
# 466 0.5536719999995536 17.0
# Average return training: 34.35
# 467 0.5524479999995524 34.0
# Average return training: 34.26
# Average return over 25 episodes of playing: 97.24
# 468 0.5484159999995484 112.0
# Average return training: 35.23
# 469 0.548019999999548 11.0
# Average return training: 35.03
# 470 0.5474799999995474 15.0
# Average return training: 34.85
# 471 0.5469399999995469 15.0
# Average return training: 34.66
# 472 0.5465439999995465 11.0
# Average return training: 34.63
# 473 0.546003999999546 15.0
# Average return training: 34.66
# 474 0.5451399999995451 24.0
# Average return training: 34.59
# 475 0.5447799999995447 10.0
# Average return training: 33.86
# 476 0.5438799999995438 25.0
# Average return training: 33.83
# 477 0.5424759999995424 39.0
# Average return training: 34.05
# 478 0.5418999999995419 16.0
# Average return training: 34.02
# 479 0.5413599999995413 15.0
# Average return training: 34.06
# 480 0.5388039999995388 71.0
# Average return training: 34.32
# 481 0.5382639999995382 15.0
# Average return training: 34.26
# 482 0.5377599999995377 14.0
# Average return training: 33.49
# 483 0.5361039999995361 46.0
# Average return training: 33.67
# 484 0.5354919999995355 17.0
# Average return training: 32.94
# 485 0.5344119999995344 30.0
# Average return training: 32.07
# 486 0.5338719999995338 15.0
# Average return training: 32.1
# 487 0.5332959999995333 16.0
# Average return training: 30.74
# 488 0.5327919999995328 14.0
# Average return training: 30.74
# 489 0.5323599999995323 12.0
# Average return training: 30.64
# Average return over 25 episodes of playing: 94.44
# 490 0.5318199999995318 15.0
# Average return training: 30.23
# 491 0.5301279999995301 47.0
# Average return training: 29.85
# 492 0.5285079999995285 45.0
# Average return training: 30.14
# 493 0.528075999999528 12.0
# Average return training: 29.94
# 494 0.5276439999995276 12.0
# Average return training: 29.26
# 495 0.5267079999995267 26.0
# Average return training: 29.35
# 496 0.5229279999995229 105.0
# Average return training: 30.29
# 497 0.5223879999995223 15.0
# Average return training: 30.28
# 498 0.5215959999995216 22.0
# Average return training: 30.42
# 499 0.5204079999995204 33.0
# Average return training: 30.22
# 500 0.52001199999952 11.0
# Average return training: 29.81
# 501 0.5195799999995195 12.0
# Average return training: 29.76
# 502 0.5191839999995191 11.0
# Average return training: 29.73
# 503 0.5172759999995172 53.0
# Average return training: 29.58
# 504 0.5166279999995166 18.0
# Average return training: 29.6
# 505 0.5143599999995143 63.0
# Average return training: 29.92
# Average return over 25 episodes of playing: 130.4
# 506 0.5102559999995102 114.0
# Average return training: 30.83
# 507 0.5089599999995089 36.0
# Average return training: 31.04
# 508 0.5074839999995074 41.0
# Average return training: 31.33
# 509 0.5048919999995048 72.0
# Average return training: 31.93
# 510 0.503991999999504 25.0
# Average return training: 31.99
# 511 0.5029479999995029 29.0
# Average return training: 31.94
# 512 0.5025159999995025 12.0
# Average return training: 31.93
# 513 0.5013999999995014 31.0
# Average return training: 31.07
# 514 0.5002119999995002 33.0
# Average return training: 31.16
# 515 0.4990959999995005 31.0
# Average return training: 31.34
# 516 0.4984839999995008 17.0
# Average return training: 31.37
# Average return over 25 episodes of playing: 287.56
# 517 0.49121199999950477 202.0
# Average return training: 33.18
# 518 0.49070799999950504 14.0
# Average return training: 32.76
# 519 0.49016799999950533 15.0
# Average return training: 32.79
# 520 0.4895199999995057 18.0
# Average return training: 32.86
# 521 0.4874319999995068 58.0
# Average return training: 33.31
# 522 0.48462399999950834 78.0
# Average return training: 33.66
# 523 0.4837599999995088 24.0
# Average return training: 32.84
# 524 0.48311199999950916 18.0
# Average return training: 32.43
# 525 0.4826799999995094 12.0
# Average return training: 32.08
# 526 0.47907999999951134 100.0
# Average return training: 32.73
# Average return over 25 episodes of playing: 95.64
# 527 0.4756599999995132 95.0
# Average return training: 33.24
# 528 0.47411199999951403 43.0
# Average return training: 33.51
# 529 0.4727079999995148 39.0
# Average return training: 33.74
# 530 0.4719519999995152 21.0
# Average return training: 33.73
# 531 0.4714119999995155 15.0
# Average return training: 33.7
# 532 0.46741599999951766 111.0
# Average return training: 34.39
# 533 0.46655199999951813 24.0
# Average return training: 34.44
# 534 0.4609359999995212 156.0
# Average return training: 35.74
# Average return over 25 episodes of playing: 151.4
# 535 0.4585239999995225 67.0
# Average return training: 35.36
# 536 0.45769599999952293 23.0
# Average return training: 35.48
# 537 0.45708399999952326 17.0
# Average return training: 35.47
# 538 0.4566159999995235 13.0
# Average return training: 35.47
# 539 0.45175599999952615 135.0
# Average return training: 36.71
# 540 0.450135999999527 45.0
# Average return training: 36.74
# 541 0.44822799999952806 53.0
# Average return training: 37.01
# 542 0.4472199999995286 28.0
# Average return training: 37.01
# 543 0.4461399999995292 30.0
# Average return training: 37.05
# 544 0.44347599999953063 74.0
# Average return training: 37.65
# Average return over 25 episodes of playing: 164.92
# 545 0.44070399999953214 77.0
# Average return training: 38.2
# 546 0.437247999999534 96.0
# Average return training: 38.86
# 547 0.4355919999995349 46.0
# Average return training: 38.93
# 548 0.43238799999953664 89.0
# Average return training: 38.73
# 549 0.43037199999953774 56.0
# Average return training: 39.05
# 550 0.4297239999995381 18.0
# Average return training: 39.07
# 551 0.4289679999995385 21.0
# Average return training: 38.79
# 552 0.42720399999953945 49.0
# Average return training: 38.13
# 553 0.4267719999995397 12.0
# Average return training: 38.04
# Average return over 25 episodes of playing: 132.6
# 554 0.422523999999542 118.0
# Average return training: 39.06
# 555 0.42151599999954253 28.0
# Average return training: 39.13
# 556 0.4167999999995451 131.0
# Average return training: 40.21
# 557 0.4162599999995454 15.0
# Average return training: 40.22
# Average return over 25 episodes of playing: 500.0
# 558 0.4051719999995514 308.0
# Average return training: 43.18
# 559 0.4034439999995523 48.0
# Average return training: 43.55
# 560 0.398511999999555 137.0
# Average return training: 44.72
# 561 0.3979719999995553 15.0
# Average return training: 44.37
# 562 0.392931999999558 140.0
# Average return training: 45.61
# 563 0.3924279999995583 14.0
# Average return training: 45.37
# 564 0.38864799999956035 105.0
# Average return training: 46.19
# 565 0.38810799999956064 15.0
# Average return training: 46.16
# Average return over 25 episodes of playing: 500.0
# 566 0.38771199999956085 11.0
# Average return training: 46.1
# 567 0.3829599999995634 132.0
# Average return training: 47.08
# 568 0.3822399999995638 20.0
# Average return training: 46.16
# 569 0.37831599999956594 109.0
# Average return training: 47.14
# 570 0.37734399999956647 27.0
# Average return training: 47.26
# 571 0.37277199999956895 127.0
# Average return training: 48.38
# 572 0.37219599999956926 16.0
# Average return training: 48.43
# Average return over 25 episodes of playing: 106.96
# 573 0.36963999999957065 71.0
# Average return training: 48.99
# 574 0.3665799999995723 85.0
# Average return training: 49.6
# 575 0.3626919999995744 108.0
# Average return training: 50.58
# 576 0.3622959999995746 11.0
# Average return training: 50.44
# 577 0.35833599999957677 110.0
# Average return training: 51.15
# 578 0.35779599999957706 15.0
# Average return training: 51.14
# 579 0.3570039999995775 22.0
# Average return training: 51.21
# 580 0.35649999999957777 14.0
# Average return training: 50.64
# 581 0.3536559999995793 79.0
# Average return training: 51.28
# 582 0.35300799999957966 18.0
# Average return training: 51.32
# 583 0.35264799999957985 10.0
# Average return training: 50.96
# 584 0.35207199999958017 16.0
# Average return training: 50.95
# Average return over 25 episodes of playing: 89.04
# 585 0.35156799999958044 14.0
# Average return training: 50.79
# 586 0.3492639999995817 64.0
# Average return training: 51.28
# 587 0.34782399999958247 40.0
# Average return training: 51.52
# 588 0.34620399999958335 45.0
# Average return training: 51.83
# 589 0.34548399999958374 20.0
# Average return training: 51.91
# 590 0.34487199999958407 17.0
# Average return training: 51.93
# 591 0.3410919999995861 105.0
# Average return training: 52.51
# 592 0.3405879999995864 14.0
# Average return training: 52.2
# 593 0.3396159999995869 27.0
# Average return training: 52.35
# 594 0.33882399999958734 22.0
# Average return training: 52.45
# 595 0.33810399999958773 20.0
# Average return training: 52.39
# 596 0.33716799999958824 26.0
# Average return training: 51.6
# 597 0.3346839999995896 69.0
# Average return training: 52.14
# Average return over 25 episodes of playing: 94.88
# 598 0.33396399999959 20.0
# Average return training: 52.12
# 599 0.3322719999995909 47.0
# Average return training: 52.26
# 600 0.3319119999995911 10.0
# Average return training: 52.25
# 601 0.3314799999995913 12.0
# Average return training: 52.25
# 602 0.33104799999959156 12.0
# Average return training: 52.26
# 603 0.33011199999959207 26.0
# Average return training: 51.99
# 604 0.32975199999959226 10.0
# Average return training: 51.91
# 605 0.32622399999959417 98.0
# Average return training: 52.26
# 606 0.32568399999959446 15.0
# Average return training: 51.27
# 607 0.32517999999959474 14.0
# Average return training: 51.05
# 608 0.32456799999959507 17.0
# Average return training: 50.81
# 609 0.3226239999995961 54.0
# Average return training: 50.63
# 610 0.31923999999959796 94.0
# Average return training: 51.32
# 611 0.3177279999995988 42.0
# Average return training: 51.45
# 612 0.3168999999995992 23.0
# Average return training: 51.56
# Average return over 25 episodes of playing: 500.0
# 613 0.3131199999996013 105.0
# Average return training: 52.3
# 614 0.31275999999960147 10.0
# Average return training: 52.07
# 615 0.3119679999996019 22.0
# Average return training: 51.98
# 616 0.30944799999960326 70.0
# Average return training: 52.51
# 617 0.30797199999960406 41.0
# Average return training: 50.9
# 618 0.30465999999960586 92.0
# Average return training: 51.68
# 619 0.3041919999996061 13.0
# Average return training: 51.66
# 620 0.3031119999996067 30.0
# Average return training: 51.78
# Average return over 25 episodes of playing: 500.0
# 621 0.29598399999961056 198.0
# Average return training: 53.18
# 622 0.2922039999996126 105.0
# Average return training: 53.45
# 623 0.2916279999996129 16.0
# Average return training: 53.37
# 624 0.29097999999961327 18.0
# Average return training: 53.37
# 625 0.2890359999996143 54.0
# Average return training: 53.79
# 626 0.28827999999961473 21.0
# Average return training: 53.0
# 627 0.2866599999996156 45.0
# Average return training: 52.5
# 628 0.28273599999961774 109.0
# Average return training: 53.16
# Average return over 25 episodes of playing: 126.68
# 629 0.27935199999961957 94.0
# Average return training: 53.71
# 630 0.27423999999962234 142.0
# Average return training: 54.92
# 631 0.26682399999962636 206.0
# Average return training: 56.83
# 632 0.26534799999962716 41.0
# Average return training: 56.13
# 633 0.26297199999962845 66.0
# Average return training: 56.55
# Average return over 25 episodes of playing: 390.68
# 634 0.25649199999963196 180.0
# Average return training: 56.79
# 635 0.2551239999996327 38.0
# Average return training: 56.5
# 636 0.25447599999963305 18.0
# Average return training: 56.45
# 637 0.25299999999963385 41.0
# Average return training: 56.69
# 638 0.2492199999996353 105.0
# Average return training: 57.61
# 639 0.2475279999996349 47.0
# Average return training: 56.73
# Average return over 25 episodes of playing: 484.04
# 640 0.24295599999963385 127.0
# Average return training: 57.55
# 641 0.24104799999963342 53.0
# Average return training: 57.55
# 642 0.23978799999963313 35.0
# Average return training: 57.62
# 643 0.23589999999963224 108.0
# Average return training: 58.4
# 644 0.22974399999963083 171.0
# Average return training: 59.37
# Average return over 25 episodes of playing: 500.0
# 645 0.2252079999996298 126.0
# Average return training: 59.86
# 646 0.2187279999996283 180.0
# Average return training: 60.7
# Average return over 25 episodes of playing: 500.0
# 647 0.20666799999962554 335.0
# Average return training: 63.59
# 648 0.20612799999962542 15.0
# Average return training: 62.85
# 649 0.20270799999962463 95.0
# Average return training: 63.24
# Average return over 25 episodes of playing: 500.0
# 650 0.18978399999962167 359.0
# Average return training: 66.65
# 651 0.18823599999962132 43.0
# Average return training: 66.87
# 652 0.1863639999996209 52.0
# Average return training: 66.9
# 653 0.18387999999962032 69.0
# Average return training: 67.47
# Average return over 25 episodes of playing: 500.0
# 654 0.17052399999961726 371.0
# Average return training: 70.0
# Average return over 100 episodes of trained agent: 500.0
# SEED: 34
# Finishing last run (ID:2cvwy64i) before initializing another...
# <br/>Waiting for W&B process to finish, PID 178... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>Average return over 100 episodes of training</td><td>▁▁▁▁▁▁▁▁▂▂▁▂▂▁▁▁▁▁▁▁▁▂▂▃▃▃▃▃▂▂▃▃▄▅▅▆▆▆▆█</td></tr><tr><td>Average return over 25 episodes of playing</td><td>▁▅▃▃▂▁▂▂▂▂▂▂▂▂▂▂▂▄▄▂▂▂▂▃▅▂▃▃██▂▂▂█▃▆████</td></tr><tr><td>episode</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>Average return over 100 episodes of training</td><td>70.0</td></tr><tr><td>Average return over 25 episodes of playing</td><td>500.0</td></tr><tr><td>episode</td><td>654</td></tr><tr><td>step</td><td>23000</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">happy-microwave-39</strong>: <a href="https://wandb.ai/raisa/DuelingDDQN-CartPole/runs/2cvwy64i" target="_blank">https://wandb.ai/raisa/DuelingDDQN-CartPole/runs/2cvwy64i</a><br/>
# Find logs at: <code>./wandb/run-20220114_194215-2cvwy64i/logs</code><br/>
# Successfully finished last run (ID:2cvwy64i). Initializing new run:<br/>
#                     Syncing run <strong><a href="https://wandb.ai/raisa/DuelingDDQN-CartPole/runs/3mftef2k" target="_blank">distinctive-flower-40</a></strong> to <a href="https://wandb.ai/raisa/DuelingDDQN-CartPole" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 1 0.9988839999999989 31.0
# 2 0.9980559999999981 23.0
# 3 0.9968679999999969 33.0
# 4 0.9963639999999964 14.0
# 5 0.9956799999999957 19.0
# 6 0.9948519999999949 23.0
# 7 0.9943119999999943 15.0
# 8 0.992007999999992 64.0
# 9 0.9912879999999913 20.0
# 10 0.9909279999999909 10.0
# 11 0.9895599999999896 38.0
# 12 0.9886239999999886 26.0
# 13 0.9877599999999878 24.0
# 14 0.9864999999999865 35.0
# 15 0.9855639999999856 26.0
# 16 0.984987999999985 16.0
# 17 0.9837639999999838 34.0
# 18 0.9826839999999827 30.0
# Average return over 25 episodes of playing: 9.24
# 19 0.9816759999999817 28.0
# 20 0.9810999999999811 16.0
# 21 0.9805959999999806 14.0
# 22 0.9794439999999794 32.0
# 23 0.9782199999999782 34.0
# 24 0.9775359999999775 19.0
# 25 0.9751239999999751 67.0
# 26 0.9744399999999744 19.0
# 27 0.9728559999999729 44.0
# 28 0.9722799999999723 16.0
# 29 0.970983999999971 36.0
# 30 0.9701199999999701 24.0
# 31 0.9693279999999693 22.0
# 32 0.9686799999999687 18.0
# 33 0.9682479999999682 12.0
# 34 0.9668079999999668 40.0
# 35 0.9661239999999661 19.0
# 36 0.9654039999999654 20.0
# Average return over 25 episodes of playing: 149.56
# 37 0.963963999999964 40.0
# 38 0.962991999999963 27.0
# 39 0.9624879999999625 14.0
# 40 0.9619119999999619 16.0
# 41 0.9605439999999605 38.0
# 42 0.95996799999996 16.0
# 43 0.9589239999999589 29.0
# 44 0.9582399999999582 19.0
# 45 0.9578439999999578 11.0
# 46 0.9574119999999574 12.0
# 47 0.9554319999999554 55.0
# 48 0.9548559999999549 16.0
# 49 0.953991999999954 24.0
# 50 0.9534159999999534 16.0
# 51 0.9527319999999527 19.0
# 52 0.9511119999999511 45.0
# 53 0.9485919999999486 70.0
# 54 0.9476199999999476 27.0
# 55 0.9467559999999468 24.0
# Average return over 25 episodes of playing: 141.72
# 56 0.945999999999946 21.0
# 57 0.9453879999999454 17.0
# 58 0.944991999999945 11.0
# 59 0.9444519999999444 15.0
# 60 0.9436599999999437 22.0
# 61 0.9417519999999417 53.0
# 62 0.940959999999941 22.0
# 63 0.9397719999999398 33.0
# 64 0.9382599999999383 42.0
# 65 0.9377559999999378 14.0
# 66 0.936027999999936 48.0
# 67 0.935019999999935 28.0
# 68 0.934047999999934 27.0
# 69 0.9328599999999329 33.0
# 70 0.931959999999932 25.0
# 71 0.9305919999999306 38.0
# 72 0.93001599999993 16.0
# 73 0.9293679999999294 18.0
# 74 0.9283239999999283 29.0
# Average return over 25 episodes of playing: 142.88
# 75 0.9276759999999277 18.0
# 76 0.9256959999999257 55.0
# 77 0.9252279999999252 13.0
# 78 0.921987999999922 90.0
# 79 0.9212679999999213 20.0
# 80 0.9200799999999201 33.0
# 81 0.9189279999999189 32.0
# 82 0.917991999999918 26.0
# 83 0.9173439999999173 18.0
# 84 0.9169119999999169 12.0
# 85 0.9161559999999161 21.0
# 86 0.9156519999999156 14.0
# 87 0.914967999999915 19.0
# 88 0.9143559999999143 17.0
# 89 0.9137799999999138 16.0
# 90 0.9132399999999132 15.0
# 91 0.9126999999999127 15.0
# 92 0.912051999999912 18.0
# 93 0.9111879999999112 24.0
# 94 0.9106479999999106 15.0
# Average return over 25 episodes of playing: 77.68
# 95 0.9093879999999094 35.0
# 96 0.9088839999999089 14.0
# 97 0.9083079999999083 16.0
# 98 0.9077679999999078 15.0
# 99 0.9067239999999067 29.0
# 100 0.905967999999906 21.0
# 101 0.9054999999999055 13.0
# Average return training: 25.94
# 102 0.9041679999999042 37.0
# Average return training: 26.08
# 103 0.903015999999903 32.0
# Average return training: 26.07
# 104 0.9021879999999022 23.0
# Average return training: 26.16
# 105 0.9017919999999018 11.0
# Average return training: 26.08
# 106 0.8995959999998996 61.0
# Average return training: 26.46
# 107 0.8982279999998982 38.0
# Average return training: 26.69
# 108 0.8971839999998972 29.0
# Average return training: 26.34
# 109 0.8964999999998965 19.0
# Average return training: 26.33
# 110 0.8952399999998952 35.0
# Average return training: 26.58
# 111 0.8946639999998947 16.0
# Average return training: 26.36
# 112 0.894015999999894 18.0
# Average return training: 26.28
# 113 0.8935839999998936 12.0
# Average return training: 26.16
# Average return over 25 episodes of playing: 113.56
# 114 0.8917839999998918 50.0
# Average return training: 26.31
# 115 0.8903079999998903 41.0
# Average return training: 26.46
# 116 0.8898399999998898 13.0
# Average return training: 26.43
# 117 0.8882559999998882 44.0
# Average return training: 26.53
# 118 0.8874279999998874 23.0
# Average return training: 26.46
# 119 0.8865999999998866 23.0
# Average return training: 26.41
# 120 0.8859159999998859 19.0
# Average return training: 26.44
# 121 0.8854479999998854 13.0
# Average return training: 26.43
# 122 0.8849439999998849 14.0
# Average return training: 26.25
# 123 0.8836839999998837 35.0
# Average return training: 26.26
# 124 0.883035999999883 18.0
# Average return training: 26.25
# 125 0.8825319999998825 14.0
# Average return training: 25.72
# 126 0.8815599999998815 27.0
# Average return training: 25.8
# 127 0.8806959999998807 24.0
# Average return training: 25.6
# 128 0.8794359999998794 35.0
# Average return training: 25.79
# 129 0.8789319999998789 14.0
# Average return training: 25.57
# 130 0.8783559999998783 16.0
# Average return training: 25.49
# 131 0.8767359999998767 45.0
# Average return training: 25.72
# 132 0.8753319999998753 39.0
# Average return training: 25.93
# 133 0.8747199999998747 17.0
# Average return training: 25.98
# 134 0.8741079999998741 17.0
# Average return training: 25.75
# Average return over 25 episodes of playing: 139.44
# 135 0.8735679999998736 15.0
# Average return training: 25.71
# 136 0.8729199999998729 18.0
# Average return training: 25.69
# 137 0.8721639999998722 21.0
# Average return training: 25.5
# 138 0.8708319999998708 37.0
# Average return training: 25.6
# 139 0.8699319999998699 25.0
# Average return training: 25.71
# 140 0.8694639999998695 13.0
# Average return training: 25.68
# 141 0.8689239999998689 15.0
# Average return training: 25.45
# 142 0.8682759999998683 18.0
# Average return training: 25.47
# 143 0.8678439999998678 12.0
# Average return training: 25.3
# 144 0.8651439999998651 75.0
# Average return training: 25.86
# 145 0.8644959999998645 18.0
# Average return training: 25.93
# 146 0.863991999999864 14.0
# Average return training: 25.95
# 147 0.8632719999998633 20.0
# Average return training: 25.6
# 148 0.8628759999998629 11.0
# Average return training: 25.55
# 149 0.8618679999998619 28.0
# Average return training: 25.59
# 150 0.8613279999998613 15.0
# Average return training: 25.58
# 151 0.8607879999998608 15.0
# Average return training: 25.54
# 152 0.8598159999998598 27.0
# Average return training: 25.36
# 153 0.858987999999859 23.0
# Average return training: 24.89
# 154 0.8584839999998585 14.0
# Average return training: 24.76
# 155 0.8577279999998577 21.0
# Average return training: 24.73
# 156 0.8573679999998574 10.0
# Average return training: 24.62
# 157 0.8565039999998565 24.0
# Average return training: 24.69
# Average return over 25 episodes of playing: 92.76
# 158 0.8553159999998553 33.0
# Average return training: 24.91
# 159 0.8547039999998547 17.0
# Average return training: 24.93
# 160 0.8543799999998544 9.0
# Average return training: 24.8
# 161 0.8519319999998519 68.0
# Average return training: 24.95
# 162 0.8506719999998507 35.0
# Average return training: 25.08
# 163 0.8501679999998502 14.0
# Average return training: 24.89
# 164 0.8490879999998491 30.0
# Average return training: 24.77
# 165 0.8487279999998487 10.0
# Average return training: 24.73
# 166 0.8477559999998477 27.0
# Average return training: 24.52
# 167 0.8473239999998473 12.0
# Average return training: 24.36
# 168 0.8467119999998467 17.0
# Average return training: 24.26
# 169 0.845991999999846 20.0
# Average return training: 24.13
# 170 0.8452359999998452 21.0
# Average return training: 24.09
# 171 0.8435079999998435 48.0
# Average return training: 24.19
# 172 0.8424999999998425 28.0
# Average return training: 24.31
# 173 0.8388279999998388 102.0
# Average return training: 25.15
# 174 0.8381799999998382 18.0
# Average return training: 25.04
# Average return over 25 episodes of playing: 131.36
# 175 0.8368119999998368 38.0
# Average return training: 25.24
# 176 0.8363439999998363 13.0
# Average return training: 24.82
# 177 0.8356599999998356 19.0
# Average return training: 24.88
# ...
# 341 0.6979599999996979 37.0
# Average return training: 25.85
# 342 0.6974199999996974 15.0
# Average return training: 25.86
# 343 0.697023999999697 11.0
# Average return training: 25.87
# 344 0.696051999999696 27.0
# Average return training: 25.56
# 345 0.6947559999996947 36.0
# Average return training: 25.75
# 346 0.6941799999996942 16.0
# Average return training: 25.12
# Average return over 25 episodes of playing: 69.04
# 347 0.6930999999996931 30.0
# Average return training: 25.21
# 348 0.6925239999996925 16.0
# Average return training: 25.26
# 349 0.6899679999996899 71.0
# Average return training: 25.67
# 350 0.6891759999996891 22.0
# Average return training: 25.71
# 351 0.6881319999996881 29.0
# Average return training: 25.37
# 352 0.6871959999996872 26.0
# Average return training: 25.05
# 353 0.6868359999996868 10.0
# Average return training: 24.98
# 354 0.6863679999996863 13.0
# Average return training: 24.72
# 355 0.6853959999996854 27.0
# Average return training: 24.56
# 356 0.6844239999996844 27.0
# Average return training: 24.66
# 357 0.6839559999996839 13.0
# Average return training: 24.56
# 358 0.6833079999996833 18.0
# Average return training: 24.48
# 359 0.6828039999996828 14.0
# Average return training: 24.28
# 360 0.6823359999996823 13.0
# Average return training: 24.24
# 361 0.6794199999996794 81.0
# Average return training: 24.81
# 362 0.6784479999996784 27.0
# Average return training: 24.75
# 363 0.6780879999996781 10.0
# Average return training: 24.65
# 364 0.6776559999996776 12.0
# Average return training: 24.53
# 365 0.6771159999996771 15.0
# Average return training: 24.49
# 366 0.6765399999996765 16.0
# Average return training: 24.47
# Average return over 25 episodes of playing: 70.4
# 367 0.675999999999676 15.0
# Average return training: 24.46
# 368 0.6753519999996753 18.0
# Average return training: 24.49
# 369 0.6749199999996749 12.0
# Average return training: 24.37
# 370 0.6740919999996741 23.0
# Average return training: 24.44
# 371 0.6736599999996736 12.0
# Average return training: 24.33
# 372 0.6731919999996732 13.0
# Average return training: 24.37
# 373 0.6724719999996724 20.0
# Average return training: 24.42
# 374 0.6716439999996716 23.0
# Average return training: 24.5
# 375 0.6691959999996692 68.0
# Average return training: 24.91
# 376 0.6684759999996684 20.0
# Average return training: 24.9
# 377 0.6678999999996679 16.0
# Average return training: 24.59
# 378 0.6666039999996666 36.0
# Average return training: 24.81
# 379 0.6661359999996661 13.0
# Average return training: 24.8
# 380 0.6648039999996648 37.0
# Average return training: 24.74
# 381 0.664047999999664 21.0
# Average return training: 24.56
# 382 0.6634719999996634 16.0
# Average return training: 24.59
# 383 0.663039999999663 12.0
# Average return training: 24.48
# 384 0.6619599999996619 30.0
# Average return training: 24.57
# 385 0.6612399999996612 20.0
# Average return training: 24.58
# 386 0.6602319999996602 28.0
# Average return training: 24.65
# 387 0.6586839999996587 43.0
# Average return training: 24.42
# 388 0.6581799999996581 14.0
# Average return training: 24.39
# Average return over 25 episodes of playing: 410.44
# 389 0.6573159999996573 24.0
# Average return training: 24.47
# 390 0.6564879999996565 23.0
# Average return training: 24.36
# 391 0.6555159999996555 27.0
# Average return training: 24.5
# 392 0.6523479999996523 88.0
# Average return training: 25.18
# 393 0.6517719999996517 16.0
# Average return training: 24.88
# 394 0.6507639999996507 28.0
# Average return training: 25.06
# 395 0.6502599999996502 14.0
# Average return training: 24.26
# 396 0.6498279999996498 12.0
# Average return training: 24.03
# 397 0.6491079999996491 20.0
# Average return training: 23.64
# 398 0.6485319999996485 16.0
# Average return training: 23.66
# 399 0.6481359999996481 11.0
# Average return training: 23.55
# 400 0.6475599999996475 16.0
# Average return training: 23.59
# 401 0.647019999999647 15.0
# Average return training: 23.49
# 402 0.6464079999996464 17.0
# Average return training: 23.37
# 403 0.6459039999996459 14.0
# Average return training: 23.39
# 404 0.6423399999996423 99.0
# Average return training: 24.02
# 405 0.6419079999996419 12.0
# Average return training: 23.92
# 406 0.6413679999996413 15.0
# Average return training: 23.86
# 407 0.6407919999996408 16.0
# Average return training: 23.86
# Average return over 25 episodes of playing: 93.36
# 408 0.6374439999996374 93.0
# Average return training: 24.28
# 409 0.6367959999996368 18.0
# Average return training: 24.29
# 410 0.6362199999996362 16.0
# Average return training: 24.29
# 411 0.6356079999996356 17.0
# Average return training: 24.28
# 412 0.6351759999996351 12.0
# Average return training: 24.24
# 413 0.6344199999996344 21.0
# Average return training: 24.34
# 414 0.6338079999996338 17.0
# Average return training: 24.19
# 415 0.6334479999996334 10.0
# Average return training: 24.16
# 416 0.6329079999996329 15.0
# Average return training: 24.18
# 417 0.6322959999996323 17.0
# Average return training: 24.17
# 418 0.6302439999996302 57.0
# Average return training: 24.59
# 419 0.6298119999996298 12.0
# Average return training: 24.47
# 420 0.6250959999996251 131.0
# Average return training: 25.63
# 421 0.6245199999996245 16.0
# Average return training: 25.62
# 422 0.6238359999996238 19.0
# Average return training: 25.63
# 423 0.6222879999996223 43.0
# Average return training: 25.92
# Average return over 25 episodes of playing: 145.0
# 424 0.6217839999996218 14.0
# Average return training: 25.62
# 425 0.6213159999996213 13.0
# Average return training: 25.5
# 426 0.6207039999996207 17.0
# Average return training: 25.51
# 427 0.6177879999996178 81.0
# Average return training: 26.15
# 428 0.6169599999996169 23.0
# Average return training: 26.15
# 429 0.6165279999996165 12.0
# Average return training: 25.86
# 430 0.6158439999996158 19.0
# Average return training: 25.85
# 431 0.6133959999996134 68.0
# Average return training: 26.34
# 432 0.6126039999996126 22.0
# Average return training: 26.46
# 433 0.6093999999996094 89.0
# Average return training: 27.18
# 434 0.6084999999996085 25.0
# Average return training: 27.26
# 435 0.6079239999996079 16.0
# Average return training: 26.61
# 436 0.6073839999996073 15.0
# Average return training: 26.39
# 437 0.6042159999996042 88.0
# Average return training: 27.12
# Average return over 25 episodes of playing: 105.24
# 438 0.601983999999602 62.0
# Average return training: 27.41
# 439 0.6008319999996008 32.0
# Average return training: 27.47
# 440 0.5974119999995974 95.0
# Average return training: 28.3
# 441 0.5962959999995963 31.0
# Average return training: 28.24
# 442 0.5918679999995918 123.0
# Average return training: 29.32
# 443 0.5913279999995913 15.0
# Average return training: 29.36
# 444 0.5908599999995908 13.0
# Average return training: 29.22
# 445 0.5892759999995892 44.0
# Average return training: 29.3
# 446 0.5888799999995888 11.0
# Average return training: 29.25
# 447 0.5883759999995883 14.0
# Average return training: 29.09
# 448 0.5877639999995877 17.0
# Average return training: 29.1
# 449 0.5871879999995872 16.0
# Average return training: 28.55
# Average return over 25 episodes of playing: 245.88
# 450 0.5854959999995855 47.0
# Average return training: 28.8
# 451 0.5843799999995843 31.0
# Average return training: 28.82
# 452 0.5808159999995808 99.0
# Average return training: 29.55
# 453 0.5797719999995797 29.0
# Average return training: 29.74
# 454 0.5791599999995791 17.0
# Average return training: 29.78
# 455 0.5787639999995787 11.0
# Average return training: 29.62
# 456 0.5742639999995742 125.0
# Average return training: 30.6
# 457 0.5728959999995729 38.0
# Average return training: 30.85
# 458 0.5719599999995719 26.0
# Average return training: 30.93
# 459 0.5685759999995685 94.0
# Average return training: 31.73
# Average return over 25 episodes of playing: 117.36
# 460 0.5658759999995658 75.0
# Average return training: 32.35
# 461 0.5649759999995649 25.0
# Average return training: 31.79
# 462 0.5602959999995603 130.0
# Average return training: 32.82
# 463 0.5597559999995597 15.0
# Average return training: 32.87
# 464 0.5589279999995589 23.0
# Average return training: 32.98
# 465 0.555003999999555 109.0
# Average return training: 33.92
# 466 0.5544999999995545 14.0
# Average return training: 33.9
# Average return over 25 episodes of playing: 128.68
# 467 0.5493879999995493 142.0
# Average return training: 35.17
# 468 0.5488839999995488 14.0
# Average return training: 35.13
# 469 0.5463639999995463 70.0
# Average return training: 35.71
# 470 0.5458959999995459 13.0
# Average return training: 35.61
# 471 0.5447799999995447 31.0
# Average return training: 35.8
# 472 0.5442399999995442 15.0
# Average return training: 35.82
# 473 0.5435559999995435 19.0
# Average return training: 35.81
# 474 0.5402799999995402 91.0
# Average return training: 36.49
# 475 0.5377959999995378 69.0
# Average return training: 36.5
# 476 0.536031999999536 49.0
# Average return training: 36.79
# Average return over 25 episodes of playing: 79.24
# 477 0.5317479999995317 119.0
# Average return training: 37.82
# 478 0.5303079999995303 40.0
# Average return training: 37.86
# 479 0.5274279999995274 80.0
# Average return training: 38.53
# 480 0.5267079999995267 20.0
# Average return training: 38.36
# 481 0.525015999999525 47.0
# Average return training: 38.62
# 482 0.5224239999995224 72.0
# Average return training: 39.18
# 483 0.5197239999995197 75.0
# Average return training: 39.81
# 484 0.5187159999995187 28.0
# Average return training: 39.79
# 485 0.5164479999995164 63.0
# Average return training: 40.22
# 486 0.5145399999995145 53.0
# Average return training: 40.47
# Average return over 25 episodes of playing: 207.48
# 487 0.5127399999995127 50.0
# Average return training: 40.54
# 488 0.5123079999995123 12.0
# Average return training: 40.52
# 489 0.5119119999995119 11.0
# Average return training: 40.39
# 490 0.5094279999995094 69.0
# Average return training: 40.85
# 491 0.5079519999995079 41.0
# Average return training: 40.99
# 492 0.5075919999995075 10.0
# Average return training: 40.21
# 493 0.5045679999995045 84.0
# Average return training: 40.89
# 494 0.5000319999995 126.0
# Average return training: 41.87
# 495 0.49823199999950096 50.0
# Average return training: 42.23
# 496 0.4975839999995013 18.0
# Average return training: 42.29
# 497 0.49643199999950194 32.0
# Average return training: 42.41
# 498 0.49603599999950215 11.0
# Average return training: 42.36
# Average return over 25 episodes of playing: 204.6
# 499 0.49214799999950426 108.0
# Average return training: 43.33
# 500 0.49160799999950455 15.0
# Average return training: 43.32
# 501 0.4911399999995048 13.0
# Average return training: 43.3
# 502 0.4902759999995053 24.0
# Average return training: 43.37
# 503 0.4887279999995061 43.0
# Average return training: 43.66
# 504 0.48714399999950697 44.0
# Average return training: 43.11
# 505 0.48624399999950746 25.0
# Average return training: 43.24
# 506 0.48588399999950765 10.0
# Average return training: 43.19
# 507 0.4819239999995098 110.0
# Average return training: 44.13
# Average return over 25 episodes of playing: 165.52
# 508 0.4763799999995128 154.0
# Average return training: 44.74
# 509 0.47151999999951544 135.0
# Average return training: 45.91
# 510 0.4675599999995176 110.0
# Average return training: 46.85
# 511 0.46709199999951784 13.0
# Average return training: 46.81
# 512 0.4628799999995201 117.0
# Average return training: 47.86
# 513 0.461259999999521 45.0
# Average return training: 48.1
# Average return over 25 episodes of playing: 398.64
# 514 0.4583079999995226 82.0
# Average return training: 48.75
# 515 0.45251199999952574 161.0
# Average return training: 50.26
# 516 0.4487319999995278 105.0
# Average return training: 51.16
# 517 0.4443039999995302 123.0
# Average return training: 52.22
# 518 0.44361999999953056 19.0
# Average return training: 51.84
# Average return over 25 episodes of playing: 500.0
# 519 0.4417119999995316 53.0
# Average return training: 52.25
# 520 0.44124399999953184 13.0
# Average return training: 51.07
# 521 0.4405599999995322 19.0
# Average return training: 51.1
# 522 0.43991199999953257 18.0
# Average return training: 51.09
# 523 0.4395159999995328 11.0
# Average return training: 50.77
# 524 0.4356279999995349 108.0
# Average return training: 51.71
# 525 0.43073199999953754 136.0
# Average return training: 52.94
# 526 0.4296879999995381 29.0
# Average return training: 53.06
# 527 0.42921999999953836 13.0
# Average return training: 52.38
# 528 0.42702399999953955 61.0
# Average return training: 52.76
# 529 0.4245759999995409 68.0
# Average return training: 53.32
# Average return over 25 episodes of playing: 20.44
# 530 0.4203279999995432 118.0
# Average return training: 54.31
# 531 0.41834799999954425 55.0
# Average return training: 54.18
# 532 0.4165479999995452 50.0
# Average return training: 54.46
# 533 0.4158639999995456 19.0
# Average return training: 53.76
# 534 0.4152879999995459 16.0
# Average return training: 53.67
# 535 0.4140279999995466 35.0
# Average return training: 53.86
# 536 0.41057199999954846 96.0
# Average return training: 54.67
# 537 0.4084479999995496 59.0
# Average return training: 54.38
# 538 0.4080879999995498 10.0
# Average return training: 53.86
# Average return over 25 episodes of playing: 191.84
# 539 0.40358799999955225 125.0
# Average return training: 54.79
# 540 0.4011039999995536 69.0
# Average return training: 54.53
# 541 0.40059999999955387 14.0
# Average return training: 54.36
# 542 0.4001679999995541 12.0
# Average return training: 53.25
# 543 0.398475999999555 47.0
# Average return training: 53.57
# 544 0.39746799999955557 28.0
# Average return training: 53.72
# 545 0.39433599999955726 87.0
# Average return training: 54.15
# 546 0.39343599999955775 25.0
# Average return training: 54.29
# 547 0.39192399999955857 42.0
# Average return training: 54.57
# 548 0.3912759999995589 18.0
# Average return training: 54.58
# 549 0.3905559999995593 20.0
# Average return training: 54.62
# 550 0.3900159999995596 15.0
# Average return training: 54.3
# Average return over 25 episodes of playing: 383.04
# 551 0.3876039999995609 67.0
# Average return training: 54.66
# 552 0.38418399999956276 95.0
# Average return training: 54.62
# 553 0.3836079999995631 16.0
# Average return training: 54.49
# 554 0.37957599999956526 112.0
# Average return training: 55.44
# 555 0.3772719999995665 64.0
# Average return training: 55.97
# 556 0.3756159999995674 46.0
# Average return training: 55.18
# 557 0.3750399999995677 16.0
# Average return training: 54.96
# 558 0.374571999999568 13.0
# Average return training: 54.83
# 559 0.37403199999956827 15.0
# Average return training: 54.04
# 560 0.37349199999956856 15.0
# Average return training: 53.44
# Average return over 25 episodes of playing: 402.12
# 561 0.3678759999995716 156.0
# Average return training: 54.75
# 562 0.3672999999995719 16.0
# Average return training: 53.61
# 563 0.3665799999995723 20.0
# Average return training: 53.66
# 564 0.3635919999995739 83.0
# Average return training: 54.26
# 565 0.3608559999995754 76.0
# Average return training: 53.93
# 566 0.3586599999995766 61.0
# Average return training: 54.4
# 567 0.35613999999957796 70.0
# Average return training: 53.68
# 568 0.3557079999995782 12.0
# Average return training: 53.66
# Average return over 25 episodes of playing: 500.0
# 569 0.3513159999995806 122.0
# Average return training: 54.18
# 570 0.35077599999958087 15.0
# Average return training: 54.2
# 571 0.34764399999958256 87.0
# Average return training: 54.76
# 572 0.346851999999583 22.0
# Average return training: 54.83
# 573 0.34069599999958633 171.0
# Average return training: 56.35
# 574 0.3383919999995876 64.0
# Average return training: 56.08
# 575 0.3379599999995878 12.0
# Average return training: 55.51
# 576 0.3352599999995893 75.0
# Average return training: 55.77
# Average return over 25 episodes of playing: 500.0
# 577 0.33270399999959066 71.0
# Average return training: 55.29
# 578 0.33104799999959156 46.0
# Average return training: 55.35
# 579 0.3300039999995921 29.0
# Average return training: 54.84
# 580 0.3273039999995936 75.0
# Average return training: 55.39
# 581 0.32665599999959394 18.0
# Average return training: 55.1
# 582 0.32625999999959415 11.0
# Average return training: 54.49
# 583 0.32366799999959556 72.0
# Average return training: 54.46
# 584 0.32316399999959583 14.0
# Average return training: 54.32
# 585 0.32129199999959684 52.0
# Average return training: 54.21
# Average return over 25 episodes of playing: 500.0
# 586 0.3032919999996066 500.0
# Average return training: 58.68
# 587 0.30264399999960695 18.0
# Average return training: 58.36
# 588 0.3021399999996072 14.0
# Average return training: 58.38
# 589 0.3014919999996076 18.0
# Average return training: 58.45
# Average return over 25 episodes of playing: 500.0
# 590 0.29522799999961097 174.0
# Average return training: 59.5
# Average return over 100 episodes of trained agent: 476.64
