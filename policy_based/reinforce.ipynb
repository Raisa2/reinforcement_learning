# %%
# Importing needed librarys
import torch
import torch.distributions as dist
import torch.nn as nn
import gym
import numpy as np
import random
import wandb

# %%
# Setting seeds
def make_deterministic(seed):
  torch.manual_seed(seed)
  random.seed(seed)
  np.random.seed(seed)

# %%
# Building a class for the neural network
class Neural_Network(nn.Module):
  def __init__(self, in_dim, out_dim, hidden_dim):
        super(Neural_Network, self).__init__()
        self.input_layer = nn.Linear(in_dim, hidden_dim[0])
        self.hidden_layer_1 = nn.Linear(hidden_dim[0], hidden_dim[1])
        self.hidden_layer_2 = nn.Linear(hidden_dim[1], hidden_dim[2])
        self.output_layer = nn.Linear(hidden_dim[2], out_dim)
       
  def forward (self, x, activation_function = nn.ReLU()):
    x = activation_function(self.input_layer(x))
    x = activation_function(self.hidden_layer_1(x))
    x = activation_function(self.hidden_layer_2(x))
    output = self.output_layer(x)
    return output

# %%
# Defining function for playing during and after training to obtain performance of the agent
def play(episodes, step, end, envs):
  x = 0
  returns = []

  for i in range(0, episodes):
    memory_rewards = []

    state = envs.reset()
    while True:
      state_tensor = torch.tensor(state, dtype=torch.float32)
      values = policy_model(state_tensor)
      distribution = dist.Categorical(logits = values)
      action = distribution.sample()
      state_next, reward, done, _ = envs.step(action.item())
      memory_rewards.append(reward)
      state = state_next

      if done:
        x = sum(memory_rewards)
        state = envs.reset()
        returns.append(x)
        break

  if end:
    avg_return = sum(returns[-100:]) / 100
    print("Average return over 100 episodes of trained agent:", avg_return)
  else:
    avg_return = sum(returns[-25:]) / 25
    wandb.log({"Average return over 25 episodes of playing:": avg_return,"step": step})
    print("Average return over 25 episodes of playing:", avg_return)

  return avg_return

# %%
##### REINFORCE Algorithm ###########

# Seeds for repeatable training results
SEEDS = (12, 34, 56)

# Creating two environments: One for training and for playing
env = gym.make("CartPole-v1")
env2 = gym.make("CartPole-v1")

# Looping over different seeds for training different agents
for seed in SEEDS:
  make_deterministic(seed)
  wandb.init(project="Reinforce-CartPole", entity="raisa")
  print("SEED:", seed)
  config = wandb.config

  # Defining hyperparameters
  gamma = 0.99 # gamma
  learning_rate = 0.001 # learning rate
  num_episodes = 10000 # maximum number of episodes
  hidden_dims = [128, 64, 32] # size of hidden layers in the neural network

  # Logging hyperparameters
  config.learning_rate = learning_rate
  config.gamma = gamma
  config.num_episodes = num_episodes
  config.hidden_dim = hidden_dims
  config.seed = seed

  # Setting the seed for the environments
  env.seed(seed)
  env.action_space.seed(seed)
  env2.seed(seed)
  env2.action_space.seed(seed)

  # Initializing list for average returns during training
  returns_train = []
  # Initializing list for average returns during playing
  returns_play = []

  # Creating neural network and setting optimizer
  policy_model = (Neural_Network(in_dim = int(np.prod(env.observation_space.shape)), out_dim = env.action_space.n, hidden_dim=hidden_dims))
  optimizer = torch.optim.Adam(policy_model.parameters(), lr=learning_rate)

  steps = 0
  reward_list = []
  disc_rewards = []
  discounts = []
  returns = []
  logs = []

  # Training the agent for number of episodes
  for episode in range(0, num_episodes):
    step = 0
    state = env.reset()
    reward_sum = 0
    returns.clear()
    logs.clear()
    while True:
      step += 1
      steps += 1

      # Choosing action and obtaining log value of action probability
      state_tensor = torch.tensor(state, dtype=torch.float32)
      values = policy_model(state_tensor)
      distribution = dist.Categorical(logits = values)
      action = distribution.sample()
      log_value = distribution.log_prob(action)
      state_next, reward, done, _ = env.step(action.item())
      reward_list.append(reward)
      logs.append(log_value)
      reward_sum += reward
      state = state_next

      # Playing every 500 steps to obtain the performance of the agent
      if steps % 500 == 0:
        avg_return_play = play(episodes = 25, step = steps, end = False, envs = env2)
        returns_play.append(avg_return_play)
      
      # Following these steps, if episode has come to an end
      if done:
        loss = 0

        # Calculating discounts
        for i in range(0,step):
          discounts.append(gamma**i)

        # Calculating discounted returns
        for i in range(0, step):
          disc_rewards = [x*y for x,y in zip(reward_list,discounts)]
          returns.append(torch.tensor(sum(disc_rewards)))
          reward_list.pop(0)

        returns_tensor = torch.stack(returns)
        logs_tensor = torch.stack(logs)
        
        # Calculating loss
        log_returns = - returns_tensor * logs_tensor
        loss = log_returns.mean()

        optimizer.zero_grad()

        # Backpropagating the loss
        loss.backward()

        # Taking an optimization step
        optimizer.step()

        print(episode + 1, reward_sum)

        returns_train.append(reward_sum)
        break

    # If episode > 100, then print the average reward for the last hundred episodes
    if episode + 1  > 100:
      x = sum(returns_train[-100:])/100
      print("Average return training:", x)
      # Logging the training average return
      wandb.log({"Average return over 100 episodes of training:": x, "episode": episode + 1})

    # If training steps >= 2500 and the agent has obtained an average reward of 475 during last 5 times of playing, end the training
    if steps >= 2500:
      if sum(returns_play[-5:]) / 5 >= 475:
        break

  # Playing after training to obtain end results
  play(episodes = 100, step = steps, end = True, envs = env2)
# Out:
# wandb: Currently logged in as: raisa (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/raisa/Reinforce-CartPole/runs/srxfj1hc" target="_blank">chocolate-paper-263</a></strong> to <a href="https://wandb.ai/raisa/Reinforce-CartPole" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# SEED: 12
# 1 13.0
# 2 12.0
# 3 22.0
# 4 17.0
# 5 23.0
# 6 12.0
# 7 35.0
# 8 18.0
# 9 21.0
# 10 12.0
# 11 14.0
# 12 14.0
# 13 11.0
# 14 31.0
# 15 21.0
# 16 17.0
# 17 17.0
# 18 34.0
# 19 26.0
# 20 40.0
# 21 29.0
# 22 10.0
# 23 19.0
# 24 20.0
# Average return over 25 episodes of playing: 19.08
# 25 12.0
# 26 20.0
# 27 37.0
# 28 16.0
# 29 20.0
# 30 54.0
# 31 15.0
# 32 29.0
# 33 41.0
# 34 56.0
# 35 14.0
# 36 17.0
# 37 44.0
# 38 27.0
# 39 28.0
# 40 12.0
# Average return over 25 episodes of playing: 26.04
# 41 83.0
# 42 40.0
# 43 19.0
# 44 13.0
# 45 21.0
# 46 15.0
# 47 19.0
# 48 17.0
# 49 36.0
# 50 25.0
# 51 18.0
# 52 25.0
# 53 66.0
# 54 20.0
# 55 25.0
# 56 23.0
# 57 19.0
# 58 40.0
# 59 11.0
# Average return over 25 episodes of playing: 25.28
# 60 46.0
# 61 11.0
# 62 26.0
# 63 18.0
# 64 13.0
# 65 22.0
# 66 23.0
# 67 29.0
# 68 38.0
# 69 16.0
# 70 29.0
# 71 30.0
# 72 43.0
# 73 18.0
# 74 18.0
# 75 16.0
# 76 9.0
# 77 30.0
# 78 12.0
# 79 14.0
# 80 10.0
# 81 34.0
# 82 26.0
# Average return over 25 episodes of playing: 26.52
# 83 15.0
# 84 19.0
# 85 23.0
# 86 56.0
# 87 34.0
# 88 14.0
# 89 74.0
# 90 22.0
# 91 48.0
# 92 37.0
# 93 15.0
# 94 26.0
# 95 28.0
# 96 11.0
# 97 15.0
# 98 29.0
# 99 32.0
# Average return over 25 episodes of playing: 23.96
# 100 9.0
# 101 32.0
# Average return training: 25.22
# 102 22.0
# Average return training: 25.32
# 103 16.0
# Average return training: 25.26
# 104 27.0
# Average return training: 25.36
# 105 25.0
# Average return training: 25.38
# 106 24.0
# Average return training: 25.5
# 107 13.0
# Average return training: 25.28
# 108 23.0
# Average return training: 25.33
# 109 19.0
# Average return training: 25.31
# 110 35.0
# Average return training: 25.54
# 111 48.0
# Average return training: 25.88
# 112 22.0
# Average return training: 25.96
# 113 24.0
# Average return training: 26.09
# 114 28.0
# Average return training: 26.06
# 115 12.0
# Average return training: 25.97
# 116 43.0
# Average return training: 26.23
# 117 13.0
# Average return training: 26.19
# 118 35.0
# Average return training: 26.2
# Average return over 25 episodes of playing: 27.88
# 119 48.0
# Average return training: 26.42
# 120 12.0
# Average return training: 26.14
# 121 17.0
# Average return training: 26.02
# 122 14.0
# Average return training: 26.06
# 123 33.0
# Average return training: 26.2
# 124 38.0
# Average return training: 26.38
# 125 33.0
# Average return training: 26.59
# 126 10.0
# Average return training: 26.49
# 127 23.0
# Average return training: 26.35
# 128 49.0
# Average return training: 26.68
# 129 27.0
# Average return training: 26.75
# 130 56.0
# Average return training: 26.77
# 131 11.0
# Average return training: 26.73
# 132 18.0
# Average return training: 26.62
# 133 79.0
# Average return training: 27.0
# 134 21.0
# Average return training: 26.65
# Average return over 25 episodes of playing: 34.64
# 135 50.0
# Average return training: 27.01
# 136 57.0
# Average return training: 27.41
# 137 59.0
# Average return training: 27.56
# 138 43.0
# Average return training: 27.72
# 139 69.0
# Average return training: 28.13
# 140 46.0
# Average return training: 28.47
# 141 48.0
# Average return training: 28.12
# 142 50.0
# Average return training: 28.22
# 143 31.0
# Average return training: 28.34
# 144 31.0
# Average return training: 28.52
# 145 12.0
# Average return training: 28.43
# 146 30.0
# Average return training: 28.58
# Average return over 25 episodes of playing: 40.12
# 147 29.0
# Average return training: 28.68
# 148 14.0
# Average return training: 28.65
# 149 21.0
# Average return training: 28.5
# 150 20.0
# Average return training: 28.45
# 151 18.0
# Average return training: 28.45
# 152 62.0
# Average return training: 28.82
# 153 16.0
# Average return training: 28.32
# 154 67.0
# Average return training: 28.79
# 155 25.0
# Average return training: 28.79
# 156 46.0
# Average return training: 29.02
# 157 32.0
# Average return training: 29.15
# 158 32.0
# Average return training: 29.07
# 159 77.0
# Average return training: 29.73
# 160 38.0
# Average return training: 29.65
# Average return over 25 episodes of playing: 33.52
# 161 32.0
# Average return training: 29.86
# 162 18.0
# Average return training: 29.78
# 163 24.0
# Average return training: 29.84
# 164 14.0
# Average return training: 29.85
# 165 24.0
# Average return training: 29.87
# 166 16.0
# Average return training: 29.8
# 167 30.0
# Average return training: 29.81
# 168 66.0
# Average return training: 30.09
# 169 33.0
# Average return training: 30.26
# 170 21.0
# Average return training: 30.18
# 171 80.0
# Average return training: 30.68
# 172 26.0
# Average return training: 30.51
# 173 81.0
# Average return training: 31.14
# 174 23.0
# Average return training: 31.19
# 175 35.0
# Average return training: 31.38
# Average return over 25 episodes of playing: 39.96
# 176 39.0
# Average return training: 31.68
# 177 23.0
# Average return training: 31.61
# 178 18.0
# Average return training: 31.67
# 179 25.0
# Average return training: 31.78
# 180 23.0
# Average return training: 31.91
# 181 58.0
# Average return training: 32.15
# 182 21.0
# Average return training: 32.1
# 183 38.0
# Average return training: 32.33
# 184 48.0
# Average return training: 32.62
# 185 39.0
# Average return training: 32.78
# 186 36.0
# Average return training: 32.58
# 187 19.0
# Average return training: 32.43
# 188 33.0
# Average return training: 32.62
# 189 38.0
# Average return training: 32.26
# 190 21.0
# Average return training: 32.25
# Average return over 25 episodes of playing: 37.76
# 191 40.0
# Average return training: 32.17
# 192 50.0
# Average return training: 32.3
# 193 16.0
# Average return training: 32.31
# 194 22.0
# Average return training: 32.27
# 195 68.0
# Average return training: 32.67
# 196 27.0
# Average return training: 32.83
# 197 12.0
# Average return training: 32.8
# 198 30.0
# Average return training: 32.81
# 199 22.0
# Average return training: 32.71
# 200 20.0
# Average return training: 32.82
# 201 37.0
# Average return training: 32.87
# 202 39.0
# Average return training: 33.04
# 203 22.0
# Average return training: 33.1
# 204 42.0
# Average return training: 33.25
# 205 40.0
# Average return training: 33.4
# 206 14.0
# Average return training: 33.3
# Average return over 25 episodes of playing: 28.96
# 207 27.0
# Average return training: 33.44
# 208 31.0
# Average return training: 33.52
# 209 24.0
# Average return training: 33.57
# 210 25.0
# Average return training: 33.47
# 211 99.0
# Average return training: 33.98
# 212 69.0
# Average return training: 34.45
# 213 20.0
# Average return training: 34.41
# 214 20.0
# Average return training: 34.33
# 215 38.0
# Average return training: 34.59
# 216 31.0
# Average return training: 34.47
# 217 21.0
# Average return training: 34.55
# 218 57.0
# Average return training: 34.77
# 219 24.0
# Average return training: 34.53
# Average return over 25 episodes of playing: 44.68
# 220 38.0
# Average return training: 34.79
# 221 75.0
# Average return training: 35.37
# 222 29.0
# Average return training: 35.52
# 223 38.0
# Average return training: 35.57
# 224 40.0
# Average return training: 35.59
# 225 22.0
# Average return training: 35.48
# 226 32.0
# Average return training: 35.7
# 227 14.0
# Average return training: 35.61
# 228 39.0
# Average return training: 35.51
# 229 65.0
# Average return training: 35.89
# 230 54.0
# Average return training: 35.87
# 231 32.0
# Average return training: 36.08
# 232 28.0
# Average return training: 36.18
# Average return over 25 episodes of playing: 45.8
# 233 31.0
# Average return training: 35.7
# 234 31.0
# Average return training: 35.8
# 235 34.0
# Average return training: 35.64
# 236 21.0
# Average return training: 35.28
# 237 77.0
# Average return training: 35.46
# 238 38.0
# Average return training: 35.41
# 239 22.0
# Average return training: 34.94
# 240 46.0
# Average return training: 34.94
# 241 21.0
# Average return training: 34.67
# 242 26.0
# Average return training: 34.43
# 243 17.0
# Average return training: 34.29
# 244 16.0
# Average return training: 34.14
# 245 25.0
# Average return training: 34.27
# 246 33.0
# Average return training: 34.3
# 247 36.0
# Average return training: 34.37
# 248 14.0
# Average return training: 34.37
# 249 37.0
# Average return training: 34.53
# Average return over 25 episodes of playing: 29.48
# 250 20.0
# Average return training: 34.53
# 251 28.0
# Average return training: 34.63
# 252 26.0
# Average return training: 34.27
# 253 16.0
# Average return training: 34.27
# 254 26.0
# Average return training: 33.86
# 255 27.0
# Average return training: 33.88
# 256 33.0
# Average return training: 33.75
# 257 23.0
# Average return training: 33.66
# 258 44.0
# Average return training: 33.78
# 259 24.0
# Average return training: 33.25
# 260 32.0
# Average return training: 33.19
# 261 38.0
# Average return training: 33.25
# 262 23.0
# Average return training: 33.3
# 263 36.0
# Average return training: 33.42
# 264 24.0
# Average return training: 33.52
# 265 31.0
# Average return training: 33.59
# 266 43.0
# Average return training: 33.86
# Average return over 25 episodes of playing: 29.68
# 267 29.0
# Average return training: 33.85
# 268 78.0
# Average return training: 33.97
# 269 41.0
# Average return training: 34.05
# 270 36.0
# Average return training: 34.2
# 271 26.0
# Average return training: 33.66
# 272 79.0
# Average return training: 34.19
# 273 46.0
# Average return training: 33.84
# 274 22.0
# Average return training: 33.83
# 275 39.0
# Average return training: 33.87
# 276 41.0
# Average return training: 33.89
# Average return over 25 episodes of playing: 42.04
# 277 88.0
# Average return training: 34.54
# 278 18.0
# Average return training: 34.54
# 279 32.0
# Average return training: 34.61
# 280 32.0
# Average return training: 34.7
# 281 44.0
# Average return training: 34.56
# 282 22.0
# Average return training: 34.57
# 283 32.0
# Average return training: 34.51
# 284 39.0
# Average return training: 34.42
# 285 19.0
# Average return training: 34.22
# 286 88.0
# Average return training: 34.74
# 287 32.0
# Average return training: 34.87
# 288 41.0
# Average return training: 34.95
# 289 61.0
# Average return training: 35.18
# Average return over 25 episodes of playing: 48.56
# 290 46.0
# Average return training: 35.43
# 291 81.0
# Average return training: 35.84
# 292 47.0
# Average return training: 35.81
# 293 31.0
# Average return training: 35.96
# 294 33.0
# Average return training: 36.07
# 295 18.0
# Average return training: 35.57
# 296 33.0
# Average return training: 35.63
# 297 37.0
# Average return training: 35.88
# 298 60.0
# Average return training: 36.18
# 299 30.0
# Average return training: 36.26
# 300 65.0
# Average return training: 36.71
# 301 28.0
# Average return training: 36.62
# Average return over 25 episodes of playing: 44.6
# 302 29.0
# Average return training: 36.52
# 303 38.0
# Average return training: 36.68
# 304 64.0
# Average return training: 36.9
# 305 27.0
# Average return training: 36.77
# 306 80.0
# Average return training: 37.43
# 307 131.0
# Average return training: 38.47
# 308 42.0
# Average return training: 38.58
# 309 100.0
# Average return training: 39.34
# Average return over 25 episodes of playing: 46.92
# 310 40.0
# Average return training: 39.49
# 311 66.0
# Average return training: 39.16
# 312 41.0
# Average return training: 38.88
# 313 56.0
# Average return training: 39.24
# 314 45.0
# Average return training: 39.49
# 315 67.0
# Average return training: 39.78
# 316 25.0
# Average return training: 39.72
# 317 57.0
# Average return training: 40.08
# 318 77.0
# Average return training: 40.28
# Average return over 25 episodes of playing: 60.28
# 319 55.0
# Average return training: 40.59
# 320 40.0
# Average return training: 40.61
# 321 39.0
# Average return training: 40.25
# 322 26.0
# Average return training: 40.22
# 323 25.0
# Average return training: 40.09
# 324 132.0
# Average return training: 41.01
# 325 75.0
# Average return training: 41.54
# Average return over 25 episodes of playing: 79.4
# 326 162.0
# Average return training: 42.84
# 327 84.0
# Average return training: 43.54
# 328 28.0
# Average return training: 43.43
# 329 75.0
# Average return training: 43.53
# 330 45.0
# Average return training: 43.44
# 331 13.0
# Average return training: 43.25
# 332 36.0
# Average return training: 43.33
# 333 47.0
# Average return training: 43.49
# 334 29.0
# Average return training: 43.47
# 335 47.0
# Average return training: 43.6
# 336 49.0
# Average return training: 43.88
# Average return over 25 episodes of playing: 67.04
# 337 99.0
# Average return training: 44.1
# 338 36.0
# Average return training: 44.08
# 339 24.0
# Average return training: 44.1
# 340 116.0
# Average return training: 44.8
# 341 76.0
# Average return training: 45.35
# 342 43.0
# Average return training: 45.52
# 343 45.0
# Average return training: 45.8
# Average return over 25 episodes of playing: 69.32
# 344 118.0
# Average return training: 46.82
# 345 55.0
# Average return training: 47.12
# 346 94.0
# Average return training: 47.73
# 347 54.0
# Average return training: 47.91
# 348 98.0
# Average return training: 48.75
# 349 38.0
# Average return training: 48.76
# 350 113.0
# Average return training: 49.69
# Average return over 25 episodes of playing: 80.32
# 351 50.0
# Average return training: 49.91
# 352 65.0
# Average return training: 50.3
# 353 69.0
# Average return training: 50.83
# 354 180.0
# Average return training: 52.37
# Average return over 25 episodes of playing: 60.72
# 355 177.0
# Average return training: 53.87
# 356 42.0
# Average return training: 53.96
# 357 180.0
# Average return training: 55.53
# 358 109.0
# Average return training: 56.18
# 359 102.0
# Average return training: 56.96
# Average return over 25 episodes of playing: 83.28
# 360 78.0
# Average return training: 57.42
# 361 50.0
# Average return training: 57.54
# 362 85.0
# Average return training: 58.16
# 363 122.0
# Average return training: 59.02
# 364 133.0
# Average return training: 60.11
# Average return over 25 episodes of playing: 103.6
# 365 126.0
# Average return training: 61.06
# 366 67.0
# Average return training: 61.3
# 367 61.0
# Average return training: 61.62
# 368 180.0
# Average return training: 62.64
# 369 60.0
# Average return training: 62.83
# Average return over 25 episodes of playing: 121.56
# 370 149.0
# Average return training: 63.96
# 371 177.0
# Average return training: 65.47
# 372 90.0
# Average return training: 65.58
# 373 77.0
# Average return training: 65.89
# 374 58.0
# Average return training: 66.25
# Average return over 25 episodes of playing: 114.44
# 375 154.0
# Average return training: 67.4
# 376 104.0
# Average return training: 68.03
# 377 172.0
# Average return training: 68.87
# Average return over 25 episodes of playing: 120.96
# 378 204.0
# Average return training: 70.73
# 379 106.0
# Average return training: 71.47
# 380 46.0
# Average return training: 71.61
# 381 129.0
# Average return training: 72.46
# Average return over 25 episodes of playing: 187.16
# 382 175.0
# Average return training: 73.99
# 383 44.0
# Average return training: 74.11
# 384 147.0
# Average return training: 75.19
# 385 115.0
# Average return training: 76.15
# 386 131.0
# Average return training: 76.58
# Average return over 25 episodes of playing: 174.48
# 387 137.0
# Average return training: 77.63
# 388 147.0
# Average return training: 78.69
# Average return over 25 episodes of playing: 197.04
# 389 296.0
# Average return training: 81.04
# 390 104.0
# Average return training: 81.62
# 391 92.0
# Average return training: 81.73
# 392 107.0
# Average return training: 82.33
# 393 80.0
# Average return training: 82.82
# Average return over 25 episodes of playing: 157.36
# 394 224.0
# Average return training: 84.73
# 395 126.0
# Average return training: 85.81
# 396 128.0
# Average return training: 86.76
# Average return over 25 episodes of playing: 137.12
# 397 119.0
# Average return training: 87.58
# 398 96.0
# Average return training: 87.94
# 399 115.0
# Average return training: 88.79
# 400 29.0
# Average return training: 88.43
# 401 100.0
# Average return training: 89.15
# 402 71.0
# Average return training: 89.57
# 403 23.0
# Average return training: 89.42
# Average return over 25 episodes of playing: 81.24
# 404 98.0
# Average return training: 89.76
# 405 94.0
# Average return training: 90.43
# 406 106.0
# Average return training: 90.69
# 407 36.0
# Average return training: 89.74
# 408 26.0
# Average return training: 89.58
# 409 53.0
# Average return training: 89.11
# 410 48.0
# Average return training: 89.19
# Average return over 25 episodes of playing: 46.64
# 411 141.0
# Average return training: 89.94
# 412 116.0
# Average return training: 90.69
# 413 46.0
# Average return training: 90.59
# 414 56.0
# Average return training: 90.7
# 415 34.0
# Average return training: 90.37
# Average return over 25 episodes of playing: 92.2
# 416 182.0
# Average return training: 91.94
# 417 177.0
# Average return training: 93.14
# 418 100.0
# Average return training: 93.37
# 419 29.0
# Average return training: 93.11
# Average return over 25 episodes of playing: 168.84
# 420 181.0
# Average return training: 94.52
# 421 103.0
# Average return training: 95.16
# 422 89.0
# Average return training: 95.79
# 423 240.0
# Average return training: 97.94
# Average return over 25 episodes of playing: 221.28
# 424 213.0
# Average return training: 98.75
# 425 217.0
# Average return training: 100.17
# Average return over 25 episodes of playing: 233.28
# 426 315.0
# Average return training: 101.7
# 427 212.0
# Average return training: 102.98
# Average return over 25 episodes of playing: 311.76
# 428 221.0
# Average return training: 104.91
# 429 241.0
# Average return training: 106.57
# Average return over 25 episodes of playing: 317.12
# 430 470.0
# Average return training: 110.82
# Average return over 25 episodes of playing: 276.68
# 431 364.0
# Average return training: 114.33
# 432 167.0
# Average return training: 115.64
# Average return over 25 episodes of playing: 287.52
# 433 271.0
# Average return training: 117.88
# 434 251.0
# Average return training: 120.1
# Average return over 25 episodes of playing: 284.76
# 435 405.0
# Average return training: 123.68
# Average return over 25 episodes of playing: 279.24
# 436 224.0
# Average return training: 125.43
# 437 261.0
# Average return training: 127.05
# Average return over 25 episodes of playing: 292.68
# 438 334.0
# Average return training: 130.03
# Average return over 25 episodes of playing: 341.24
# 439 410.0
# Average return training: 133.89
# Average return over 25 episodes of playing: 387.64
# 440 500.0
# Average return training: 137.73
# Average return over 25 episodes of playing: 429.64
# 441 500.0
# Average return training: 141.97
# Average return over 25 episodes of playing: 398.48
# 442 500.0
# Average return training: 146.54
# Average return over 25 episodes of playing: 388.84
# 443 500.0
# Average return training: 151.09
# 444 367.0
# Average return training: 153.58
# Average return over 25 episodes of playing: 300.56
# 445 146.0
# Average return training: 154.49
# 446 444.0
# Average return training: 157.99
# Average return over 25 episodes of playing: 222.52
# 447 205.0
# Average return training: 159.5
# 448 158.0
# Average return training: 160.1
# Average return over 25 episodes of playing: 345.04
# 449 327.0
# Average return training: 162.99
# Average return over 25 episodes of playing: 310.72
# 450 424.0
# Average return training: 166.1
# Average return over 25 episodes of playing: 376.24
# 451 438.0
# Average return training: 169.98
# 452 325.0
# Average return training: 172.58
# Average return over 25 episodes of playing: 302.36
# 453 500.0
# Average return training: 176.89
# Average return over 25 episodes of playing: 333.88
# 454 203.0
# Average return training: 177.12
# 455 237.0
# Average return training: 177.72
# Average return over 25 episodes of playing: 242.96
# 456 210.0
# Average return training: 179.4
# 457 181.0
# Average return training: 179.41
# Average return over 25 episodes of playing: 267.56
# 458 463.0
# Average return training: 182.95
# 459 246.0
# Average return training: 184.39
# Average return over 25 episodes of playing: 221.08
# 460 365.0
# Average return training: 187.26
# Average return over 25 episodes of playing: 204.36
# 461 500.0
# Average return training: 191.76
# Average return over 25 episodes of playing: 260.48
# 462 467.0
# Average return training: 195.58
# 463 209.0
# Average return training: 196.45
# Average return over 25 episodes of playing: 255.92
# 464 386.0
# Average return training: 198.98
# Average return over 25 episodes of playing: 271.8
# 465 200.0
# Average return training: 199.72
# 466 127.0
# Average return training: 200.32
# Average return over 25 episodes of playing: 310.88
# 467 500.0
# Average return training: 204.71
# 468 125.0
# Average return training: 204.16
# Average return over 25 episodes of playing: 297.72
# 469 318.0
# Average return training: 206.74
# 470 280.0
# Average return training: 208.05
# Average return over 25 episodes of playing: 279.2
# 471 500.0
# Average return training: 211.28
# Average return over 25 episodes of playing: 352.56
# 472 339.0
# Average return training: 213.77
# Average return over 25 episodes of playing: 310.0
# 473 408.0
# Average return training: 217.08
# Average return over 25 episodes of playing: 396.44
# 474 500.0
# Average return training: 221.5
# 475 270.0
# Average return training: 222.66
# Average return over 25 episodes of playing: 265.08
# 476 263.0
# Average return training: 224.25
# 477 227.0
# Average return training: 224.8
# Average return over 25 episodes of playing: 186.28
# 478 155.0
# Average return training: 224.31
# 479 203.0
# Average return training: 225.28
# 480 109.0
# Average return training: 225.91
# 481 104.0
# Average return training: 225.66
# Average return over 25 episodes of playing: 124.04
# 482 119.0
# Average return training: 225.1
# 483 98.0
# Average return training: 225.64
# 484 107.0
# Average return training: 225.24
# 485 97.0
# Average return training: 225.06
# 486 45.0
# Average return training: 224.2
# 487 77.0
# Average return training: 223.6
# Average return over 25 episodes of playing: 52.36
# 488 52.0
# Average return training: 222.65
# 489 34.0
# Average return training: 220.03
# 490 85.0
# Average return training: 219.84
# 491 52.0
# Average return training: 219.44
# 492 41.0
# Average return training: 218.78
# 493 46.0
# Average return training: 218.44
# 494 32.0
# Average return training: 216.52
# 495 40.0
# Average return training: 215.66
# 496 31.0
# Average return training: 214.69
# 497 58.0
# Average return training: 214.08
# Average return over 25 episodes of playing: 38.4
# 498 52.0
# Average return training: 213.64
# 499 26.0
# Average return training: 212.75
# 500 56.0
# Average return training: 213.02
# 501 55.0
# Average return training: 212.57
# 502 66.0
# Average return training: 212.52
# 503 30.0
# Average return training: 212.59
# 504 39.0
# Average return training: 212.0
# 505 79.0
# Average return training: 211.85
# 506 71.0
# Average return training: 211.5
# 507 28.0
# Average return training: 211.42
# Average return over 25 episodes of playing: 56.84
# 508 54.0
# Average return training: 211.7
# 509 65.0
# Average return training: 211.82
# 510 113.0
# Average return training: 212.47
# 511 100.0
# Average return training: 212.06
# 512 93.0
# Average return training: 211.83
# Average return over 25 episodes of playing: 82.48
# 513 122.0
# Average return training: 212.59
# 514 125.0
# Average return training: 213.28
# 515 113.0
# Average return training: 214.07
# 516 107.0
# Average return training: 213.32
# 517 116.0
# Average return training: 212.71
# Average return over 25 episodes of playing: 123.52
# 518 133.0
# Average return training: 213.04
# 519 110.0
# Average return training: 213.85
# 520 115.0
# Average return training: 213.19
# 521 135.0
# Average return training: 213.51
# Average return over 25 episodes of playing: 133.2
# 522 129.0
# Average return training: 213.91
# 523 114.0
# Average return training: 212.65
# 524 126.0
# Average return training: 211.78
# 525 114.0
# Average return training: 210.75
# Average return over 25 episodes of playing: 128.48
# 526 125.0
# Average return training: 208.85
# 527 128.0
# Average return training: 208.01
# 528 123.0
# Average return training: 207.03
# 529 141.0
# Average return training: 206.03
# Average return over 25 episodes of playing: 126.32
# 530 109.0
# Average return training: 202.42
# 531 109.0
# Average return training: 199.87
# 532 125.0
# Average return training: 199.45
# 533 112.0
# Average return training: 197.86
# Average return over 25 episodes of playing: 117.48
# 534 104.0
# Average return training: 196.39
# 535 123.0
# Average return training: 193.57
# 536 108.0
# Average return training: 192.41
# 537 109.0
# Average return training: 190.89
# 538 114.0
# Average return training: 188.69
# Average return over 25 episodes of playing: 104.04
# 539 110.0
# Average return training: 185.69
# 540 108.0
# Average return training: 181.77
# 541 120.0
# Average return training: 177.97
# 542 119.0
# Average return training: 174.16
# Average return over 25 episodes of playing: 99.24
# 543 93.0
# Average return training: 170.09
# 544 110.0
# Average return training: 167.52
# 545 103.0
# Average return training: 167.09
# 546 114.0
# Average return training: 163.79
# 547 104.0
# Average return training: 162.78
# Average return over 25 episodes of playing: 100.4
# 548 103.0
# Average return training: 162.23
# 549 115.0
# Average return training: 160.11
# 550 103.0
# Average return training: 156.9
# 551 110.0
# Average return training: 153.62
# 552 53.0
# Average return training: 150.9
# 553 27.0
# Average return training: 146.17
# Average return over 25 episodes of playing: 93.28
# 554 106.0
# Average return training: 145.2
# 555 53.0
# Average return training: 143.36
# 556 47.0
# Average return training: 141.73
# 557 50.0
# Average return training: 140.42
# 558 54.0
# Average return training: 136.33
# 559 48.0
# Average return training: 134.35
# 560 29.0
# Average return training: 130.99
# 561 42.0
# Average return training: 126.41
# 562 41.0
# Average return training: 122.15
# 563 53.0
# Average return training: 120.59
# Average return over 25 episodes of playing: 50.08
# 564 39.0
# Average return training: 117.12
# 565 26.0
# Average return training: 115.38
# 566 39.0
# Average return training: 114.5
# 567 70.0
# Average return training: 110.2
# 568 44.0
# Average return training: 109.39
# 569 33.0
# Average return training: 106.54
# 570 31.0
# Average return training: 104.05
# 571 45.0
# Average return training: 99.5
# 572 33.0
# Average return training: 96.44
# 573 26.0
# Average return training: 92.62
# 574 41.0
# Average return training: 88.03
# 575 53.0
# Average return training: 85.86
# Average return over 25 episodes of playing: 36.16
# 576 29.0
# Average return training: 83.52
# 577 27.0
# Average return training: 81.52
# 578 37.0
# Average return training: 80.34
# 579 44.0
# Average return training: 78.75
# 580 43.0
# Average return training: 78.09
# 581 54.0
# Average return training: 77.59
# 582 67.0
# Average return training: 77.07
# 583 38.0
# Average return training: 76.47
# 584 68.0
# Average return training: 76.08
# 585 103.0
# Average return training: 76.14
# Average return over 25 episodes of playing: 90.48
# 586 39.0
# Average return training: 76.08
# 587 107.0
# Average return training: 76.38
# 588 110.0
# Average return training: 76.96
# 589 33.0
# Average return training: 76.95
# 590 100.0
# Average return training: 77.1
# Average return over 25 episodes of playing: 103.84
# 591 125.0
# Average return training: 77.83
# 592 114.0
# Average return training: 78.56
# 593 120.0
# Average return training: 79.3
# 594 128.0
# Average return training: 80.26
# 595 112.0
# Average return training: 80.98
# Average return over 25 episodes of playing: 122.92
# 596 114.0
# Average return training: 81.81
# 597 119.0
# Average return training: 82.42
# 598 133.0
# Average return training: 83.23
# 599 106.0
# Average return training: 84.03
# Average return over 25 episodes of playing: 119.08
# 600 108.0
# Average return training: 84.55
# 601 142.0
# Average return training: 85.42
# 602 114.0
# Average return training: 85.9
# 603 112.0
# Average return training: 86.72
# Average return over 25 episodes of playing: 100.76
# 604 110.0
# Average return training: 87.43
# 605 112.0
# Average return training: 87.76
# 606 101.0
# Average return training: 88.06
# 607 107.0
# Average return training: 88.85
# 608 96.0
# Average return training: 89.27
# Average return over 25 episodes of playing: 82.36
# 609 116.0
# Average return training: 89.78
# 610 96.0
# Average return training: 89.61
# 611 118.0
# Average return training: 89.79
# 612 67.0
# Average return training: 89.53
# 613 97.0
# Average return training: 89.28
# 614 51.0
# Average return training: 88.54
# Average return over 25 episodes of playing: 78.24
# 615 91.0
# Average return training: 88.32
# 616 48.0
# Average return training: 87.73
# 617 69.0
# Average return training: 87.26
# 618 73.0
# Average return training: 86.66
# 619 99.0
# Average return training: 86.55
# 620 89.0
# Average return training: 86.29
# Average return over 25 episodes of playing: 87.12
# 621 101.0
# Average return training: 85.95
# 622 104.0
# Average return training: 85.7
# 623 107.0
# Average return training: 85.63
# 624 40.0
# Average return training: 84.77
# 625 96.0
# Average return training: 84.59
# Average return over 25 episodes of playing: 91.8
# 626 108.0
# Average return training: 84.42
# 627 88.0
# Average return training: 84.02
# 628 114.0
# Average return training: 83.93
# 629 109.0
# Average return training: 83.61
# 630 108.0
# Average return training: 83.6
# Average return over 25 episodes of playing: 106.2
# 631 109.0
# Average return training: 83.6
# 632 117.0
# Average return training: 83.52
# 633 116.0
# Average return training: 83.56
# 634 102.0
# Average return training: 83.54
# 635 109.0
# Average return training: 83.4
# Average return over 25 episodes of playing: 108.96
# 636 108.0
# Average return training: 83.4
# 637 78.0
# Average return training: 83.09
# 638 114.0
# Average return training: 83.09
# 639 112.0
# Average return training: 83.11
# Average return over 25 episodes of playing: 100.96
# 640 114.0
# Average return training: 83.17
# 641 46.0
# Average return training: 82.43
# 642 125.0
# Average return training: 82.49
# 643 95.0
# Average return training: 82.51
# 644 96.0
# Average return training: 82.37
# 645 106.0
# Average return training: 82.4
# Average return over 25 episodes of playing: 91.32
# 646 112.0
# Average return training: 82.38
# 647 118.0
# Average return training: 82.52
# 648 67.0
# Average return training: 82.16
# 649 111.0
# Average return training: 82.12
# 650 103.0
# Average return training: 82.12
# Average return over 25 episodes of playing: 102.4
# 651 103.0
# Average return training: 82.05
# 652 108.0
# Average return training: 82.6
# 653 46.0
# Average return training: 82.79
# 654 117.0
# Average return training: 82.9
# 655 101.0
# Average return training: 83.38
# Average return over 25 episodes of playing: 97.64
# 656 109.0
# Average return training: 84.0
# 657 104.0
# Average return training: 84.54
# 658 109.0
# Average return training: 85.09
# 659 123.0
# Average return training: 85.84
# Average return over 25 episodes of playing: 93.32
# 660 95.0
# Average return training: 86.5
# 661 109.0
# Average return training: 87.17
# 662 105.0
# Average return training: 87.81
# 663 114.0
# Average return training: 88.42
# 664 105.0
# Average return training: 89.08
# Average return over 25 episodes of playing: 106.36
# 665 109.0
# Average return training: 89.91
# 666 110.0
# Average return training: 90.62
# 667 120.0
# Average return training: 91.12
# 668 116.0
# Average return training: 91.84
# Average return over 25 episodes of playing: 121.32
# 669 101.0
# Average return training: 92.52
# 670 112.0
# Average return training: 93.33
# 671 105.0
# Average return training: 93.93
# 672 126.0
# Average return training: 94.86
# 673 112.0
# Average return training: 95.72
# Average return over 25 episodes of playing: 118.56
# 674 122.0
# Average return training: 96.53
# 675 115.0
# Average return training: 97.15
# 676 137.0
# Average return training: 98.23
# 677 114.0
# Average return training: 99.1
# Average return over 25 episodes of playing: 119.52
# 678 112.0
# Average return training: 99.85
# 679 125.0
# Average return training: 100.66
# 680 123.0
# Average return training: 101.46
# 681 128.0
# Average return training: 102.2
# Average return over 25 episodes of playing: 114.72
# 682 117.0
# Average return training: 102.7
# 683 104.0
# Average return training: 103.36
# 684 112.0
# Average return training: 103.8
# 685 120.0
# Average return training: 103.97
# Average return over 25 episodes of playing: 120.2
# 686 139.0
# Average return training: 104.97
# 687 123.0
# Average return training: 105.13
# 688 107.0
# Average return training: 105.1
# 689 130.0
# Average return training: 106.07
# Average return over 25 episodes of playing: 123.44
# 690 128.0
# Average return training: 106.35
# 691 112.0
# Average return training: 106.22
# 692 135.0
# Average return training: 106.43
# 693 131.0
# Average return training: 106.54
# Average return over 25 episodes of playing: 136.92
# 694 124.0
# Average return training: 106.5
# 695 134.0
# Average return training: 106.72
# 696 166.0
# Average return training: 107.24
# 697 127.0
# Average return training: 107.32
# Average return over 25 episodes of playing: 153.2
# 698 157.0
# Average return training: 107.56
# 699 146.0
# Average return training: 107.96
# 700 177.0
# Average return training: 108.65
# Average return over 25 episodes of playing: 184.08
# 701 168.0
# Average return training: 108.91
# 702 202.0
# Average return training: 109.79
# Average return over 25 episodes of playing: 194.8
# 703 218.0
# Average return training: 110.85
# 704 184.0
# Average return training: 111.59
# 705 231.0
# Average return training: 112.78
# Average return over 25 episodes of playing: 227.32
# 706 233.0
# Average return training: 114.1
# 707 252.0
# Average return training: 115.55
# Average return over 25 episodes of playing: 228.64
# 708 273.0
# Average return training: 117.32
# 709 222.0
# Average return training: 118.38
# Average return over 25 episodes of playing: 258.08
# 710 250.0
# Average return training: 119.92
# 711 220.0
# Average return training: 120.94
# Average return over 25 episodes of playing: 258.64
# 712 250.0
# Average return training: 122.77
# 713 301.0
# Average return training: 124.81
# Average return over 25 episodes of playing: 259.36
# 714 227.0
# Average return training: 126.57
# 715 266.0
# Average return training: 128.32
# Average return over 25 episodes of playing: 239.32
# 716 218.0
# Average return training: 130.02
# 717 253.0
# Average return training: 131.86
# Average return over 25 episodes of playing: 251.36
# 718 264.0
# Average return training: 133.77
# 719 268.0
# Average return training: 135.46
# Average return over 25 episodes of playing: 244.32
# 720 290.0
# Average return training: 137.47
# 721 249.0
# Average return training: 138.95
# Average return over 25 episodes of playing: 292.44
# 722 270.0
# Average return training: 140.61
# Average return over 25 episodes of playing: 308.64
# 723 283.0
# Average return training: 142.37
# 724 316.0
# Average return training: 145.13
# Average return over 25 episodes of playing: 324.52
# 725 358.0
# Average return training: 147.75
# Average return over 25 episodes of playing: 331.48
# 726 323.0
# Average return training: 149.9
# 727 362.0
# Average return training: 152.64
# Average return over 25 episodes of playing: 338.0
# 728 360.0
# Average return training: 155.1
# Average return over 25 episodes of playing: 340.28
# 729 359.0
# Average return training: 157.6
# Average return over 25 episodes of playing: 348.96
# 730 422.0
# Average return training: 160.74
# 731 305.0
# Average return training: 162.7
# Average return over 25 episodes of playing: 434.68
# 732 390.0
# Average return training: 165.43
# Average return over 25 episodes of playing: 461.72
# 733 412.0
# Average return training: 168.39
# Average return over 25 episodes of playing: 467.6
# 734 414.0
# Average return training: 171.51
# Average return over 25 episodes of playing: 470.24
# 735 500.0
# Average return training: 175.42
# Average return over 25 episodes of playing: 494.04
# 736 500.0
# Average return training: 179.34
# Average return over 25 episodes of playing: 476.76
# 737 500.0
# Average return training: 183.56
# Average return over 25 episodes of playing: 494.52
# 738 500.0
# Average return training: 187.42
# Average return over 100 episodes of trained agent: 485.89
# Finishing last run (ID:srxfj1hc) before initializing another...
# <br/>Waiting for W&B process to finish, PID 966... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>Average return over 100 episodes of training:</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▃▃▃▄▆▇████▇▅▄▃▃▃▃▃▃▄▄▅▆</td></tr><tr><td>Average return over 25 episodes of playing:</td><td>▁▁▁▁▁▁▂▂▂▄▃▃▆▅▆▇▅▄▄▅▆▃▁▃▂▂▂▂▂▂▂▂▂▃▅▅▅▆██</td></tr><tr><td>episode</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>Average return over 100 episodes of training:</td><td>187.42</td></tr><tr><td>Average return over 25 episodes of playing:</td><td>494.52</td></tr><tr><td>episode</td><td>738</td></tr><tr><td>step</td><td>70500</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">chocolate-paper-263</strong>: <a href="https://wandb.ai/raisa/Reinforce-CartPole/runs/srxfj1hc" target="_blank">https://wandb.ai/raisa/Reinforce-CartPole/runs/srxfj1hc</a><br/>
# Find logs at: <code>./wandb/run-20220116_184238-srxfj1hc/logs</code><br/>
# Successfully finished last run (ID:srxfj1hc). Initializing new run:<br/>
#                     Syncing run <strong><a href="https://wandb.ai/raisa/Reinforce-CartPole/runs/2itpylre" target="_blank">chocolate-totem-264</a></strong> to <a href="https://wandb.ai/raisa/Reinforce-CartPole" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# SEED: 34
# 1 22.0
# 2 17.0
# 3 10.0
# 4 26.0
# 5 13.0
# 6 22.0
# 7 42.0
# 8 37.0
# 9 16.0
# 10 14.0
# 11 47.0
# 12 15.0
# 13 15.0
# 14 21.0
# 15 89.0
# 16 9.0
# 17 15.0
# 18 19.0
# 19 41.0
# Average return over 25 episodes of playing: 24.36
# 20 21.0
# 21 15.0
# 22 13.0
# 23 17.0
# 24 23.0
# 25 57.0
# 26 18.0
# 27 12.0
# 28 14.0
# 29 13.0
# 30 10.0
# 31 13.0
# 32 17.0
# 33 62.0
# 34 10.0
# 35 12.0
# 36 23.0
# 37 22.0
# 38 11.0
# 39 12.0
# 40 13.0
# Average return over 25 episodes of playing: 22.24
# 41 112.0
# 42 10.0
# 43 10.0
# 44 26.0
# 45 19.0
# 46 13.0
# 47 23.0
# 48 13.0
# 49 19.0
# 50 19.0
# 51 18.0
# 52 64.0
# 53 18.0
# 54 13.0
# 55 16.0
# 56 58.0
# 57 26.0
# 58 20.0
# 59 68.0
# 60 10.0
# 61 23.0
# Average return over 25 episodes of playing: 22.08
# 62 24.0
# 63 30.0
# 64 16.0
# 65 11.0
# 66 15.0
# 67 8.0
# 68 17.0
# 69 29.0
# 70 17.0
# 71 81.0
# 72 17.0
# 73 19.0
# 74 39.0
# 75 47.0
# 76 14.0
# 77 21.0
# 78 21.0
# 79 16.0
# 80 19.0
# 81 16.0
# Average return over 25 episodes of playing: 23.48
# 82 40.0
# 83 20.0
# 84 33.0
# 85 31.0
# 86 38.0
# 87 23.0
# 88 26.0
# 89 22.0
# 90 18.0
# 91 21.0
# 92 22.0
# 93 15.0
# 94 60.0
# 95 14.0
# 96 36.0
# 97 34.0
# 98 69.0
# Average return over 25 episodes of playing: 28.4
# 99 56.0
# 100 21.0
# 101 14.0
# Average return training: 25.64
# 102 15.0
# Average return training: 25.62
# 103 19.0
# Average return training: 25.71
# 104 17.0
# Average return training: 25.62
# 105 20.0
# Average return training: 25.69
# 106 25.0
# Average return training: 25.72
# 107 18.0
# Average return training: 25.48
# 108 38.0
# Average return training: 25.49
# 109 19.0
# Average return training: 25.52
# 110 33.0
# Average return training: 25.71
# 111 25.0
# Average return training: 25.49
# 112 15.0
# Average return training: 25.49
# 113 16.0
# Average return training: 25.5
# 114 37.0
# Average return training: 25.66
# 115 20.0
# Average return training: 24.97
# 116 27.0
# Average return training: 25.15
# 117 39.0
# Average return training: 25.39
# 118 26.0
# Average return training: 25.46
# Average return over 25 episodes of playing: 29.12
# 119 26.0
# Average return training: 25.31
# 120 18.0
# Average return training: 25.28
# 121 15.0
# Average return training: 25.28
# 122 15.0
# Average return training: 25.3
# 123 85.0
# Average return training: 25.98
# 124 31.0
# Average return training: 26.06
# 125 13.0
# Average return training: 25.62
# 126 25.0
# Average return training: 25.69
# 127 15.0
# Average return training: 25.72
# 128 29.0
# Average return training: 25.87
# 129 14.0
# Average return training: 25.88
# 130 73.0
# Average return training: 26.51
# 131 35.0
# Average return training: 26.73
# 132 31.0
# Average return training: 26.87
# 133 15.0
# Average return training: 26.4
# 134 48.0
# Average return training: 26.78
# 135 14.0
# Average return training: 26.8
# Average return over 25 episodes of playing: 34.6
# 136 31.0
# Average return training: 26.88
# 137 9.0
# Average return training: 26.75
# 138 52.0
# Average return training: 27.16
# 139 35.0
# Average return training: 27.39
# 140 18.0
# Average return training: 27.44
# 141 28.0
# Average return training: 26.6
# 142 47.0
# Average return training: 26.97
# 143 57.0
# Average return training: 27.44
# 144 51.0
# Average return training: 27.69
# 145 27.0
# Average return training: 27.77
# 146 43.0
# Average return training: 28.07
# 147 22.0
# Average return training: 28.06
# 148 79.0
# Average return training: 28.72
# Average return over 25 episodes of playing: 30.52
# 149 24.0
# Average return training: 28.77
# 150 42.0
# Average return training: 29.0
# 151 26.0
# Average return training: 29.08
# 152 41.0
# Average return training: 28.85
# 153 17.0
# Average return training: 28.84
# 154 30.0
# Average return training: 29.01
# 155 70.0
# Average return training: 29.55
# 156 24.0
# Average return training: 29.21
# 157 17.0
# Average return training: 29.12
# 158 18.0
# Average return training: 29.1
# 159 31.0
# Average return training: 28.73
# 160 21.0
# Average return training: 28.84
# 161 24.0
# Average return training: 28.85
# 162 12.0
# Average return training: 28.73
# 163 20.0
# Average return training: 28.63
# 164 17.0
# Average return training: 28.64
# 165 19.0
# Average return training: 28.72
# 166 40.0
# Average return training: 28.97
# Average return over 25 episodes of playing: 29.72
# 167 20.0
# Average return training: 29.09
# 168 28.0
# Average return training: 29.2
# 169 19.0
# Average return training: 29.1
# 170 15.0
# Average return training: 29.08
# 171 13.0
# Average return training: 28.4
# 172 25.0
# Average return training: 28.48
# 173 19.0
# Average return training: 28.48
# 174 50.0
# Average return training: 28.59
# 175 61.0
# Average return training: 28.73
# 176 13.0
# Average return training: 28.72
# 177 21.0
# Average return training: 28.72
# 178 16.0
# Average return training: 28.67
# 179 21.0
# Average return training: 28.72
# 180 18.0
# Average return training: 28.71
# 181 19.0
# Average return training: 28.74
# 182 48.0
# Average return training: 28.82
# 183 86.0
# Average return training: 29.48
# Average return over 25 episodes of playing: 31.0
# 184 22.0
# Average return training: 29.37
# 185 137.0
# Average return training: 30.43
# 186 11.0
# Average return training: 30.16
# 187 14.0
# Average return training: 30.07
# 188 31.0
# Average return training: 30.12
# 189 18.0
# Average return training: 30.08
# 190 25.0
# Average return training: 30.15
# 191 28.0
# Average return training: 30.22
# 192 121.0
# Average return training: 31.21
# 193 11.0
# Average return training: 31.17
# 194 41.0
# Average return training: 30.98
# 195 18.0
# Average return training: 31.02
# 196 28.0
# Average return training: 30.94
# Average return over 25 episodes of playing: 43.2
# 197 46.0
# Average return training: 31.06
# 198 12.0
# Average return training: 30.49
# 199 23.0
# Average return training: 30.16
# 200 21.0
# Average return training: 30.16
# 201 15.0
# Average return training: 30.17
# 202 23.0
# Average return training: 30.25
# 203 46.0
# Average return training: 30.52
# 204 15.0
# Average return training: 30.5
# 205 15.0
# Average return training: 30.45
# 206 53.0
# Average return training: 30.73
# 207 27.0
# Average return training: 30.82
# 208 17.0
# Average return training: 30.61
# 209 56.0
# Average return training: 30.98
# 210 11.0
# Average return training: 30.76
# 211 39.0
# Average return training: 30.9
# 212 23.0
# Average return training: 30.98
# 213 68.0
# Average return training: 31.5
# Average return over 25 episodes of playing: 32.72
# 214 22.0
# Average return training: 31.35
# 215 35.0
# Average return training: 31.5
# 216 14.0
# Average return training: 31.37
# 217 20.0
# Average return training: 31.18
# 218 40.0
# Average return training: 31.32
# 219 29.0
# Average return training: 31.35
# 220 27.0
# Average return training: 31.44
# 221 50.0
# Average return training: 31.79
# 222 46.0
# Average return training: 32.1
# 223 43.0
# Average return training: 31.68
# 224 40.0
# Average return training: 31.77
# 225 51.0
# Average return training: 32.15
# 226 43.0
# Average return training: 32.33
# 227 42.0
# Average return training: 32.6
# Average return over 25 episodes of playing: 32.72
# 228 32.0
# Average return training: 32.63
# 229 28.0
# Average return training: 32.77
# 230 20.0
# Average return training: 32.24
# 231 22.0
# Average return training: 32.11
# 232 16.0
# Average return training: 31.96
# 233 37.0
# Average return training: 32.18
# 234 88.0
# Average return training: 32.58
# 235 36.0
# Average return training: 32.8
# 236 59.0
# Average return training: 33.08
# 237 24.0
# Average return training: 33.23
# 238 48.0
# Average return training: 33.19
# 239 52.0
# Average return training: 33.36
# Average return over 25 episodes of playing: 36.96
# 240 75.0
# Average return training: 33.93
# 241 13.0
# Average return training: 33.78
# 242 75.0
# Average return training: 34.06
# 243 21.0
# Average return training: 33.7
# 244 54.0
# Average return training: 33.73
# 245 25.0
# Average return training: 33.71
# 246 30.0
# Average return training: 33.58
# 247 177.0
# Average return training: 35.13
# 248 68.0
# Average return training: 35.02
# Average return over 25 episodes of playing: 49.32
# 249 92.0
# Average return training: 35.7
# 250 33.0
# Average return training: 35.61
# 251 36.0
# Average return training: 35.71
# 252 45.0
# Average return training: 35.75
# 253 33.0
# Average return training: 35.91
# 254 38.0
# Average return training: 35.99
# 255 15.0
# Average return training: 35.44
# 256 29.0
# Average return training: 35.49
# 257 23.0
# Average return training: 35.55
# 258 111.0
# Average return training: 36.48
# Average return over 25 episodes of playing: 49.2
# 259 72.0
# Average return training: 36.89
# 260 29.0
# Average return training: 36.97
# 261 31.0
# Average return training: 37.04
# 262 28.0
# Average return training: 37.2
# 263 24.0
# Average return training: 37.24
# 264 56.0
# Average return training: 37.63
# 265 52.0
# Average return training: 37.96
# 266 36.0
# Average return training: 37.92
# 267 61.0
# Average return training: 38.33
# 268 58.0
# Average return training: 38.63
# 269 19.0
# Average return training: 38.63
# 270 61.0
# Average return training: 39.09
# Average return over 25 episodes of playing: 47.24
# 271 46.0
# Average return training: 39.42
# 272 67.0
# Average return training: 39.84
# 273 101.0
# Average return training: 40.66
# 274 68.0
# Average return training: 40.84
# 275 103.0
# Average return training: 41.26
# 276 74.0
# Average return training: 41.87
# Average return over 25 episodes of playing: 55.88
# 277 131.0
# Average return training: 42.97
# 278 31.0
# Average return training: 43.12
# 279 132.0
# Average return training: 44.23
# 280 157.0
# Average return training: 45.62
# 281 25.0
# Average return training: 45.68
# 282 69.0
# Average return training: 45.89
# Average return over 25 episodes of playing: 83.28
# 283 59.0
# Average return training: 45.62
# 284 35.0
# Average return training: 45.75
# 285 44.0
# Average return training: 44.82
# 286 63.0
# Average return training: 45.34
# 287 71.0
# Average return training: 45.91
# 288 82.0
# Average return training: 46.42
# 289 57.0
# Average return training: 46.81
# 290 92.0
# Average return training: 47.48
# Average return over 25 episodes of playing: 87.52
# 291 63.0
# Average return training: 47.83
# 292 89.0
# Average return training: 47.51
# 293 68.0
# Average return training: 48.08
# 294 126.0
# Average return training: 48.93
# 295 16.0
# Average return training: 48.91
# 296 94.0
# Average return training: 49.57
# 297 52.0
# Average return training: 49.63
# Average return over 25 episodes of playing: 77.04
# 298 34.0
# Average return training: 49.85
# 299 113.0
# Average return training: 50.75
# 300 126.0
# Average return training: 51.8
# 301 41.0
# Average return training: 52.06
# 302 35.0
# Average return training: 52.18
# 303 41.0
# Average return training: 52.13
# 304 43.0
# Average return training: 52.41
# 305 42.0
# Average return training: 52.68
# Average return over 25 episodes of playing: 56.84
# 306 108.0
# Average return training: 53.23
# 307 108.0
# Average return training: 54.04
# 308 56.0
# Average return training: 54.43
# 309 90.0
# Average return training: 54.77
# 310 101.0
# Average return training: 55.67
# Average return over 25 episodes of playing: 128.08
# 311 131.0
# Average return training: 56.59
# 312 133.0
# Average return training: 57.69
# 313 80.0
# Average return training: 57.81
# Average return over 25 episodes of playing: 106.64
# 314 258.0
# Average return training: 60.17
# 315 116.0
# Average return training: 60.98
# 316 144.0
# Average return training: 62.28
# 317 183.0
# Average return training: 63.91
# Average return over 25 episodes of playing: 153.84
# 318 104.0
# Average return training: 64.55
# 319 243.0
# Average return training: 66.69
# 320 86.0
# Average return training: 67.28
# Average return over 25 episodes of playing: 123.4
# 321 370.0
# Average return training: 70.48
# Average return over 25 episodes of playing: 136.88
# 322 293.0
# Average return training: 72.95
# 323 142.0
# Average return training: 73.94
# 324 126.0
# Average return training: 74.8
# 325 80.0
# Average return training: 75.09
# Average return over 25 episodes of playing: 116.64
# 326 132.0
# Average return training: 75.98
# 327 103.0
# Average return training: 76.59
# 328 119.0
# Average return training: 77.46
# 329 127.0
# Average return training: 78.45
# 330 65.0
# Average return training: 78.9
# Average return over 25 episodes of playing: 96.92
# 331 73.0
# Average return training: 79.41
# 332 40.0
# ...
# Average return over 25 episodes of playing: 365.6
# 606 500.0
# Average return training: 72.16
# Average return over 25 episodes of playing: 394.56
# 607 500.0
# Average return training: 76.93
# Average return over 25 episodes of playing: 384.4
# 608 407.0
# Average return training: 80.74
# Average return over 25 episodes of playing: 358.32
# 609 364.0
# Average return training: 84.18
# Average return over 25 episodes of playing: 297.36
# 610 330.0
# Average return training: 87.25
# 611 270.0
# Average return training: 89.72
# Average return over 25 episodes of playing: 280.64
# 612 198.0
# Average return training: 91.57
# 613 231.0
# Average return training: 93.69
# 614 201.0
# Average return training: 95.52
# Average return over 25 episodes of playing: 168.6
# 615 146.0
# Average return training: 96.75
# 616 160.0
# Average return training: 98.16
# 617 63.0
# Average return training: 98.62
# Average return over 25 episodes of playing: 116.56
# 618 150.0
# Average return training: 99.84
# 619 116.0
# Average return training: 100.77
# 620 130.0
# Average return training: 101.82
# 621 107.0
# Average return training: 102.64
# 622 25.0
# Average return training: 102.58
# 623 43.0
# Average return training: 102.84
# 624 23.0
# Average return training: 102.74
# Average return over 25 episodes of playing: 44.12
# 625 106.0
# Average return training: 103.52
# 626 30.0
# Average return training: 103.55
# 627 27.0
# Average return training: 103.64
# 628 100.0
# Average return training: 104.43
# 629 102.0
# Average return training: 105.23
# 630 23.0
# Average return training: 105.11
# 631 107.0
# Average return training: 105.86
# Average return over 25 episodes of playing: 62.0
# 632 105.0
# Average return training: 106.62
# 633 34.0
# Average return training: 106.81
# 634 44.0
# Average return training: 106.76
# 635 38.0
# Average return training: 106.83
# 636 120.0
# Average return training: 107.88
# 637 42.0
# Average return training: 107.97
# 638 139.0
# Average return training: 109.07
# Average return over 25 episodes of playing: 114.76
# 639 109.0
# Average return training: 109.99
# 640 26.0
# Average return training: 109.96
# 641 120.0
# Average return training: 110.77
# 642 35.0
# Average return training: 110.87
# 643 128.0
# Average return training: 111.95
# Average return over 25 episodes of playing: 106.32
# 644 148.0
# Average return training: 113.14
# 645 32.0
# Average return training: 113.23
# 646 156.0
# Average return training: 114.47
# 647 142.0
# Average return training: 115.68
# Average return over 25 episodes of playing: 155.76
# 648 167.0
# Average return training: 117.14
# 649 35.0
# Average return training: 117.25
# 650 186.0
# Average return training: 118.88
# 651 181.0
# Average return training: 120.47
# Average return over 25 episodes of playing: 151.76
# 652 208.0
# Average return training: 122.3
# 653 185.0
# Average return training: 123.83
# 654 99.0
# Average return training: 124.48
# Average return over 25 episodes of playing: 150.68
# 655 183.0
# Average return training: 126.09
# 656 217.0
# Average return training: 128.06
# Average return over 25 episodes of playing: 158.0
# 657 213.0
# Average return training: 129.86
# 658 224.0
# Average return training: 131.9
# 659 240.0
# Average return training: 133.91
# Average return over 25 episodes of playing: 187.68
# 660 120.0
# Average return training: 134.9
# 661 294.0
# Average return training: 137.56
# Average return over 25 episodes of playing: 234.64
# 662 280.0
# Average return training: 140.07
# 663 73.0
# Average return training: 140.43
# Average return over 25 episodes of playing: 210.24
# 664 345.0
# Average return training: 143.65
# 665 174.0
# Average return training: 145.11
# 666 18.0
# Average return training: 144.94
# 667 65.0
# Average return training: 145.28
# Average return over 25 episodes of playing: 290.64
# 668 398.0
# Average return training: 148.75
# 669 23.0
# Average return training: 148.68
# Average return over 25 episodes of playing: 293.56
# 670 460.0
# Average return training: 152.43
# Average return over 25 episodes of playing: 248.96
# 671 304.0
# Average return training: 155.14
# 672 100.0
# Average return training: 155.78
# 673 35.0
# Average return training: 155.77
# 674 177.0
# Average return training: 156.32
# Average return over 25 episodes of playing: 258.64
# 675 500.0
# Average return training: 160.72
# Average return over 25 episodes of playing: 336.92
# 676 145.0
# Average return training: 161.08
# 677 40.0
# Average return training: 160.99
# 678 189.0
# Average return training: 161.48
# 679 231.0
# Average return training: 162.38
# Average return over 25 episodes of playing: 240.12
# 680 425.0
# Average return training: 165.03
# Average return over 25 episodes of playing: 255.8
# 681 399.0
# Average return training: 166.54
# Average return over 25 episodes of playing: 253.08
# 682 316.0
# Average return training: 166.87
# 683 219.0
# Average return training: 166.45
# 684 87.0
# Average return training: 164.36
# Average return over 25 episodes of playing: 162.2
# 685 249.0
# Average return training: 165.86
# 686 177.0
# Average return training: 165.83
# 687 18.0
# Average return training: 165.01
# 688 134.0
# Average return training: 165.29
# Average return over 25 episodes of playing: 119.76
# 689 17.0
# Average return training: 164.11
# 690 99.0
# Average return training: 163.87
# 691 19.0
# Average return training: 162.89
# 692 133.0
# Average return training: 163.05
# 693 108.0
# Average return training: 163.07
# 694 127.0
# Average return training: 163.37
# Average return over 25 episodes of playing: 64.08
# 695 11.0
# Average return training: 162.56
# 696 120.0
# Average return training: 162.52
# 697 15.0
# Average return training: 161.82
# 698 24.0
# Average return training: 161.25
# 699 20.0
# Average return training: 160.3
# 700 28.0
# Average return training: 158.76
# 701 155.0
# Average return training: 159.75
# Average return over 25 episodes of playing: 87.6
# 702 153.0
# Average return training: 159.98
# 703 30.0
# Average return training: 157.09
# 704 188.0
# Average return training: 155.68
# 705 101.0
# Average return training: 153.58
# Average return over 25 episodes of playing: 187.64
# 706 264.0
# Average return training: 151.22
# 707 219.0
# Average return training: 148.41
# Average return over 25 episodes of playing: 240.52
# 708 364.0
# Average return training: 147.98
# Average return over 25 episodes of playing: 247.24
# 709 475.0
# Average return training: 149.09
# Average return over 25 episodes of playing: 328.44
# 710 452.0
# Average return training: 150.31
# 711 198.0
# Average return training: 149.59
# Average return over 25 episodes of playing: 323.2
# 712 192.0
# Average return training: 149.53
# Average return over 25 episodes of playing: 369.04
# 713 500.0
# Average return training: 152.22
# 714 377.0
# Average return training: 153.98
# Average return over 25 episodes of playing: 363.2
# 715 500.0
# Average return training: 157.52
# Average return over 25 episodes of playing: 433.32
# 716 481.0
# Average return training: 160.73
# Average return over 25 episodes of playing: 388.8
# 717 500.0
# Average return training: 165.1
# Average return over 25 episodes of playing: 388.08
# 718 261.0
# Average return training: 166.21
# 719 359.0
# Average return training: 168.64
# Average return over 25 episodes of playing: 419.0
# 720 500.0
# Average return training: 172.34
# Average return over 25 episodes of playing: 352.96
# 721 500.0
# Average return training: 176.27
# Average return over 25 episodes of playing: 366.68
# 722 500.0
# Average return training: 181.02
# Average return over 25 episodes of playing: 405.0
# 723 184.0
# Average return training: 182.43
# 724 330.0
# Average return training: 185.5
# Average return over 25 episodes of playing: 366.2
# 725 500.0
# Average return training: 189.44
# Average return over 25 episodes of playing: 392.6
# 726 275.0
# Average return training: 191.89
# Average return over 25 episodes of playing: 404.52
# 727 355.0
# Average return training: 195.17
# Average return over 25 episodes of playing: 323.64
# 728 379.0
# Average return training: 197.96
# 729 433.0
# Average return training: 201.27
# Average return over 25 episodes of playing: 369.36
# 730 321.0
# Average return training: 204.25
# Average return over 25 episodes of playing: 323.32
# 731 255.0
# Average return training: 205.73
# 732 292.0
# Average return training: 207.6
# Average return over 25 episodes of playing: 378.6
# 733 277.0
# Average return training: 210.03
# Average return over 25 episodes of playing: 397.0
# 734 500.0
# Average return training: 214.59
# Average return over 25 episodes of playing: 390.12
# 735 500.0
# Average return training: 219.21
# Average return over 25 episodes of playing: 369.2
# 736 500.0
# Average return training: 223.01
# Average return over 25 episodes of playing: 391.48
# 737 479.0
# Average return training: 227.38
# 738 378.0
# Average return training: 229.77
# Average return over 25 episodes of playing: 399.12
# 739 440.0
# Average return training: 233.08
# Average return over 25 episodes of playing: 380.76
# 740 500.0
# Average return training: 237.82
# Average return over 25 episodes of playing: 424.8
# 741 500.0
# Average return training: 241.62
# Average return over 25 episodes of playing: 434.2
# 742 450.0
# Average return training: 245.77
# Average return over 25 episodes of playing: 428.04
# 743 446.0
# Average return training: 248.95
# Average return over 25 episodes of playing: 423.16
# 744 500.0
# Average return training: 252.47
# Average return over 25 episodes of playing: 412.56
# 745 500.0
# Average return training: 257.15
# Average return over 25 episodes of playing: 410.16
# 746 475.0
# Average return training: 260.34
# Average return over 25 episodes of playing: 440.04
# 747 263.0
# Average return training: 261.55
# Average return over 25 episodes of playing: 440.44
# 748 500.0
# Average return training: 264.88
# Average return over 25 episodes of playing: 422.08
# 749 490.0
# Average return training: 269.43
# 750 457.0
# Average return training: 272.14
# Average return over 25 episodes of playing: 466.12
# 751 340.0
# Average return training: 273.73
# Average return over 25 episodes of playing: 471.52
# 752 500.0
# Average return training: 276.65
# Average return over 25 episodes of playing: 432.76
# 753 500.0
# Average return training: 279.8
# Average return over 25 episodes of playing: 419.4
# 754 500.0
# Average return training: 283.81
# Average return over 25 episodes of playing: 428.04
# 755 500.0
# Average return training: 286.98
# Average return over 25 episodes of playing: 445.76
# 756 392.0
# Average return training: 288.73
# Average return over 25 episodes of playing: 447.32
# 757 500.0
# Average return training: 291.6
# Average return over 25 episodes of playing: 471.8
# 758 500.0
# Average return training: 294.36
# Average return over 25 episodes of playing: 423.32
# 759 500.0
# Average return training: 296.96
# Average return over 25 episodes of playing: 449.04
# 760 500.0
# Average return training: 300.76
# Average return over 25 episodes of playing: 465.16
# 761 500.0
# Average return training: 302.82
# Average return over 25 episodes of playing: 460.36
# 762 500.0
# Average return training: 305.02
# Average return over 25 episodes of playing: 488.56
# 763 341.0
# Average return training: 307.7
# Average return over 25 episodes of playing: 466.48
# 764 500.0
# Average return training: 309.25
# 765 384.0
# Average return training: 311.35
# Average return over 25 episodes of playing: 448.28
# 766 500.0
# Average return training: 316.17
# Average return over 25 episodes of playing: 459.8
# 767 455.0
# Average return training: 320.07
# Average return over 25 episodes of playing: 415.6
# 768 500.0
# Average return training: 321.09
# Average return over 25 episodes of playing: 445.92
# 769 500.0
# Average return training: 325.86
# Average return over 25 episodes of playing: 412.0
# 770 500.0
# Average return training: 326.26
# Average return over 25 episodes of playing: 427.72
# 771 218.0
# Average return training: 325.4
# Average return over 25 episodes of playing: 371.12
# 772 500.0
# Average return training: 329.4
# 773 401.0
# Average return training: 333.06
# Average return over 25 episodes of playing: 364.16
# 774 481.0
# Average return training: 336.1
# Average return over 25 episodes of playing: 364.96
# 775 88.0
# Average return training: 331.98
# 776 100.0
# Average return training: 331.53
# Average return over 25 episodes of playing: 356.96
# 777 500.0
# Average return training: 336.13
# 778 294.0
# Average return training: 337.18
# Average return over 25 episodes of playing: 319.4
# 779 365.0
# Average return training: 338.52
# Average return over 25 episodes of playing: 289.64
# 780 500.0
# Average return training: 339.27
# 781 158.0
# Average return training: 336.86
# Average return over 25 episodes of playing: 229.16
# 782 27.0
# Average return training: 333.97
# 783 215.0
# Average return training: 333.93
# Average return over 25 episodes of playing: 183.08
# 784 312.0
# Average return training: 336.18
# 785 99.0
# Average return training: 334.68
# 786 283.0
# Average return training: 335.74
# Average return over 25 episodes of playing: 281.72
# 787 221.0
# Average return training: 337.77
# 788 320.0
# Average return training: 339.63
# Average return over 25 episodes of playing: 290.76
# 789 328.0
# Average return training: 342.74
# 790 85.0
# Average return training: 342.6
# Average return over 25 episodes of playing: 291.48
# 791 500.0
# Average return training: 347.41
# Average return over 25 episodes of playing: 264.6
# 792 271.0
# Average return training: 348.79
# 793 197.0
# Average return training: 349.68
# 794 92.0
# Average return training: 349.33
# Average return over 25 episodes of playing: 315.2
# 795 248.0
# Average return training: 351.7
# Average return over 25 episodes of playing: 336.48
# 796 471.0
# Average return training: 355.21
# 797 137.0
# Average return training: 356.43
# Average return over 25 episodes of playing: 364.64
# 798 320.0
# Average return training: 359.39
# 799 181.0
# Average return training: 361.0
# Average return over 25 episodes of playing: 347.92
# 800 218.0
# Average return training: 362.9
# 801 313.0
# Average return training: 364.48
# Average return over 25 episodes of playing: 360.84
# 802 500.0
# Average return training: 367.95
# Average return over 25 episodes of playing: 393.44
# 803 186.0
# Average return training: 369.51
# Average return over 25 episodes of playing: 378.48
# 804 500.0
# Average return training: 372.63
# 805 398.0
# Average return training: 375.6
# Average return over 25 episodes of playing: 373.72
# 806 282.0
# Average return training: 375.78
# Average return over 25 episodes of playing: 414.68
# 807 500.0
# Average return training: 378.59
# Average return over 25 episodes of playing: 430.04
# 808 500.0
# Average return training: 379.95
# Average return over 25 episodes of playing: 444.4
# 809 400.0
# Average return training: 379.2
# Average return over 25 episodes of playing: 406.56
# 810 454.0
# Average return training: 379.22
# 811 351.0
# Average return training: 380.75
# Average return over 25 episodes of playing: 442.68
# 812 500.0
# Average return training: 383.83
# Average return over 25 episodes of playing: 423.32
# 813 500.0
# Average return training: 383.83
# Average return over 25 episodes of playing: 458.44
# 814 500.0
# Average return training: 385.06
# Average return over 25 episodes of playing: 410.6
# 815 500.0
# Average return training: 385.06
# Average return over 25 episodes of playing: 419.56
# 816 500.0
# Average return training: 385.25
# Average return over 25 episodes of playing: 435.64
# 817 323.0
# Average return training: 383.48
# Average return over 25 episodes of playing: 406.56
# 818 500.0
# Average return training: 385.87
# Average return over 25 episodes of playing: 437.0
# 819 500.0
# Average return training: 387.28
# Average return over 25 episodes of playing: 441.68
# 820 459.0
# Average return training: 386.87
# Average return over 25 episodes of playing: 426.0
# 821 500.0
# Average return training: 386.87
# Average return over 25 episodes of playing: 425.28
# 822 500.0
# Average return training: 386.87
# Average return over 25 episodes of playing: 424.12
# 823 500.0
# Average return training: 390.03
# Average return over 25 episodes of playing: 434.36
# 824 500.0
# Average return training: 391.73
# Average return over 25 episodes of playing: 463.8
# 825 500.0
# Average return training: 391.73
# Average return over 25 episodes of playing: 489.76
# 826 500.0
# Average return training: 393.98
# Average return over 25 episodes of playing: 482.4
# 827 500.0
# Average return training: 395.43
# 828 74.0
# Average return training: 392.38
# Average return over 25 episodes of playing: 496.68
# 829 500.0
# Average return training: 393.05
# Average return over 25 episodes of playing: 500.0
# 830 500.0
# Average return training: 394.84
# Average return over 100 episodes of trained agent: 495.57
